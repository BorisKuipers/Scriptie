# %% [markdown]
# # LSTM model met alle mempool data

# %%
# pip install shap tensorflow numpy matplotlib

# %%
# Install shap first
# !pip install shap

# %%
# # Import shap if installed, otherwise install it first
# try:
#     import shap
# except ImportError:
#     import subprocess
#     import sys
#     subprocess.check_call([sys.executable, "-m", "pip", "install", "shap"])
#     import shap

# %%
# import shap

# %%
# Import data
import pandas as pd

# Read the dataset without mempool data
df = pd.read_csv('C:/Users/boris/Documents/M&T/Financial Innovation/Afstuderen/Scriptie/Feature_engineering/df_geen_mempool.csv')

# %%
df= df.drop(columns = 'regime_change')

# %%
df
# Out:
#        Timestamp       Open       High        Low      Close        Volume  \
# 0     2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1     2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2     2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3     2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4     2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...          ...        ...        ...        ...        ...           ...
# 2660  2025-05-15  103514.00  104184.00  101442.00  103793.00   1339.093301
# 2661  2025-05-16  103800.00  104570.00  103137.00  103506.00    994.760377
# 2662  2025-05-17  103503.00  103720.00  102668.00  103153.00    459.809889
# 2663  2025-05-18  103172.00  106635.00  103149.00  106520.00    905.179396
# 2664  2025-05-19  106520.00  107115.00  102126.00  105622.00   1677.932123
#
#       value value_classification  daily_std            MA7          MA30  \
# 0      30.0                 Fear    683.300   10602.648571  12637.540000
# 1      15.0         Extreme Fear    804.425   10250.204286  12429.063333
# 2      40.0                 Fear    636.625    9956.165714  12249.274000
# 3      24.0         Extreme Fear    650.940    9484.974286  11980.415000
# 4      11.0         Extreme Fear    775.185    8862.992857  11650.574333
# ...     ...                  ...        ...            ...           ...
# 2660   70.0                Greed   1371.000  103740.571429  95361.833333
# 2661   71.0                Greed    716.500  103814.142857  96010.500000
# 2662   74.0                Greed    526.000  103577.571429  96617.133333
# 2663   74.0                Greed   1743.000  103919.142857  97352.200000
# 2664   74.0                Greed   2494.500  104322.857143  98037.300000
#
#       market_regime
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 2660              0
# 2661              0
# 2662              0
# 2663              0
# 2664              0
#
# [2665 rows x 12 columns]

# %%
# Check for missing values in the 'value' column
print("Number of missing values in 'value' column:", df['value'].isna().sum())

# Interpolate missing values in the 'value' column using linear interpolation
df['value'] = df['value'].interpolate(method='linear')

# Verify that all missing values are filled
print("Number of missing values after interpolation:", df['value'].isna().sum())
# Out:
# Number of missing values in 'value' column: 4
# Number of missing values after interpolation: 0

# %% [markdown]
# ### Mempool data toevoegen aan df

# %%
# Read mempool data
mempool_df = pd.read_csv('C:/Users/boris/Documents/M&T/Financial Innovation/Afstuderen/Scriptie/Feature_engineering/mempool_data.csv')

# %%
mempool_df
# Out:
#             Date  mempool_transaction_count  MempoolSizeBytes  avg_fee_usd
# 0     2018-02-01                   9.784452         17.768706     4.351634
# 1     2018-02-02                   9.764333         17.773003     4.305297
# 2     2018-02-03                   9.743801         17.777281     4.393192
# 3     2018-02-04                   9.394608         17.405676     4.578901
# 4     2018-02-05                   8.853456         16.807729     4.889506
# ...          ...                        ...               ...          ...
# 2651  2025-05-06                   8.574361         14.885169     4.619751
# 2652  2025-05-07                   8.498121         15.494085     4.774688
# 2653  2025-05-08                   8.415585         15.869819     4.990036
# 2654  2025-05-09                   8.391017         15.795769     5.078121
# 2655  2025-05-10                   8.365830         15.715794     5.098894
#
# [2656 rows x 4 columns]

# %%
# Convert 'Date' column to datetime
mempool_df['Date'] = pd.to_datetime(mempool_df['Date'])

# Rename 'Date' column to 'Timestamp' to match df
mempool_df = mempool_df.rename(columns={'Date': 'Timestamp'})

# Set Timestamp as index to match format with df
mempool_df.set_index('Timestamp', inplace=True)

# %%
mempool_df.reset_index()
# Out:
#       Timestamp  mempool_transaction_count  MempoolSizeBytes  avg_fee_usd
# 0    2018-02-01                   9.784452         17.768706     4.351634
# 1    2018-02-02                   9.764333         17.773003     4.305297
# 2    2018-02-03                   9.743801         17.777281     4.393192
# 3    2018-02-04                   9.394608         17.405676     4.578901
# 4    2018-02-05                   8.853456         16.807729     4.889506
# ...         ...                        ...               ...          ...
# 2651 2025-05-06                   8.574361         14.885169     4.619751
# 2652 2025-05-07                   8.498121         15.494085     4.774688
# 2653 2025-05-08                   8.415585         15.869819     4.990036
# 2654 2025-05-09                   8.391017         15.795769     5.078121
# 2655 2025-05-10                   8.365830         15.715794     5.098894
#
# [2656 rows x 4 columns]

# %%
# Reset index of both dataframes before merging
df = df.reset_index()
mempool_df = mempool_df.reset_index()

# Convert Timestamp columns to datetime type
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
mempool_df['Timestamp'] = pd.to_datetime(mempool_df['Timestamp'])

# Merge df with mempool_df on Timestamp
df = pd.merge(df, mempool_df, on='Timestamp', how='left')

# Set Timestamp back as index
df.set_index('Timestamp', inplace=True)

# Check the merged dataframe
df
# Out:
#             index       Open       High        Low      Close        Volume  \
# Timestamp
# 2018-02-01      0    9974.91   10187.56    8820.96    8970.00  20517.085284
# 2018-02-02      1    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2018-02-03      2    8551.19    9443.96    8170.71    9386.72  17968.929040
# 2018-02-04      3    9391.30    9491.20    8189.32    8301.65  14407.720751
# 2018-02-05      4    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...           ...        ...        ...        ...        ...           ...
# 2025-05-15   2660  103514.00  104184.00  101442.00  103793.00   1339.093301
# 2025-05-16   2661  103800.00  104570.00  103137.00  103506.00    994.760377
# 2025-05-17   2662  103503.00  103720.00  102668.00  103153.00    459.809889
# 2025-05-18   2663  103172.00  106635.00  103149.00  106520.00    905.179396
# 2025-05-19   2664  106520.00  107115.00  102126.00  105622.00   1677.932123
#
#             value value_classification  daily_std            MA7  \
# Timestamp
# 2018-02-01   30.0                 Fear    683.300   10602.648571
# 2018-02-02   15.0         Extreme Fear    804.425   10250.204286
# 2018-02-03   40.0                 Fear    636.625    9956.165714
# 2018-02-04   24.0         Extreme Fear    650.940    9484.974286
# 2018-02-05   11.0         Extreme Fear    775.185    8862.992857
# ...           ...                  ...        ...            ...
# 2025-05-15   70.0                Greed   1371.000  103740.571429
# 2025-05-16   71.0                Greed    716.500  103814.142857
# 2025-05-17   74.0                Greed    526.000  103577.571429
# 2025-05-18   74.0                Greed   1743.000  103919.142857
# 2025-05-19   74.0                Greed   2494.500  104322.857143
#
#                     MA30  market_regime  mempool_transaction_count  \
# Timestamp
# 2018-02-01  12637.540000              1                   9.784452
# 2018-02-02  12429.063333              1                   9.764333
# 2018-02-03  12249.274000              1                   9.743801
# 2018-02-04  11980.415000              1                   9.394608
# 2018-02-05  11650.574333              1                   8.853456
# ...                  ...            ...                        ...
# 2025-05-15  95361.833333              0                        NaN
# 2025-05-16  96010.500000              0                        NaN
# 2025-05-17  96617.133333              0                        NaN
# 2025-05-18  97352.200000              0                        NaN
# 2025-05-19  98037.300000              0                        NaN
#
#             MempoolSizeBytes  avg_fee_usd
# Timestamp
# 2018-02-01         17.768706     4.351634
# 2018-02-02         17.773003     4.305297
# 2018-02-03         17.777281     4.393192
# 2018-02-04         17.405676     4.578901
# 2018-02-05         16.807729     4.889506
# ...                      ...          ...
# 2025-05-15               NaN          NaN
# 2025-05-16               NaN          NaN
# 2025-05-17               NaN          NaN
# 2025-05-18               NaN          NaN
# 2025-05-19               NaN          NaN
#
# [2665 rows x 15 columns]

# %%
# Save the dataframe with all features to CSV
df.to_csv('df_alle_features.csv')

# %%
# Keep only rows where data is available for all columns (drop rows with any NaN values)
df = df.dropna(how='any')

# %%
# Get first and last date from the DataFrame
first_date = df.index[0]
last_date = df.index[-1]

print(f"First date in dataset: {first_date}")
print(f"Last date in dataset: {last_date}")
# Out:
# First date in dataset: 2018-02-01 00:00:00
# Last date in dataset: 2025-05-10 00:00:00

# %%
# pip install tensorflow

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, LSTM

# %%
plt.figure(figsize=(16, 8))
plt.title('Bitcoin Close Price', fontsize=24)
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('USD', fontsize=18)
plt.grid(True)
plt.show()

# %% [markdown]
# # mempool features toevoegen aan de features

# %%
# Voeg features toe aan feature lijst (of juiste naam in jouw dataframe)
feature_columns = ['Close', 'Volume', 'value', 'daily_std', 
                  'MA7', 'MA30', 'market_regime', 'MempoolSizeBytes',
                  'mempool_transaction_count', 'avg_fee_usd']

# Maak features en target sets
features = df[feature_columns].values  # numpy array van alle features
target = df[['Close']].values  # Doel is nog steeds de Close prijs

# Train-val-test splits indices zoals eerder
train_size = int(len(df) * 0.7)
val_size = int(len(df) * 0.15) 
test_size = len(df) - train_size - val_size

train_end = train_size
val_end = train_size + val_size

# %%
# Splits features en target in train, val, test
train_features = features[:train_end]
val_features = features[train_end:val_end]
test_features = features[val_end:]

train_target = target[:train_end]
val_target = target[train_end:val_end]
test_target = target[val_end:]

# %%
# Normaliseer ALLE features op basis van training set
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_features)
val_scaled = scaler.transform(val_features)
test_scaled = scaler.transform(test_features)

# %%
# Target schaal apart houden en fitten op train target
target_scaler = MinMaxScaler(feature_range=(0,1))
train_target_scaled = target_scaler.fit_transform(train_target)
val_target_scaled = target_scaler.transform(val_target)
test_target_scaled = target_scaler.transform(test_target)

# %%
# Sequenties maken (nu voor alle features)
def create_sequences(features, target, seq_length=60):
    X, y = [], []
    for i in range(seq_length, len(features)):
        X.append(features[i-seq_length:i])  # alle features in sequentie
        y.append(target[i])
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_scaled, train_target_scaled)
X_val, y_val = create_sequences(val_scaled, val_target_scaled)
X_test, y_test = create_sequences(test_scaled, test_target_scaled)

# Check shapes
print("X_train shape:", X_train.shape)  # moet (samples, 60, 2) zijn
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (1796, 60, 10)
# y_train shape: (1796, 1)

# %% [markdown]
# # Model architectuur opzetten

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Zet de random seed voor reproduceerbaarheid
tf.random.set_seed(42)

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))  # 2 features
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))  # Voorspelling van 1 waarde: Close prijs

model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\boris\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # Iteratie 1:

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Early stopping om overfitting te voorkomen
early_stop = EarlyStopping(monitor='val_loss', patience=3)

# Train het model
history = model.fit(
    X_train, y_train,
    batch_size=32,
    epochs=20,
    validation_data=(X_val, y_val),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 0.0218 - val_loss: 0.0050
# Epoch 2/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 3/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 4/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 5/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 6/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 7/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 9.5926e-04 - val_loss: 0.0023
# Epoch 8/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 9.1434e-04 - val_loss: 0.0022
# Epoch 9/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 8.7576e-04 - val_loss: 0.0021
# Epoch 10/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 8.4240e-04 - val_loss: 0.0021
# Epoch 11/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 8.1264e-04 - val_loss: 0.0021
# Epoch 12/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 7.8513e-04 - val_loss: 0.0020
# Epoch 13/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 7.5905e-04 - val_loss: 0.0020
# Epoch 14/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 7.3406e-04 - val_loss: 0.0019
# Epoch 15/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 7.1010e-04 - val_loss: 0.0019
# Epoch 16/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 6.8719e-04 - val_loss: 0.0018
# Epoch 17/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.6528e-04 - val_loss: 0.0018
# Epoch 18/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.4431e-04 - val_loss: 0.0017
# Epoch 19/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.2420e-04 - val_loss: 0.0017
# Epoch 20/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.0488e-04 - val_loss: 0.0016

# %%
# Plot training and validation loss
plt.figure(figsize=(16, 8))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Make predictions on validation set
val_predictions = model.predict(X_val)

# Calculate RMSE
from sklearn.metrics import mean_squared_error
import numpy as np

val_rmse = np.sqrt(mean_squared_error(y_val, val_predictions))
print(f"Validation RMSE: {val_rmse}")

# Since the data was scaled, we should also show the unscaled RMSE
unscaled_val_rmse = val_rmse * (target_scaler.data_max_ - target_scaler.data_min_)
print(f"Unscaled Validation RMSE: {unscaled_val_rmse}")
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# Validation RMSE: 0.04005833148354525
# Unscaled Validation RMSE: [2588.60623413]

# %%
# For better date visualization, we can use the actual dates
# First define training size and sequence length
training_size = len(X_train)
sequence_length = X_train.shape[1]  # Get sequence length from training data shape

# Get the dates corresponding to validation set
val_dates = df.index[training_size+sequence_length:training_size+len(y_val)+sequence_length]

# Show the unscaled version
unscaled_y_val = target_scaler.inverse_transform(y_val.reshape(-1, 1))
unscaled_predictions = target_scaler.inverse_transform(val_predictions)

plt.figure(figsize=(16, 8))
plt.plot(val_dates, unscaled_y_val, label='Werkelijke prijs', alpha=0.8)
plt.plot(val_dates, unscaled_predictions, label='Voorspelde prijs', alpha=0.8)
plt.title('Voorspelde versus werkelijke Bitcoin prijs')
plt.xlabel('Datum')
plt.ylabel('Prijs in USD')
plt.legend()
plt.grid(True)

# Format x-axis to show dates properly
plt.gcf().autofmt_xdate()  # Rotate and align the tick labels
from matplotlib.dates import DateFormatter
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))

plt.show()

# %%
# Make predictions on validation set
val_predictions = model.predict(X_val)

# Calculate RMSE on unscaled predictions
val_rmse = np.sqrt(mean_squared_error(
    target_scaler.inverse_transform(y_val.reshape(-1, 1)),
    target_scaler.inverse_transform(val_predictions)
))

# Calculate MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((target_scaler.inverse_transform(y_val.reshape(-1, 1)) - 
                       target_scaler.inverse_transform(val_predictions)) / 
                       target_scaler.inverse_transform(y_val.reshape(-1, 1)))) * 100

print(f'Validation RMSE: ${val_rmse:,.2f}')
print(f'Validation MAPE: {mape:.2f}%')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Validation RMSE: $2,588.61
# Validation MAPE: 4.03%

# %% [markdown]
# # Ieteratie 2: Meer neuronen toevoegen

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Exacte modelstructuur van Iteratie 1
model_it_1_repeat = Sequential()
model_it_1_repeat.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model_it_1_repeat.add(LSTM(100, return_sequences=False))
model_it_1_repeat.add(Dense(25))
model_it_1_repeat.add(Dense(1))

# Zelfde optimizer en loss
model_it_1_repeat.compile(optimizer='adam', loss='mean_squared_error')

# Early stopping als veiligheid (optioneel, verhoogd naar patience=10)
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# Train het model
history_it_1_repeat = model_it_1_repeat.fit(
    X_train, y_train,
    batch_size=32,
    epochs=100,
    validation_data=(X_val, y_val),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# c:\Users\boris\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0196 - val_loss: 0.0053
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0010 - val_loss: 0.0027
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 9.6789e-04 - val_loss: 0.0025
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 8.9880e-04 - val_loss: 0.0024
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 8.4341e-04 - val_loss: 0.0023
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 8.0169e-04 - val_loss: 0.0023
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 7.7238e-04 - val_loss: 0.0022
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 7.5414e-04 - val_loss: 0.0022
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 7.4560e-04 - val_loss: 0.0022
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 7.4448e-04 - val_loss: 0.0022
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 7.4573e-04 - val_loss: 0.0021
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 7.4053e-04 - val_loss: 0.0019
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 7.2189e-04 - val_loss: 0.0018
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 6.9350e-04 - val_loss: 0.0016
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 6.6517e-04 - val_loss: 0.0015
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 6.4159e-04 - val_loss: 0.0014
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 6.2215e-04 - val_loss: 0.0014
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 6.0524e-04 - val_loss: 0.0013
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 5.8985e-04 - val_loss: 0.0013
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 5.7540e-04 - val_loss: 0.0012
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 5.6159e-04 - val_loss: 0.0012
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 5.4820e-04 - val_loss: 0.0011
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 5.3511e-04 - val_loss: 0.0011
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 5.2219e-04 - val_loss: 0.0011
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 5.0934e-04 - val_loss: 0.0011
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 4.9648e-04 - val_loss: 0.0010
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 4.8362e-04 - val_loss: 0.0010
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 4.7100e-04 - val_loss: 0.0010
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.5928e-04 - val_loss: 0.0010
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - loss: 4.4970e-04 - val_loss: 0.0010
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 4.4339e-04 - val_loss: 0.0011
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - loss: 4.3856e-04 - val_loss: 0.0010
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - loss: 4.3313e-04 - val_loss: 0.0010
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - loss: 4.2828e-04 - val_loss: 9.9721e-04
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 4.2201e-04 - val_loss: 9.8655e-04
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 4.1635e-04 - val_loss: 9.9225e-04
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 4.1266e-04 - val_loss: 9.8024e-04
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 4.0732e-04 - val_loss: 9.7330e-04
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 4.0238e-04 - val_loss: 9.6601e-04
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.9739e-04 - val_loss: 9.5946e-04
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.9244e-04 - val_loss: 9.5339e-04
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 3.8759e-04 - val_loss: 9.4819e-04
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.8292e-04 - val_loss: 9.4394e-04
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 3.7843e-04 - val_loss: 9.4079e-04
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 3.7418e-04 - val_loss: 9.3874e-04
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 3.7017e-04 - val_loss: 9.3775e-04
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - loss: 3.6643e-04 - val_loss: 9.3773e-04
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.6294e-04 - val_loss: 9.3865e-04
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 3.5968e-04 - val_loss: 9.4054e-04
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 3.5658e-04 - val_loss: 9.4354e-04
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 3.5359e-04 - val_loss: 9.4774e-04
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.5062e-04 - val_loss: 9.5307e-04

# %%
plt.figure(figsize=(16, 8))
plt.plot(history_it_1_repeat.history['loss'], label='Training Loss')
plt.plot(history_it_1_repeat.history['val_loss'], label='Validation Loss')
plt.title('Model Loss During Training (Iteratie 1 opnieuw, 100 epochs)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Make predictions on validation set
val_predictions = model_it_1_repeat.predict(X_val)

# Calculate RMSE on unscaled predictions
val_rmse = np.sqrt(mean_squared_error(
    target_scaler.inverse_transform(y_val.reshape(-1, 1)),
    target_scaler.inverse_transform(val_predictions)
))

# Calculate MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((target_scaler.inverse_transform(y_val.reshape(-1, 1)) - 
                       target_scaler.inverse_transform(val_predictions)) / 
                       target_scaler.inverse_transform(y_val.reshape(-1, 1)))) * 100

print(f'Validation RMSE: ${val_rmse:,.2f}')
print(f'Validation MAPE: {mape:.2f}%')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# Validation RMSE: $1,994.96
# Validation MAPE: 3.95%

# %%
# For better date visualization, we can use the actual dates
training_size = len(X_train)
sequence_length = X_train.shape[1]  # Get sequence length from training data shape

# Get the dates corresponding to validation set
val_dates = df.index[training_size+sequence_length:training_size+len(y_val)+sequence_length]

# Show the unscaled version
unscaled_y_val = target_scaler.inverse_transform(y_val.reshape(-1, 1))
unscaled_predictions = target_scaler.inverse_transform(val_predictions)

plt.figure(figsize=(16, 8))
plt.plot(val_dates, unscaled_y_val, label='Actual Price', alpha=0.8)
plt.plot(val_dates, unscaled_predictions, label='Predicted Price', alpha=0.8)
plt.title('Predicted vs Actual Bitcoin Price')
plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.legend()
plt.grid(True)

# Format x-axis to show dates properly
plt.gcf().autofmt_xdate()  # Rotate and align the tick labels
from matplotlib.dates import DateFormatter
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))

plt.show()

# %%
# Calculate RMSE on unscaled predictions
val_rmse = np.sqrt(mean_squared_error(
    target_scaler.inverse_transform(y_val.reshape(-1, 1)),
    target_scaler.inverse_transform(val_predictions)
))

# Calculate MAPE (Mean Absolute Percentage Error)
mape = np.mean(np.abs((target_scaler.inverse_transform(y_val.reshape(-1, 1)) - 
                       target_scaler.inverse_transform(val_predictions)) / 
                       target_scaler.inverse_transform(y_val.reshape(-1, 1)))) * 100

print(f'Validation RMSE: ${val_rmse:,.2f}')
print(f'Validation MAPE: {mape:.2f}%')
# Out:
# Validation RMSE: $1,994.96
# Validation MAPE: 3.95%

# %% [markdown]
# # Grid Search

# %%
# import itertools
# import numpy as np
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping
# from sklearn.metrics import mean_squared_error

# # Define parametergrid
# param_grid = {
#     'units_per_layer': [[25,25], [50,50], [150,150], [25,50], [50,150]], #Units
#     'num_layers': [1, 2, 3],
#     'return_sequences': [[True], [True, False], [True, True, False]],  # afgestemd op num_layers
#     'dropout': [0.0, 0.2, 0.3],
#     'recurrent_dropout': [0.0, 0.2, 0.3],
#     'batch_size': [16, 32, 64],
#     'learning_rate': [0.01, 0.001, 0.0001],
#     'epochs': [100]
# }

# # Combinaties zonder return_sequences
# base_keys = ['units_per_layer', 'num_layers', 'dropout', 'recurrent_dropout', 'batch_size', 'learning_rate', 'epochs']
# base_values = [param_grid[k] for k in base_keys]
# base_combinations = list(itertools.product(*base_values))

# results = []

# for base in base_combinations:
#     base_config = dict(zip(base_keys, base))

#     # Selecteer juiste return_sequences patroon op basis van aantal lagen
#     if base_config['num_layers'] == 1:
#         return_seq_options = [[True]]
#     elif base_config['num_layers'] == 2:
#         return_seq_options = [[True, False]]
#     else:
#         return_seq_options = [[True, True, False]]

#     for rs in return_seq_options:
#         config = base_config.copy()
#         config['return_sequences'] = rs

#         tf.keras.backend.clear_session()
#         model = Sequential()

#         for i in range(config['num_layers']):
#             return_seq = config['return_sequences'][i]
#             units = base_config['units_per_layer'][i]

#             if i == 0:
#                 model.add(LSTM(
#                     units=units,
#                     return_sequences=return_seq,
#                     dropout=config['dropout'],
#                     recurrent_dropout=config['recurrent_dropout'],
#                     input_shape=(X_train.shape[1], X_train.shape[2])
#                 ))
#             else:
#                 model.add(LSTM(
#                     units=units,
#                     return_sequences=return_seq,
#                     dropout=config['dropout'],
#                     recurrent_dropout=config['recurrent_dropout']
#                 ))

#         model.add(Dense(25))
#         model.add(Dense(1))

#         model.compile(optimizer=Adam(learning_rate=config['learning_rate']), loss='mean_squared_error')

#         early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

#         history = model.fit(
#             X_train, y_train,
#             validation_data=(X_val, y_val),
#             epochs=config['epochs'],
#             batch_size=config['batch_size'],
#             callbacks=[early_stop],
#             verbose=0
#         )

#         val_pred = model.predict(X_val, verbose=0)
#         rmse = np.sqrt(mean_squared_error(y_val, val_pred))

#         results.append({
#             **config,
#             'val_rmse': rmse
#         })

# # Beste config selecteren
# best_config = min(results, key=lambda x: x['val_rmse'])

# # Print resultaten
# print("\nBeste hyperparameters gevonden na grid search:")
# print("-------------------------------------------------------------------")
# print(f"Number of units (LSTM per layer): {best_config['units_per_layer']}")  
# print(f"Number of LSTM layers: {best_config['num_layers']}")
# print(f"Return sequences: {best_config['return_sequences']}")
# print(f"Dropout: {best_config['dropout']}")
# print(f"Recurrent Dropout: {best_config['recurrent_dropout']}")
# print(f"Batch size: {best_config['batch_size']}")
# print(f"Learning rate: {best_config['learning_rate']}")
# print(f"Number of epochs: {best_config['epochs']} (early stopping was actief)")

# %% [markdown]
# # Model met beste hyperparameters uit grid search trainen

# %%
# Create a new variant of the model with a different name
model_variant_2 = Sequential()
model_variant_2.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model_variant_2.add(LSTM(150, return_sequences=False))
model_variant_2.add(Dense(25))
model_variant_2.add(Dense(1))

# Compile with same optimizer and loss
model_variant_2.compile(optimizer='adam', loss='mean_squared_error')

# Early stopping callback
early_stop_v2 = EarlyStopping(monitor='val_loss', patience=5)

# Train the model
history_variant_2 = model_variant_2.fit(
    X_train, y_train,
    batch_size=32,
    epochs=100,
    validation_data=(X_val, y_val),
    callbacks=[early_stop_v2]
)
# Out:
# c:\Users\boris\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - loss: 0.0226 - val_loss: 0.0026
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 9.4052e-04 - val_loss: 0.0020
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 8.7074e-04 - val_loss: 0.0018
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 8.1804e-04 - val_loss: 0.0018
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 7.7683e-04 - val_loss: 0.0017
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 7.4382e-04 - val_loss: 0.0017
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 7.1742e-04 - val_loss: 0.0017
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 6.9664e-04 - val_loss: 0.0016
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - loss: 6.8082e-04 - val_loss: 0.0016
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 6.6951e-04 - val_loss: 0.0016
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 6.6245e-04 - val_loss: 0.0016
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 6.5948e-04 - val_loss: 0.0016
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.6032e-04 - val_loss: 0.0016
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.6409e-04 - val_loss: 0.0015
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 6.6850e-04 - val_loss: 0.0015
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 6.6920e-04 - val_loss: 0.0013
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 6.6112e-04 - val_loss: 0.0012
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.4293e-04 - val_loss: 0.0011
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.1929e-04 - val_loss: 0.0010
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 5.9629e-04 - val_loss: 9.5470e-04
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 5.7673e-04 - val_loss: 9.2406e-04
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 5.6051e-04 - val_loss: 9.0221e-04
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.4666e-04 - val_loss: 8.8434e-04
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.3439e-04 - val_loss: 8.6796e-04
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 5.2314e-04 - val_loss: 8.5219e-04
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.1254e-04 - val_loss: 8.3719e-04
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - loss: 5.0239e-04 - val_loss: 8.2358e-04
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 4.9258e-04 - val_loss: 8.1179e-04
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 4.8312e-04 - val_loss: 8.0178e-04
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.7407e-04 - val_loss: 7.9294e-04
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.6546e-04 - val_loss: 7.8399e-04
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.5727e-04 - val_loss: 7.7338e-04
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 4.4940e-04 - val_loss: 7.6045e-04
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 4.4162e-04 - val_loss: 7.4730e-04
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.3370e-04 - val_loss: 7.3717e-04
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.2597e-04 - val_loss: 7.2998e-04
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 4.1899e-04 - val_loss: 7.2265e-04
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - loss: 4.1292e-04 - val_loss: 7.1287e-04
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 4.0761e-04 - val_loss: 7.0196e-04
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.0201e-04 - val_loss: 6.9576e-04
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 3.9554e-04 - val_loss: 6.9407e-04
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 3.8916e-04 - val_loss: 6.9209e-04
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 3.8373e-04 - val_loss: 6.8938e-04
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 3.8140e-04 - val_loss: 6.7844e-04
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 3.8059e-04 - val_loss: 6.8187e-04
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 3.7523e-04 - val_loss: 6.9699e-04
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 3.7229e-04 - val_loss: 6.8794e-04
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.6828e-04 - val_loss: 6.8950e-04
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 3.6552e-04 - val_loss: 6.8158e-04

# %%
# Make predictions on validation set with variant 2 model
val_predictions_v2 = model_variant_2.predict(X_val)

# Calculate RMSE on unscaled predictions for variant 2
val_rmse_v2 = np.sqrt(mean_squared_error(
    target_scaler.inverse_transform(y_val.reshape(-1, 1)),
    target_scaler.inverse_transform(val_predictions_v2)
))

# Calculate MAPE for variant 2
val_mape_v2 = np.mean(np.abs((target_scaler.inverse_transform(y_val.reshape(-1, 1)) - 
                       target_scaler.inverse_transform(val_predictions_v2)) / 
                       target_scaler.inverse_transform(y_val.reshape(-1, 1)))) * 100

print(f'Validation RMSE Variant 2: ${val_rmse_v2:,.2f}')
print(f'Validation MAPE Variant 2: {val_mape_v2:.2f}%')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
# Validation RMSE Variant 2: $1,687.07
# Validation MAPE Variant 2: 3.12%

# %%
# Get the dates corresponding to validation set
val_dates = df.index[training_size+sequence_length:training_size+len(y_val)+sequence_length]

# Show the unscaled version
unscaled_y_val = target_scaler.inverse_transform(y_val.reshape(-1, 1))
unscaled_val_predictions = target_scaler.inverse_transform(val_predictions_v2)

plt.figure(figsize=(16, 8))
plt.plot(val_dates, unscaled_y_val, label='Actual Price', alpha=0.8)
plt.plot(val_dates, unscaled_val_predictions, label='Predicted Price', alpha=0.8)
plt.title('Predicted vs Actual Bitcoin Price (Validation Set) - Model Variant 2')
plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.legend()
plt.grid(True)

# Format x-axis to show dates properly
plt.gcf().autofmt_xdate()  # Rotate and align the tick labels
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))

plt.show()

# %% [markdown]
# # Resultaten testset berekenen

# %%
# Make predictions for variant 2
test_predictions_v2 = model_variant_2.predict(X_test)

# Calculate RMSE on unscaled predictions for variant 2
test_rmse_v2 = np.sqrt(mean_squared_error(
    target_scaler.inverse_transform(y_test.reshape(-1, 1)),
    target_scaler.inverse_transform(test_predictions_v2)
))

# Calculate MAPE for variant 2
test_mape_v2 = np.mean(np.abs((target_scaler.inverse_transform(y_test.reshape(-1, 1)) - 
                       target_scaler.inverse_transform(test_predictions_v2)) / 
                       target_scaler.inverse_transform(y_test.reshape(-1, 1)))) * 100

print(f'Test RMSE Variant 2: ${test_rmse_v2:,.2f}')
print(f'Test MAPE Variant 2: {test_mape_v2:.2f}%')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step
# Test RMSE Variant 2: $10,463.63
# Test MAPE Variant 2: 10.60%

# %%
# Get the dates corresponding to test set
test_dates = df.index[training_size+val_size+sequence_length:training_size+val_size+len(y_test)+sequence_length]

# Show the unscaled version
unscaled_y_test = target_scaler.inverse_transform(y_test.reshape(-1, 1))
unscaled_test_predictions = target_scaler.inverse_transform(test_predictions_v2)

plt.figure(figsize=(16, 8))
plt.plot(test_dates, unscaled_y_test, label='Actual Price', alpha=0.8)
plt.plot(test_dates, unscaled_test_predictions, label='Predicted Price', alpha=0.8)
plt.title('Predicted vs Actual Bitcoin Price (Test Set)')
plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.legend()
plt.grid(True)

# Format x-axis to show dates properly
plt.gcf().autofmt_xdate()  # Rotate and align the tick labels
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))

plt.show()

# %% [markdown]
# # Vegrelijking Model met baseline model:

# %% [markdown]
# ### Vergelijking testset prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter

# Geef het volledige pad op (gebruik raw string of dubbele backslashes)
file_path = r'C:\Users\boris\Documents\M&T\Financial Innovation\Afstuderen\Scriptie\LSTM_Model\saved_models\lstm_baseline_results_rmse_11037.22_mape_10.49.csv'

# Lees het CSV-bestand in, en parse de datumkolom
df = pd.read_csv(file_path, parse_dates=['Date'])

# Get dates from test set
test_dates = df['Date']

# Get actual and predicted values from variant 3
actual_prices = target_scaler.inverse_transform(y_test.reshape(-1, 1))
predicted_prices_v3 = target_scaler.inverse_transform(test_predictions_v2)

# Plotten van de daadwerkelijke en voorspelde prijzen
plt.figure(figsize=(16, 8))
plt.plot(test_dates, actual_prices, label='Actual Price', alpha=0.8)
plt.plot(test_dates, df['Predicted_Price'], label='Predicted Price (Baseline Model)', alpha=0.8)
plt.plot(test_dates, predicted_prices_v3, label='Predicted Price (Model with Mempool Size)', alpha=0.8)

plt.title('LSTM Prediction vs Actual – Baseline Model vs Model With Mempool Size Data')
plt.xlabel('Date')
plt.ylabel('Price in USD')
plt.legend()
plt.grid(True)

# Nettere datumnotatie
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))

plt.show()

# %% [markdown]
# # Feature Importance Analyse met Shap

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Functioneel model i.p.v. Sequential
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))
x = LSTM(50, return_sequences=True)(input_layer)
x = LSTM(150, return_sequences=False)(x)
x = Dense(25)(x)
output_layer = Dense(1)(x)

# Maak model
model_lstm = Model(inputs=input_layer, outputs=output_layer)
model_lstm.compile(optimizer='adam', loss='mean_squared_error')

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5)

history = model_lstm.fit(
    X_train, y_train,
    batch_size=32,
    epochs=100,
    validation_data=(X_val, y_val),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - loss: 0.0204 - val_loss: 0.0026
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - loss: 9.5900e-04 - val_loss: 0.0017
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 104ms/step - loss: 8.9462e-04 - val_loss: 0.0016
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 8.5052e-04 - val_loss: 0.0016
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - loss: 8.1859e-04 - val_loss: 0.0015
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - loss: 7.8939e-04 - val_loss: 0.0014
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - loss: 7.5788e-04 - val_loss: 0.0014
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 7.2485e-04 - val_loss: 0.0013
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 6.9340e-04 - val_loss: 0.0013
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 6.6515e-04 - val_loss: 0.0013
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 6.4004e-04 - val_loss: 0.0012
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - loss: 6.1769e-04 - val_loss: 0.0012
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - loss: 5.9824e-04 - val_loss: 0.0012
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 5.8170e-04 - val_loss: 0.0012
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - loss: 5.6730e-04 - val_loss: 0.0012
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - loss: 5.5427e-04 - val_loss: 0.0011
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 5.4219e-04 - val_loss: 0.0011
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 5.3079e-04 - val_loss: 0.0011
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 5.1995e-04 - val_loss: 0.0012
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 5.0954e-04 - val_loss: 0.0012
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.9946e-04 - val_loss: 0.0012
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 4.8964e-04 - val_loss: 0.0012

# %%
import shap
import numpy as np
import matplotlib.pyplot as plt

# Kleine subset (anders duurt SHAP te lang)
X_explain = X_val[:200]

# Maak explainer – dit werkt nu omdat het model 'input' en 'output' definieert
explainer = shap.GradientExplainer((model_lstm.input, model_lstm.output), X_explain)
shap_values = explainer.shap_values(X_explain)

# Gemiddelde SHAP over tijdstappen
shap_matrix = shap_values[0][:, :, 0]  # van (60, 10, 1) → (60, 10)


# Neem laatste tijdstap voor representatieve input per sample
X_explain = X_val[:60]                     # gebruik 60 samples
shap_matrix = shap_values[0][:, :, 0]      # (60, 10)
X_last = X_explain[:, -1, :]               # (60, 10)



X_last = np.array(X_last)  # Forceer correcte arrayvorm
print("SHAP shape:", shap_mean.shape)
print("X_last shape:", X_last.shape)

# Rename 'value' to 'Fear&Greed_Index' in feature_columns if needed
feature_columns = ['Fear&Greed_Index' if col == 'value' else col for col in feature_columns]


# Plot feature importance
shap.summary_plot(shap_matrix, X_last, feature_names=feature_columns)
# Out:
# c:\Users\boris\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_58
# Received: inputs=['Tensor(shape=(200, 60, 10))']
#   warnings.warn(msg)
# c:\Users\boris\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_58
# Received: inputs=['Tensor(shape=(50, 60, 10))']
#   warnings.warn(msg)
# SHAP shape: (60, 1)
# X_last shape: (60, 10)
# C:\Users\boris\AppData\Local\Temp\ipykernel_13020\192136387.py:32: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_matrix, X_last, feature_names=feature_columns)

# %%
# Bar plot van gemiddelde absolute SHAP waarden
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_matrix, X_last, feature_names=feature_columns, plot_type="bar")
# Out:
# C:\Users\boris\AppData\Local\Temp\ipykernel_13020\2317580890.py:3: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(shap_matrix, X_last, feature_names=feature_columns, plot_type="bar")
