# %% [markdown]
# # Code voor XGBOOST model:
#
# ### Onderdelen in Code:
# - Data Inladen
# - Data verkennen
# - Data Preprocessing
# - Feature Engineering
# - Baseline Model Getraind en geoptimaliseert
# - Model 1 = Baseline Model + Avg Fee
# - Model 2 = Baseline Model + Mempool data
# - Resultaten en plots

# %% [markdown]
# # BTC price historic data Data Inladen:

# %%
import sys
# !{sys.executable} -m pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (0.3.10)
# Requirement already satisfied: packaging in c:\users\boris\appdata\roaming\python\python313\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\boris\appdata\roaming\python\python313\site-packages (from tqdm->kagglehub) (0.4.6)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import os

# %%
import kagglehub


path = kagglehub.dataset_download("mczielinski/bitcoin-historical-data")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.10), please consider upgrading to the latest version (0.3.12).
# Path to dataset files: C:\Users\boris\.cache\kagglehub\datasets\mczielinski\bitcoin-historical-data\versions\242

# %% [markdown]
# # BTC histric data verkennen

# %%
import pandas as pd


csv_file = os.path.join(path, "btcusd_1-min_data.csv") 
df_holc = pd.read_csv(csv_file)

# Bekijk de eerste paar rijen van de dataset
df_holc.head()
# Out:
#       Timestamp  Open  High   Low  Close  Volume
# 0  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 1  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 2  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 3  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 4  1.325412e+09  4.58  4.58  4.58   4.58     0.0

# %%
df_holc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7039184 entries, 0 to 7039183
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Timestamp  float64
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Volume     float64
# dtypes: float64(6)
# memory usage: 322.2 MB

# %%
# Bekijk de unieke waarden in de Volume-kolom
unique_values = df_holc["Volume"].unique()

print("Unieke waarden in de Volume-kolom:", unique_values)
# Out:
# Unieke waarden in de Volume-kolom: [ 0.         10.         10.1        ...  0.10877982  1.0353187
#   0.92270432]

# %%
# Eerste timestamp
eerste_timestamp = df_holc["Timestamp"].min()

# Laatste timestamp
laatste_timestamp = df_holc["Timestamp"].max()

print("Eerste timestamp:", eerste_timestamp)
print("Laatste timestamp:", laatste_timestamp)
# Out:
# Eerste timestamp: 1325412060.0
# Laatste timestamp: 1747832640.0

# %%
import pandas as pd

# Timestamps omzetten naar een leesbaar formaat
eerste_datum = pd.to_datetime(1325412060, unit="s")
laatste_datum = pd.to_datetime(1740614400, unit="s")

print("Eerste datum:", eerste_datum)
print("Laatste datum:", laatste_datum)
# Out:
# Eerste datum: 2012-01-01 10:01:00
# Laatste datum: 2025-02-27 00:00:00

# %%
import matplotlib.pyplot as plt


df_holc["Timestamp"] = pd.to_datetime(df_holc["Timestamp"], unit="s")

# Plot de Closing Price over tijd
plt.figure(figsize=(12,6))
plt.plot(df_holc["Timestamp"], df_holc["Close"], label="Close Price", color="blue")

# Grafiek instellingen
plt.xlabel("Time")
plt.ylabel("Bitcoin Price (USD)")
plt.title("Bitcoin Price over Time")
plt.legend()
plt.grid(True)

# Weergeven
plt.show()

# %%
df_holc.shape
# Out:
# (7039184, 6)

# %%
df_holc.head()
# Out:
#             Timestamp  Open  High   Low  Close  Volume
# 0 2012-01-01 10:01:00  4.58  4.58  4.58   4.58     0.0
# 1 2012-01-01 10:02:00  4.58  4.58  4.58   4.58     0.0
# 2 2012-01-01 10:03:00  4.58  4.58  4.58   4.58     0.0
# 3 2012-01-01 10:04:00  4.58  4.58  4.58   4.58     0.0
# 4 2012-01-01 10:05:00  4.58  4.58  4.58   4.58     0.0

# %%
# Basis statistieken van de dataset
print("Basis statistieken:")
print(df_holc.describe())

# Controleren op missende waarden
print("\nMissende waarden per kolom:")
print(df_holc.isnull().sum())

# Correlatie tussen numerieke kolommen
correlation = df_holc[['Open', 'High', 'Low', 'Close', 'Volume']].corr()
print("\nCorrelatie matrix:")
print(correlation)

# Visualisaties
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Box plot voor prijsdistributie
plt.figure(figsize=(12,6))
df_holc[['Open', 'High', 'Low', 'Close']].boxplot()
plt.title('Distributie van Bitcoin prijzen')
plt.ylabel('Prijs (USD)')
plt.xticks(rotation=45)
plt.show()

# 2. Histogram van handelsvolume
plt.figure(figsize=(12,6))
plt.hist(df_holc['Volume'], bins=50)
plt.title('Distributie van Handelsvolume')
plt.xlabel('Volume')
plt.ylabel('Frequentie')
plt.show()

# 3. Correlatie heatmap
plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0)
plt.title('Correlatie Heatmap')
plt.show()

# 4. Volume over tijd
plt.figure(figsize=(12,6))
plt.plot(df_holc['Timestamp'], df_holc['Volume'])
plt.title('Handelsvolume over Tijd')
plt.xlabel('Tijd')
plt.ylabel('Volume')
plt.xticks(rotation=45)
plt.show()

# Outlier analyse
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]
    return outliers, lower_bound, upper_bound

# Outlier analyse voor elke numerieke kolom
numeric_columns = ['Open', 'High', 'Low', 'Close', 'Volume']
for column in numeric_columns:
    outliers, lower_bound, upper_bound = detect_outliers(df_holc, column)
    print(f"\nOutliers in {column}:")
    print(f"Aantal outliers: {len(outliers)}")
    print(f"Percentage outliers: {(len(outliers)/len(df_holc))*100:.2f}%")
    print(f"Lower bound: {lower_bound:.2f}")
    print(f"Upper bound: {upper_bound:.2f}")
    
    # Boxplot met outliers
    plt.figure(figsize=(10,6))
    sns.boxplot(x=df_holc[column])
    plt.title(f'Boxplot met Outliers - {column}')
    plt.show()

# Basis statistieken printen
print("\nSamenvatting van de dataset:")
print(f"Aantal rijen: {len(df_holc)}")
print(f"Tijdsperiode: van {df_holc['Timestamp'].min()} tot {df_holc['Timestamp'].max()}")
print("\nPrijs statistieken:")
print(f"Hoogste prijs ooit: ${df_holc['High'].max():,.2f}")
print(f"Laagste prijs ooit: ${df_holc['Low'].min():,.2f}")
print(f"Gemiddelde prijs: ${df_holc['Close'].mean():,.2f}")
print(f"Mediaan prijs: ${df_holc['Close'].median():,.2f}")
# Out:
# Basis statistieken:
#                            Timestamp          Open          High  \
# count                        7039184  7.039184e+06  7.039184e+06
# mean   2018-09-10 14:08:20.229224704  1.774059e+04  1.774758e+04
# min              2012-01-01 10:01:00  3.800000e+00  3.800000e+00
# 25%              2015-05-07 11:56:45  4.259900e+02  4.260700e+02
# 50%              2018-09-10 13:52:30  6.647110e+03  6.650825e+03
# 75%              2022-01-14 15:48:15  2.761700e+04  2.762400e+04
# max              2025-05-21 13:04:00  1.091110e+05  1.093560e+05
# std                              NaN  2.458937e+04  2.459732e+04
#
#                 Low         Close        Volume
# count  7.039184e+06  7.039184e+06  7.039184e+06
# mean   1.773337e+04  1.774058e+04  5.283990e+00
# min    3.800000e+00  3.800000e+00  0.000000e+00
# 25%    4.257800e+02  4.259900e+02  1.806778e-02
# 50%    6.642470e+03  6.646905e+03  4.643150e-01
# 75%    2.761200e+04  2.761700e+04  3.019063e+00
# max    1.087940e+05  1.090360e+05  5.853852e+03
# std    2.458120e+04  2.458933e+04  2.247701e+01
#
# Missende waarden per kolom:
# Timestamp    0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# dtype: int64
#
# Correlatie matrix:
#             Open      High       Low     Close    Volume
# Open    1.000000  1.000000  1.000000  0.999999 -0.089246
# High    1.000000  1.000000  0.999999  1.000000 -0.089177
# Low     1.000000  0.999999  1.000000  1.000000 -0.089328
# Close   0.999999  1.000000  1.000000  1.000000 -0.089252
# Volume -0.089246 -0.089177 -0.089328 -0.089252  1.000000
# Outliers in Open:
# Aantal outliers: 347475
# Percentage outliers: 4.94%
# Lower bound: -40360.53
# Upper bound: 68403.51
# Outliers in High:
# Aantal outliers: 347363
# Percentage outliers: 4.93%
# Lower bound: -40370.83
# Upper bound: 68420.90
# Outliers in Low:
# Aantal outliers: 347384
# Percentage outliers: 4.94%
# Lower bound: -40353.55
# Upper bound: 68391.33
# Outliers in Close:
# Aantal outliers: 347504
# Percentage outliers: 4.94%
# Lower bound: -40360.53
# Upper bound: 68403.51
# Outliers in Volume:
# Aantal outliers: 985716
# Percentage outliers: 14.00%
# Lower bound: -4.48
# Upper bound: 7.52
# Samenvatting van de dataset:
# Aantal rijen: 7039184
# Tijdsperiode: van 2012-01-01 10:01:00 tot 2025-05-21 13:04:00
#
# Prijs statistieken:
# Hoogste prijs ooit: $109,356.00
# Laagste prijs ooit: $3.80
# Gemiddelde prijs: $17,740.58
# Mediaan prijs: $6,646.90

# %% [markdown]
# # Fear & Greed index data Inladen en Verkennen

# %%
import requests
import pandas as pd
from datetime import datetime
import time

def load_fear_greed_data(limit=0):
    """
    Load Fear & Greed Index data from the API
    Args:
        limit (int): Number of results to return. Use 0 for all available data
    Returns:
        DataFrame with Fear & Greed Index data
    """
    # API endpoint
    url = f"https://api.alternative.me/fng/?limit={limit}"
    
    try:
        # Make API request
        response = requests.get(url)
        response.raise_for_status()
        
        # Parse JSON response
        data = response.json()
        
        # Extract the data points
        data_points = data['data']
        
        # Convert to DataFrame
        df_fear_greed = pd.DataFrame(data_points)
        
        # Convert timestamp to datetime
        df_fear_greed['date'] = pd.to_datetime(df_fear_greed['timestamp'].astype(int), unit='s')
        
        # Convert value to numeric
        df_fear_greed['value'] = df_fear_greed['value'].astype(int)
        
        # Reorder columns
        df_fear_greed = df_fear_greed[['date', 'value', 'value_classification']]
        
        # Sort by date
        df_fear_greed = df_fear_greed.sort_values('date')
        
        return df_fear_greed
        
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

if __name__ == "__main__":
    # Load all available data
    df_fear_greed = load_fear_greed_data(limit=0)
    
    if df_fear_greed is not None:
        # Save to CSV
        df_fear_greed.to_csv('fear_greed_data.csv', index=False)
        print("Data successfully saved to fear_greed_data.csv")
        print("\nFirst few rows of the data:")
        print(df_fear_greed.head())
# Out:
# Data successfully saved to fear_greed_data.csv
#
# First few rows of the data:
#            date  value value_classification
# 2662 2018-02-01     30                 Fear
# 2661 2018-02-02     15         Extreme Fear
# 2660 2018-02-03     40                 Fear
# 2659 2018-02-04     24         Extreme Fear
# 2658 2018-02-05     11         Extreme Fear

# %%
# Toon basis informatie over de dataset
print("Dataset Info:")
print("-" * 50)
print(df_fear_greed.info())
print("\n")

# Toon basis statistieken
print("Basic Statistics:")
print("-" * 50)
print(df_fear_greed.describe())
print("\n")

# Toon waarde tellingen voor value_classification
print("Value Classification Distribution:")
print("-" * 50)
print(df_fear_greed['value_classification'].value_counts())
print("\n")

# Controleer op ontbrekende waarden
print("Missing Values:")
print("-" * 50)
print(df_fear_greed.isnull().sum())
print("\n")

# Toon datum bereik
print("Date Range:")
print("-" * 50)
print(f"Start Date: {df_fear_greed['date'].min()}")
print(f"End Date: {df_fear_greed['date'].max()}")
print(f"Total Days: {len(df_fear_greed)}")
print("\n")

# Toon waarde distributie statistieken
print("Fear & Greed Index Distribution:")
print("-" * 50)
print("Value ranges:")
print("Extreme Fear (0-25):", len(df_fear_greed[df_fear_greed['value'] <= 25]))
print("Fear (26-45):", len(df_fear_greed[(df_fear_greed['value'] > 25) & (df_fear_greed['value'] <= 45)]))
print("Neutral (46-55):", len(df_fear_greed[(df_fear_greed['value'] > 45) & (df_fear_greed['value'] <= 55)]))
print("Greed (56-75):", len(df_fear_greed[(df_fear_greed['value'] > 55) & (df_fear_greed['value'] <= 75)]))
print("Extreme Greed (76-100):", len(df_fear_greed[df_fear_greed['value'] > 75]))

# Maak visualisatie van waarde classificatie distributie
plt.figure(figsize=(12, 6))

# Maak taartdiagram
value_counts = df_fear_greed['value_classification'].value_counts()
colors = ['#ff9999', '#ffd700', '#90ee90', '#66b3ff', '#c2c2f0']
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', colors=colors)
plt.title('Distribution of Fear & Greed Classifications')

# Voeg legenda toe
plt.legend(value_counts.index, title="Classifications", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.show()

# Maak tijdreeks visualisatie met kleur-gecodeerde classificaties
plt.figure(figsize=(15, 8))

# Maak scatter plot met kleurcodering
colors = {'Extreme Fear': 'red', 'Fear': 'orange', 'Neutral': 'yellow', 
          'Greed': 'lightgreen', 'Extreme Greed': 'darkgreen'}

for classification in colors:
    mask = df_fear_greed['value_classification'] == classification
    plt.scatter(df_fear_greed[mask]['date'], df_fear_greed[mask]['value'], 
                c=colors[classification], label=classification, alpha=0.6)

plt.title('Fear & Greed Index Values Over Time by Classification')
plt.xlabel('Date')
plt.ylabel('Fear & Greed Index Value')
plt.legend()
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Dataset Info:
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Index: 2663 entries, 2662 to 0
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  2663 non-null   datetime64[ns]
#  1   value                 2663 non-null   int64
#  2   value_classification  2663 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 83.2+ KB
# None
#
#
# Basic Statistics:
# --------------------------------------------------
#                                 date        value
# count                           2663  2663.000000
# mean   2021-09-26 23:55:07.998497792    47.134810
# min              2018-02-01 00:00:00     5.000000
# 25%              2019-12-01 12:00:00    28.000000
# 50%              2021-09-27 00:00:00    46.000000
# 75%              2023-07-24 12:00:00    66.000000
# max              2025-05-21 00:00:00    95.000000
# std                              NaN    21.830012
#
#
# Value Classification Distribution:
# --------------------------------------------------
# value_classification
# Fear             786
# Greed            698
# Extreme Fear     551
# Neutral          349
# Extreme Greed    279
# Name: count, dtype: int64
#
#
# Missing Values:
# --------------------------------------------------
# date                    0
# value                   0
# value_classification    0
# dtype: int64
#
#
# Date Range:
# --------------------------------------------------
# Start Date: 2018-02-01 00:00:00
# End Date: 2025-05-21 00:00:00
# Total Days: 2663
#
#
# Fear & Greed Index Distribution:
# --------------------------------------------------
# Value ranges:
# Extreme Fear (0-25): 551
# Fear (26-45): 761
# Neutral (46-55): 412
# Greed (56-75): 660
# Extreme Greed (76-100): 279

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\boris\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\boris\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\boris\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\boris\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Stel de stijl in
plt.style.use('default') 
sns.set_theme() 

# Maak de grafiek
plt.figure(figsize=(15, 8))
plt.plot(df_fear_greed['date'], df_fear_greed['value'], linewidth=2)

# Voeg horizontale lijnen toe voor de sentiment niveaus
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.axhline(y=25, color='r', linestyle='--', alpha=0.3)
plt.axhline(y=50, color='y', linestyle='--', alpha=0.3)
plt.axhline(y=75, color='g', linestyle='--', alpha=0.3)
plt.axhline(y=100, color='g', linestyle='--', alpha=0.3)

# Voeg labels toe
plt.title('Crypto Fear & Greed Index Over Time', fontsize=14, pad=20)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Fear & Greed Index', fontsize=12)

# Voeg sentiment labels toe
plt.text(df_fear_greed['date'].max(), 0, 'Extreme Fear', verticalalignment='bottom')
plt.text(df_fear_greed['date'].max(), 25, 'Fear', verticalalignment='bottom')
plt.text(df_fear_greed['date'].max(), 50, 'Neutral', verticalalignment='bottom')
plt.text(df_fear_greed['date'].max(), 75, 'Greed', verticalalignment='bottom')
plt.text(df_fear_greed['date'].max(), 100, 'Extreme Greed', verticalalignment='bottom')

# Rotate x-axis labels voor betere leesbaarheid
plt.xticks(rotation=45)

# Voeg grid toe
plt.grid(True, alpha=0.3)

# Pas de layout aan
plt.tight_layout()

# Toon de grafiek
plt.show()

# %%
# Print algemene informatie over de dataset
print("Dataset informatie:")
print(df_fear_greed.info())

# Print beschrijvende statistieken
print("\nBeschrijvende statistieken:")
print(df_fear_greed.describe())

# Print unieke waarden per kolom
print("\nUnieke waarden per kolom:")
for column in df_fear_greed.columns:
    print(f"\n{column}:")
    print(df_fear_greed[column].nunique())

# Correlaties tussen numerieke kolommen
print("\nCorrelatiematrix:")
numeric_columns = df_fear_greed.select_dtypes(include=['float64', 'int64']).columns
correlation_matrix = df_fear_greed[numeric_columns].corr()
print(correlation_matrix)

# Visualiseer de distributie van de Fear & Greed waarden
plt.figure(figsize=(10, 6))
sns.histplot(data=df_fear_greed, x='value', bins=30)
plt.title('Distributie van Fear & Greed Index Waarden')
plt.xlabel('Fear & Greed Index')
plt.ylabel('Aantal observaties')
plt.show()

# Boxplot voor outlier detectie
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_fear_greed, y='value')
plt.title('Boxplot van Fear & Greed Index Waarden')
plt.ylabel('Fear & Greed Index')
plt.show()

# Print samenvattende statistieken per jaar
print("\nJaarlijkse statistieken:")
yearly_stats = df_fear_greed.groupby(df_fear_greed['date'].dt.year)['value'].describe()
print(yearly_stats)
# Out:
# Dataset informatie:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2663 entries, 2662 to 0
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  2663 non-null   datetime64[ns]
#  1   value                 2663 non-null   int64
#  2   value_classification  2663 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 83.2+ KB
# None
#
# Beschrijvende statistieken:
#                                 date        value
# count                           2663  2663.000000
# mean   2021-09-26 23:55:07.998497792    47.134810
# min              2018-02-01 00:00:00     5.000000
# 25%              2019-12-01 12:00:00    28.000000
# 50%              2021-09-27 00:00:00    46.000000
# 75%              2023-07-24 12:00:00    66.000000
# max              2025-05-21 00:00:00    95.000000
# std                              NaN    21.830012
#
# Unieke waarden per kolom:
#
# date:
# 2663
#
# value:
# 90
#
# value_classification:
# 5
#
# Correlatiematrix:
#        value
# value    1.0
# Jaarlijkse statistieken:
#       count       mean        std   min   25%   50%   75%   max
# date
# 2018  331.0  30.848943  13.555995   8.0  20.0  28.0  39.0  74.0
# 2019  365.0  45.120548  18.136289   5.0  32.0  41.0  61.0  95.0
# 2020  366.0  52.852459  23.670804   8.0  40.0  49.0  75.0  95.0
# 2021  365.0  54.860274  25.055426  10.0  27.0  65.0  75.0  95.0
# 2022  365.0  25.317808  10.135502   6.0  20.0  24.0  29.0  60.0
# 2023  365.0  54.704110  10.972749  25.0  49.0  53.0  63.0  75.0
# 2024  365.0  63.309589  17.361225  17.0  52.0  71.0  75.0  94.0
# 2025  141.0  50.751773  18.754868  10.0  34.0  49.0  70.0  84.0

# %% [markdown]
# # Fear & Greed data Cleanen en Prepereren

# %%
# Print de eerste paar rijen van de datetime kolom
print("First few timestamps in df_fear_greed:")
print(df_fear_greed['date'].head())

# Print informatie over de datetime kolom
print("\nDatetime info:")
print(df_fear_greed['date'].dtype)

# Print unieke timestamps per dag om te zien hoe vaak per dag wordt gemeten
print("\nUnique timestamps per day:")
print(df_fear_greed['date'].dt.date.value_counts().sort_index().head())
# Out:
# First few timestamps in df_fear_greed:
# 2662   2018-02-01
# 2661   2018-02-02
# 2660   2018-02-03
# 2659   2018-02-04
# 2658   2018-02-05
# Name: date, dtype: datetime64[ns]
#
# Datetime info:
# datetime64[ns]
#
# Unique timestamps per day:
# date
# 2018-02-01    1
# 2018-02-02    1
# 2018-02-03    1
# 2018-02-04    1
# 2018-02-05    1
# Name: count, dtype: int64

# %%
# Vind de vroegste datum in de dataset
earliest_date = df_fear_greed['date'].min()
print(f"De vroegste datum in de Fear & Greed dataset is: {earliest_date}")
# Out:
# De vroegste datum in de Fear & Greed dataset is: 2018-02-01 00:00:00

# %%
# Converteer date kolom naar datetime formaat 
df_fear_greed['date'] = pd.to_datetime(df_fear_greed['date'])

# Voeg Timestamp kolom toe met alleen de datum
df_fear_greed['Timestamp'] = df_fear_greed['date'].dt.date

# Converteer Timestamp naar datetime formaat om overeen te komen met andere dataframes
df_fear_greed['Timestamp'] = pd.to_datetime(df_fear_greed['Timestamp'])

# Verifieer de nieuwe kolom
print("\nFirst few rows with new Timestamp column:")
print(df_fear_greed.head())
# Out:
# First few rows with new Timestamp column:
#            date  value value_classification  Timestamp
# 2662 2018-02-01     30                 Fear 2018-02-01
# 2661 2018-02-02     15         Extreme Fear 2018-02-02
# 2660 2018-02-03     40                 Fear 2018-02-03
# 2659 2018-02-04     24         Extreme Fear 2018-02-04
# 2658 2018-02-05     11         Extreme Fear 2018-02-05

# %%
# Verwijder de date kolom en herorden kolommen om Timestamp eerst te hebben
df_fear_greed = df_fear_greed.drop('date', axis=1)
df_fear_greed = df_fear_greed[['Timestamp', 'value', 'value_classification']]

# Toon de eerste paar rijen om de wijzigingen te verifiëren
print("Updated fear & greed dataframe:")
print(df_fear_greed.head())
# Out:
# Updated fear & greed dataframe:
#       Timestamp  value value_classification
# 2662 2018-02-01     30                 Fear
# 2661 2018-02-02     15         Extreme Fear
# 2660 2018-02-03     40                 Fear
# 2659 2018-02-04     24         Extreme Fear
# 2658 2018-02-05     11         Extreme Fear

# %% [markdown]
# # BTC Historic Price HOLC Data Cleanen en Prepareren

# %%
# Resample naar dagelijkse candlestick-structuur
# Eerst Timestamp als index zetten
df_holc = df_holc.set_index('Timestamp')

# Nu resamplen naar dagelijkse data
df_daily = df_holc.resample('D').agg({
    'Open': 'first',
    'High': 'max',
    'Low': 'min',
    'Close': 'last',
    'Volume': 'sum'
}).reset_index()

# Controleer resultaat
print(df_daily.head())
# Out:
#    Timestamp  Open  High   Low  Close      Volume
# 0 2012-01-01  4.58  4.84  4.58   4.84   10.000000
# 1 2012-01-02  4.84  5.00  4.84   5.00   10.100000
# 2 2012-01-03  5.00  5.32  5.00   5.29  107.085281
# 3 2012-01-04  5.29  5.57  4.93   5.57  107.233260
# 4 2012-01-05  5.57  6.46  5.57   6.42   70.328742

# %%
df_daily
# Out:
#       Timestamp       Open       High        Low      Close       Volume
# 0    2012-01-01       4.58       4.84       4.58       4.84    10.000000
# 1    2012-01-02       4.84       5.00       4.84       5.00    10.100000
# 2    2012-01-03       5.00       5.32       5.00       5.29   107.085281
# 3    2012-01-04       5.29       5.57       4.93       5.57   107.233260
# 4    2012-01-05       5.57       6.46       5.57       6.42    70.328742
# ...         ...        ...        ...        ...        ...          ...
# 4885 2025-05-17  103503.00  103720.00  102668.00  103153.00   459.809889
# 4886 2025-05-18  103172.00  106635.00  103149.00  106520.00   905.179396
# 4887 2025-05-19  106520.00  107115.00  102126.00  105622.00  1677.932123
# 4888 2025-05-20  105630.00  107340.00  104232.00  106855.00  1462.424853
# 4889 2025-05-21  106891.00  108035.00  106141.00  106600.00   541.551602
#
# [4890 rows x 6 columns]

# %%
# Rename df_daily to df_holc_daily
df_holc_daily = df_daily.copy()

# %%
# Calculate 7-day and 30-day moving averages of closing prices
df_holc_daily['MA7'] = df_holc_daily['Close'].rolling(window=7).mean()
df_holc_daily['MA30'] = df_holc_daily['Close'].rolling(window=30).mean()

# %%
# Filter HOLC data to keep only records from 2018-02-01 onwards
df_holc_daily = df_holc_daily[df_holc_daily['Timestamp'] >= '2018-02-01']

# Reset index after filtering
df_holc_daily.reset_index(drop=True, inplace=True)

print("HOLC data after filtering to 2018-02-01 onwards:")
print(df_holc_daily.head())
# Out:
# HOLC data after filtering to 2018-02-01 onwards:
#    Timestamp     Open      High      Low    Close        Volume           MA7  \
# 0 2018-02-01  9974.91  10187.56  8820.96  8970.00  20517.085284  10602.648571
# 1 2018-02-02  8970.00   9234.10  7625.25  8580.00  47828.982222  10250.204286
# 2 2018-02-03  8551.19   9443.96  8170.71  9386.72  17968.929040   9956.165714
# 3 2018-02-04  9391.30   9491.20  8189.32  8301.65  14407.720751   9484.974286
# 4 2018-02-05  8301.65   8416.03  6865.66  6877.61  37314.242065   8862.992857
#
#            MA30
# 0  12637.540000
# 1  12429.063333
# 2  12249.274000
# 3  11980.415000
# 4  11650.574333

# %%
df_holc_daily
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2662 2025-05-17  103503.00  103720.00  102668.00  103153.00    459.809889
# 2663 2025-05-18  103172.00  106635.00  103149.00  106520.00    905.179396
# 2664 2025-05-19  106520.00  107115.00  102126.00  105622.00   1677.932123
# 2665 2025-05-20  105630.00  107340.00  104232.00  106855.00   1462.424853
# 2666 2025-05-21  106891.00  108035.00  106141.00  106600.00    541.551602
#
#                 MA7          MA30
# 0      10602.648571  12637.540000
# 1      10250.204286  12429.063333
# 2       9956.165714  12249.274000
# 3       9484.974286  11980.415000
# 4       8862.992857  11650.574333
# ...             ...           ...
# 2662  103577.571429  96617.133333
# 2663  103919.142857  97352.200000
# 2664  104322.857143  98037.300000
# 2665  104711.428571  98759.200000
# 2666  105149.857143  99395.700000
#
# [2667 rows x 8 columns]

# %% [markdown]
# # Samenvoegen van de BTC Price Historic dataset en Fear & Greed index dataset

# %%
# Zorg dat alle Timestamp-kolommen datetime64[ns] zijn, zonder tijdzone
df_holc_daily['Timestamp'] = pd.to_datetime(df_holc_daily['Timestamp']).dt.tz_localize(None)
df_fear_greed['Timestamp'] = pd.to_datetime(df_fear_greed['Timestamp']).dt.tz_localize(None)

# %%
# Merge alle datasets op Timestamp
df_combined = df_holc_daily.merge(df_fear_greed[['Timestamp', 'value', 'value_classification']], on='Timestamp', how='left')

# %%
df_combined
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2660 2025-05-15  103514.00  104184.00  101442.00  103793.00   1339.093301
# 2661 2025-05-16  103800.00  104570.00  103137.00  103506.00    994.760377
# 2662 2025-05-17  103503.00  103720.00  102668.00  103153.00    459.809889
# 2663 2025-05-18  103172.00  106635.00  103149.00  106520.00    905.179396
# 2664 2025-05-19  106520.00  107115.00  105224.00  105323.00    182.863484
#
#                 MA7          MA30  value value_classification
# 0      10602.648571  12637.540000   30.0                 Fear
# 1      10250.204286  12429.063333   15.0         Extreme Fear
# 2       9956.165714  12249.274000   40.0                 Fear
# 3       9484.974286  11980.415000   24.0         Extreme Fear
# 4       8862.992857  11650.574333   11.0         Extreme Fear
# ...             ...           ...    ...                  ...
# 2660  103740.571429  95361.833333   70.0                Greed
# 2661  103814.142857  96010.500000   71.0                Greed
# 2662  103577.571429  96617.133333   74.0                Greed
# 2663  103919.142857  97352.200000   74.0                Greed
# 2664  104280.142857  98027.333333   74.0                Greed
#
# [2665 rows x 10 columns]

# %%
# This means the last date where none of the columns from any dataset are NaN
last_complete_date = df_combined.dropna().iloc[-1]['Timestamp']
print(f"Last date with complete data from all datasets: {last_complete_date}")
# Out:
# Last date with complete data from all datasets: 2025-05-19 00:00:00

# %%
# Filter df_combined to keep only rows up to 2025-05-12
df_combined = df_combined[df_combined['Timestamp'] <= '2025-05-12']

# %%
df_combined = df_combined.reindex(columns=['Timestamp'] + [col for col in df_combined.columns if col != 'Timestamp'])
df_combined
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2653 2025-05-08   97059.00  104159.00   96907.00  103261.00   2303.463144
# 2654 2025-05-09  103234.00  104332.00  102350.00  102991.00   1336.085909
# 2655 2025-05-10  102992.00  104985.00  102845.00  104809.00    624.265066
# 2656 2025-05-11  104809.00  104958.00  103369.00  104129.00    718.368323
# 2657 2025-05-12  104138.00  105706.00  100764.00  102796.00   1914.472054
#
#                 MA7          MA30  value value_classification
# 0      10602.648571  12637.540000   30.0                 Fear
# 1      10250.204286  12429.063333   15.0         Extreme Fear
# 2       9956.165714  12249.274000   40.0                 Fear
# 3       9484.974286  11980.415000   24.0         Extreme Fear
# 4       8862.992857  11650.574333   11.0         Extreme Fear
# ...             ...           ...    ...                  ...
# 2653   97001.571429  90581.600000   65.0                Greed
# 2654   97868.142857  91261.466667   73.0                Greed
# 2655   99138.571429  92103.666667   70.0                Greed
# 2656  100540.428571  92795.166667   70.0                Greed
# 2657  101693.428571  93379.233333   70.0                Greed
#
# [2658 rows x 10 columns]

# %% [markdown]
# # Bear & Bull Markets Features toevoegen:

# %%
import numpy as np

df_combined = df_combined.copy() 

df_combined['SMA_50'] = df_combined['Close'].rolling(window=50).mean()
df_combined['SMA_200'] = df_combined['Close'].rolling(window=200).mean()
df_combined['market_regime'] = np.where(df_combined['SMA_50'] > df_combined['SMA_200'], 'Bull', 'Bear')

# %%
df_combined = df_combined.drop(['SMA_50', 'SMA_200'], axis=1)

# %%
df_combined
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2653 2025-05-08   97059.00  104159.00   96907.00  103261.00   2303.463144
# 2654 2025-05-09  103234.00  104332.00  102350.00  102991.00   1336.085909
# 2655 2025-05-10  102992.00  104985.00  102845.00  104809.00    624.265066
# 2656 2025-05-11  104809.00  104958.00  103369.00  104129.00    718.368323
# 2657 2025-05-12  104138.00  105706.00  100764.00  102796.00   1914.472054
#
#                 MA7          MA30  value value_classification market_regime
# 0      10602.648571  12637.540000   30.0                 Fear          Bear
# 1      10250.204286  12429.063333   15.0         Extreme Fear          Bear
# 2       9956.165714  12249.274000   40.0                 Fear          Bear
# 3       9484.974286  11980.415000   24.0         Extreme Fear          Bear
# 4       8862.992857  11650.574333   11.0         Extreme Fear          Bear
# ...             ...           ...    ...                  ...           ...
# 2653   97001.571429  90581.600000   65.0                Greed          Bear
# 2654   97868.142857  91261.466667   73.0                Greed          Bear
# 2655   99138.571429  92103.666667   70.0                Greed          Bear
# 2656  100540.428571  92795.166667   70.0                Greed          Bear
# 2657  101693.428571  93379.233333   70.0                Greed          Bear
#
# [2658 rows x 11 columns]

# %%
# Group consecutive periods with the same market regime
regime_changes = df_combined['market_regime'].ne(df_combined['market_regime'].shift()).cumsum()
regime_periods = df_combined.groupby(regime_changes).agg({
    'Timestamp': ['first', 'last'],
    'market_regime': 'first'
}).reset_index(drop=True)


regime_periods.columns = ['Start Date', 'End Date', 'Market Regime']

# Calculate duration in days for each period
regime_periods['Duration (days)'] = (pd.to_datetime(regime_periods['End Date']) - 
                                   pd.to_datetime(regime_periods['Start Date'])).dt.days

print("\nMarket Regime Periods:")
print(regime_periods.to_string(index=False))

# Calculate summary statistics
total_days = regime_periods['Duration (days)'].sum()
bull_days = regime_periods[regime_periods['Market Regime'] == 'Bull']['Duration (days)'].sum()
bear_days = regime_periods[regime_periods['Market Regime'] == 'Bear']['Duration (days)'].sum()

print(f"\nSummary Statistics:")
print(f"Total days analyzed: {total_days}")
print(f"Days in Bull market: {bull_days} ({(bull_days/total_days*100):.1f}%)")
print(f"Days in Bear market: {bear_days} ({(bear_days/total_days*100):.1f}%)")
# Out:
# Market Regime Periods:
# Start Date   End Date Market Regime  Duration (days)
# 2018-02-01 2019-04-22          Bear              445
# 2019-04-23 2019-10-25          Bull              185
# 2019-10-26 2020-02-18          Bear              115
# 2020-02-19 2020-03-25          Bull               35
# 2020-03-26 2020-05-20          Bear               55
# 2020-05-21 2021-06-18          Bull              393
# 2021-06-19 2021-09-14          Bear               87
# 2021-09-15 2022-01-14          Bull              121
# 2022-01-15 2023-02-06          Bear              387
# 2023-02-07 2023-09-11          Bull              216
# 2023-09-12 2023-10-29          Bear               47
# 2023-10-30 2024-08-09          Bull              284
# 2024-08-10 2024-10-26          Bear               77
# 2024-10-27 2025-04-06          Bull              161
# 2025-04-07 2025-05-12          Bear               35
#
# Summary Statistics:
# Total days analyzed: 2643
# Days in Bull market: 1395 (52.8%)
# Days in Bear market: 1248 (47.2%)

# %%
# Convert market_regime to binary values (1 for Bull, 0 for Bear)
df_combined['market_regime'] = (df_combined['market_regime'] == 'Bull').astype(int)
df_combined
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2653 2025-05-08   97059.00  104159.00   96907.00  103261.00   2303.463144
# 2654 2025-05-09  103234.00  104332.00  102350.00  102991.00   1336.085909
# 2655 2025-05-10  102992.00  104985.00  102845.00  104809.00    624.265066
# 2656 2025-05-11  104809.00  104958.00  103369.00  104129.00    718.368323
# 2657 2025-05-12  104138.00  105706.00  100764.00  102796.00   1914.472054
#
#                 MA7          MA30  value value_classification  market_regime
# 0      10602.648571  12637.540000   30.0                 Fear              0
# 1      10250.204286  12429.063333   15.0         Extreme Fear              0
# 2       9956.165714  12249.274000   40.0                 Fear              0
# 3       9484.974286  11980.415000   24.0         Extreme Fear              0
# 4       8862.992857  11650.574333   11.0         Extreme Fear              0
# ...             ...           ...    ...                  ...            ...
# 2653   97001.571429  90581.600000   65.0                Greed              0
# 2654   97868.142857  91261.466667   73.0                Greed              0
# 2655   99138.571429  92103.666667   70.0                Greed              0
# 2656  100540.428571  92795.166667   70.0                Greed              0
# 2657  101693.428571  93379.233333   70.0                Greed              0
#
# [2658 rows x 11 columns]

# %%
# Rename 'value' column to 'fear_greed_index' and drop 'value_classification' column
df_combined = df_combined.rename(columns={'value': 'fear_greed_index'})
df_combined = df_combined.drop('value_classification', axis=1)
df_combined
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2653 2025-05-08   97059.00  104159.00   96907.00  103261.00   2303.463144
# 2654 2025-05-09  103234.00  104332.00  102350.00  102991.00   1336.085909
# 2655 2025-05-10  102992.00  104985.00  102845.00  104809.00    624.265066
# 2656 2025-05-11  104809.00  104958.00  103369.00  104129.00    718.368323
# 2657 2025-05-12  104138.00  105706.00  100764.00  102796.00   1914.472054
#
#                 MA7          MA30  fear_greed_index  market_regime
# 0      10602.648571  12637.540000              30.0              0
# 1      10250.204286  12429.063333              15.0              0
# 2       9956.165714  12249.274000              40.0              0
# 3       9484.974286  11980.415000              24.0              0
# 4       8862.992857  11650.574333              11.0              0
# ...             ...           ...               ...            ...
# 2653   97001.571429  90581.600000              65.0              0
# 2654   97868.142857  91261.466667              73.0              0
# 2655   99138.571429  92103.666667              70.0              0
# 2656  100540.428571  92795.166667              70.0              0
# 2657  101693.428571  93379.233333              70.0              0
#
# [2658 rows x 10 columns]

# %% [markdown]
# # Target Value (Y) Toevoegen
#
# De Volgende klasse zijn gedefineert om ongeveer een van elke klasse evenveel voorbeelden te hebben (gebalanceerde target value kolom):
#
# - UP = 1
# - Neutraal = 0 (+-1% daling/stijging)
# - Down = -1

# %%
# Bereken procentuele verandering naar de volgende dag
df_combined['next_close'] = df_combined['Close'].shift(-1)
df_combined['return_pct'] = (df_combined['next_close'] - df_combined['Close']) / df_combined['Close']

# Stel label vast: 
# -1 = sterke daling (meer dan -1%)
# 0 = neutraal (tussen -1% en +1% verandering)
# 1 = sterke stijging (meer dan +1%)
def classify_movement(pct_change, threshold=0.01):  # 1%
    if pct_change > threshold:
        return 1     # sterke stijging (>1%)
    elif pct_change < -threshold:
        return -1    # sterke daling (<-1%) 
    else:
        return 0     # neutraal (-1% tot +1%)

df_combined['y'] = df_combined['return_pct'].apply(classify_movement)

print(df_combined['y'].value_counts())
# Out:
# y
#  0    979
#  1    882
# -1    797
# Name: count, dtype: int64

# %%
# Print total number of rows in dataframe
print(f"Total number of rows in dataframe: {len(df_combined)}")
# Print total number of values in y column
print(f"Total number of values in y column: {df_combined['y'].count()}")
# Out:
# Total number of rows in dataframe: 2658
# Total number of values in y column: 2658

# %% [markdown]
# # Vensters maken van 30 dagen:
# Ik gebruik de afgelopen 30 dagen om 1 dag vooruit te voorspellen. Ik maak dus vensters van 30 dagen waarin de target value de prijsbeweging van de volgende dag is.

# %%
import numpy as np

window_size = 30

feature_columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'MA7', 'MA30', 'fear_greed_index', 'market_regime']

X = []
y = []

for i in range(len(df_combined) - window_size - 1):
    X.append(df_combined[feature_columns].iloc[i:i+window_size].values)
    
    price_today = df_combined['Close'].iloc[i + window_size - 1]
    price_tomorrow = df_combined['Close'].iloc[i + window_size]
    
    # Bereken procentuele verandering
    perc_change = (price_tomorrow - price_today) / price_today

    # Classificatie op basis van 1% drempel
    if perc_change > 0.01:
        label = 1  # Up (>1% stijging)
    elif perc_change < -0.01:
        label = -1  # Down (>1% daling)
    else:
        label = 0  # Neutraal (tussen -1% en +1%)
    y.append(label)

X = np.array(X)
y = np.array(y)

print(f'X shape: {X.shape}')  # (aantal samples, 30, aantal features)
print(f'y shape: {y.shape}')  # (aantal samples,)
# Out:
# X shape: (2627, 30, 9)
# y shape: (2627,)

# %% [markdown]
# # Data splitsen
#
# Time based split (70-15-15)

# %%
# Bepaal totale lengte
n_total = X.shape[0]

# Bepaal de indices voor de splitsing (70% train, 15% val, 15% test)
train_end = int(n_total * 0.7)
val_end = int(n_total * 0.85)

# Splits X en y op basis van tijdsvolgorde
X_train, y_train = X[:train_end], y[:train_end]
X_val, y_val = X[train_end:val_end], y[train_end:val_end]
X_test, y_test = X[val_end:], y[val_end:]

# Print shapes om te checken
print("Train:", X_train.shape, y_train.shape)
print("Validation:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# Train: (1838, 30, 9) (1838,)
# Validation: (394, 30, 9) (394,)
# Test: (395, 30, 9) (395,)

# %%
# Bereken de verdeling van market regimes in de trainingsdata
# -1 = dalen, 0 = neutraal, 1 = stijgen
unique_values, counts = np.unique(y_train, return_counts=True)

# Bereken percentages
total = len(y_train)
percentages = (counts / total) * 100

# Print resultaten
print("\nVerdeling klasen in y_train:")
print(f"Dalen (-1): {counts[0]} samples ({percentages[0]:.1f}%)")
print(f"Neutraal (0): {counts[1]} samples ({percentages[1]:.1f}%)")
print(f"Stijgen (1): {counts[2]} samples ({percentages[2]:.1f}%)")
# Out:
# Verdeling klasen in y_train:
# Dalen (-1): 575 samples (31.3%)
# Neutraal (0): 629 samples (34.2%)
# Stijgen (1): 634 samples (34.5%)

# %%
# Bereken de verdeling van market regimes in X_train
# Flatten eerst de array om alle market regime waarden te tellen
all_regimes = X_train[:, :, -1].flatten()
unique_regimes, regime_counts = np.unique(all_regimes, return_counts=True)

# Bereken percentages van totaal aantal regimes
total_regimes = len(all_regimes)
regime_percentages = (regime_counts / total_regimes) * 100

# Print resultaten
print("\nVerdeling market regimes in X_train:")
print(f"Bear (0): {regime_counts[0]} samples ({regime_percentages[0]:.1f}%)")
print(f"Bull (1): {regime_counts[1]} samples ({regime_percentages[1]:.1f}%)")
# Out:
# Verdeling market regimes in X_train:
# Bear (0): 32385 samples (58.7%)
# Bull (1): 22755 samples (41.3%)

# %% [markdown]
# # Verantwoording Iteraties staat in rapport en logboek

# %% [markdown]
# ## Baseline Model trainen en optimalisatie (XGBoost)

# %%
# Flatten de input: (samples, 30, n_features) → (samples, 30 * n_features)
X_train_flat = X_train.reshape((X_train.shape[0], -1))
X_val_flat = X_val.reshape((X_val.shape[0], -1))
X_test_flat = X_test.reshape((X_test.shape[0], -1))

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# Initialize XGBoost classifier
model = XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    eval_metric='mlogloss',
    use_label_encoder=False,
    random_state=42,
)

# Convert labels from [-1,0,1] to [0,1,2]
y_train_adj = y_train + 1
y_val_adj = y_val + 1

# Train model with evaluation set
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]
model.fit(
    X_train_flat, 
    y_train_adj,
    eval_set=eval_set,
    verbose=True
)

# Get evaluation results
results = model.evals_result()

# Plot learning curves
plt.figure(figsize=(10,6))
plt.plot(results['validation_0']['mlogloss'], label='Train')
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('XGBoost Learning Curves')
plt.legend()
plt.grid(True)
plt.show()

# Make predictions on validation set
y_val_pred = model.predict(X_val_flat)

# Print classification report
print("\nClassification Report on Validation Set:")
print(classification_report(y_val_adj, y_val_pred))
# Out:
# [0]	validation_0-mlogloss:1.01582	validation_1-mlogloss:1.08087
# [1]	validation_0-mlogloss:0.93874	validation_1-mlogloss:1.08013
# c:\Users\boris\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [01:05:53] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [2]	validation_0-mlogloss:0.88039	validation_1-mlogloss:1.08444
# [3]	validation_0-mlogloss:0.82644	validation_1-mlogloss:1.08271
# [4]	validation_0-mlogloss:0.79510	validation_1-mlogloss:1.08455
# [5]	validation_0-mlogloss:0.75848	validation_1-mlogloss:1.07217
# [6]	validation_0-mlogloss:0.72528	validation_1-mlogloss:1.06444
# [7]	validation_0-mlogloss:0.70108	validation_1-mlogloss:1.06529
# [8]	validation_0-mlogloss:0.66928	validation_1-mlogloss:1.06341
# [9]	validation_0-mlogloss:0.64734	validation_1-mlogloss:1.06596
# [10]	validation_0-mlogloss:0.62442	validation_1-mlogloss:1.07285
# [11]	validation_0-mlogloss:0.60766	validation_1-mlogloss:1.07081
# [12]	validation_0-mlogloss:0.59732	validation_1-mlogloss:1.07316
# [13]	validation_0-mlogloss:0.58065	validation_1-mlogloss:1.07744
# [14]	validation_0-mlogloss:0.56028	validation_1-mlogloss:1.08490
# [15]	validation_0-mlogloss:0.54351	validation_1-mlogloss:1.08964
# [16]	validation_0-mlogloss:0.52446	validation_1-mlogloss:1.09277
# [17]	validation_0-mlogloss:0.50879	validation_1-mlogloss:1.09482
# [18]	validation_0-mlogloss:0.48773	validation_1-mlogloss:1.09773
# [19]	validation_0-mlogloss:0.47180	validation_1-mlogloss:1.10058
# [20]	validation_0-mlogloss:0.45637	validation_1-mlogloss:1.10581
# [21]	validation_0-mlogloss:0.44655	validation_1-mlogloss:1.10972
# [22]	validation_0-mlogloss:0.42351	validation_1-mlogloss:1.11285
# [23]	validation_0-mlogloss:0.41296	validation_1-mlogloss:1.11721
# [24]	validation_0-mlogloss:0.39742	validation_1-mlogloss:1.11863
# [25]	validation_0-mlogloss:0.38210	validation_1-mlogloss:1.11604
# [26]	validation_0-mlogloss:0.36953	validation_1-mlogloss:1.11741
# [27]	validation_0-mlogloss:0.35772	validation_1-mlogloss:1.11747
# [28]	validation_0-mlogloss:0.34790	validation_1-mlogloss:1.11797
# [29]	validation_0-mlogloss:0.33446	validation_1-mlogloss:1.11452
# [30]	validation_0-mlogloss:0.32476	validation_1-mlogloss:1.11471
# [31]	validation_0-mlogloss:0.31487	validation_1-mlogloss:1.11489
# [32]	validation_0-mlogloss:0.30432	validation_1-mlogloss:1.11750
# [33]	validation_0-mlogloss:0.29361	validation_1-mlogloss:1.11910
# [34]	validation_0-mlogloss:0.28178	validation_1-mlogloss:1.11853
# [35]	validation_0-mlogloss:0.27221	validation_1-mlogloss:1.12176
# [36]	validation_0-mlogloss:0.26172	validation_1-mlogloss:1.12623
# [37]	validation_0-mlogloss:0.25744	validation_1-mlogloss:1.12580
# [38]	validation_0-mlogloss:0.25287	validation_1-mlogloss:1.13275
# [39]	validation_0-mlogloss:0.24690	validation_1-mlogloss:1.13370
# [40]	validation_0-mlogloss:0.24041	validation_1-mlogloss:1.13612
# [41]	validation_0-mlogloss:0.23174	validation_1-mlogloss:1.13910
# [42]	validation_0-mlogloss:0.22534	validation_1-mlogloss:1.13746
# [43]	validation_0-mlogloss:0.21871	validation_1-mlogloss:1.13499
# [44]	validation_0-mlogloss:0.21334	validation_1-mlogloss:1.14189
# [45]	validation_0-mlogloss:0.20877	validation_1-mlogloss:1.14266
# [46]	validation_0-mlogloss:0.20429	validation_1-mlogloss:1.14487
# [47]	validation_0-mlogloss:0.19646	validation_1-mlogloss:1.14472
# [48]	validation_0-mlogloss:0.18966	validation_1-mlogloss:1.14215
# [49]	validation_0-mlogloss:0.18192	validation_1-mlogloss:1.14753
# [50]	validation_0-mlogloss:0.17746	validation_1-mlogloss:1.15514
# [51]	validation_0-mlogloss:0.17254	validation_1-mlogloss:1.15472
# [52]	validation_0-mlogloss:0.16653	validation_1-mlogloss:1.15464
# [53]	validation_0-mlogloss:0.16320	validation_1-mlogloss:1.15707
# [54]	validation_0-mlogloss:0.15838	validation_1-mlogloss:1.15756
# [55]	validation_0-mlogloss:0.15309	validation_1-mlogloss:1.15826
# [56]	validation_0-mlogloss:0.14817	validation_1-mlogloss:1.15945
# [57]	validation_0-mlogloss:0.14357	validation_1-mlogloss:1.16596
# [58]	validation_0-mlogloss:0.14060	validation_1-mlogloss:1.16767
# [59]	validation_0-mlogloss:0.13572	validation_1-mlogloss:1.17373
# [60]	validation_0-mlogloss:0.13161	validation_1-mlogloss:1.17744
# [61]	validation_0-mlogloss:0.12723	validation_1-mlogloss:1.17881
# [62]	validation_0-mlogloss:0.12267	validation_1-mlogloss:1.18779
# [63]	validation_0-mlogloss:0.11953	validation_1-mlogloss:1.19054
# [64]	validation_0-mlogloss:0.11580	validation_1-mlogloss:1.19343
# [65]	validation_0-mlogloss:0.11402	validation_1-mlogloss:1.19173
# [66]	validation_0-mlogloss:0.11135	validation_1-mlogloss:1.19496
# [67]	validation_0-mlogloss:0.10852	validation_1-mlogloss:1.19629
# [68]	validation_0-mlogloss:0.10566	validation_1-mlogloss:1.19641
# [69]	validation_0-mlogloss:0.10313	validation_1-mlogloss:1.19549
# [70]	validation_0-mlogloss:0.10099	validation_1-mlogloss:1.20181
# [71]	validation_0-mlogloss:0.09832	validation_1-mlogloss:1.20461
# [72]	validation_0-mlogloss:0.09614	validation_1-mlogloss:1.20425
# [73]	validation_0-mlogloss:0.09300	validation_1-mlogloss:1.20839
# [74]	validation_0-mlogloss:0.09087	validation_1-mlogloss:1.20681
# [75]	validation_0-mlogloss:0.08871	validation_1-mlogloss:1.21098
# [76]	validation_0-mlogloss:0.08697	validation_1-mlogloss:1.21180
# [77]	validation_0-mlogloss:0.08424	validation_1-mlogloss:1.21445
# [78]	validation_0-mlogloss:0.08215	validation_1-mlogloss:1.21799
# [79]	validation_0-mlogloss:0.08073	validation_1-mlogloss:1.21992
# [80]	validation_0-mlogloss:0.07904	validation_1-mlogloss:1.22243
# [81]	validation_0-mlogloss:0.07753	validation_1-mlogloss:1.22065
# [82]	validation_0-mlogloss:0.07602	validation_1-mlogloss:1.22174
# [83]	validation_0-mlogloss:0.07414	validation_1-mlogloss:1.22185
# [84]	validation_0-mlogloss:0.07194	validation_1-mlogloss:1.22502
# [85]	validation_0-mlogloss:0.06967	validation_1-mlogloss:1.22227
# [86]	validation_0-mlogloss:0.06794	validation_1-mlogloss:1.22147
# [87]	validation_0-mlogloss:0.06640	validation_1-mlogloss:1.22235
# [88]	validation_0-mlogloss:0.06489	validation_1-mlogloss:1.22629
# [89]	validation_0-mlogloss:0.06409	validation_1-mlogloss:1.22684
# [90]	validation_0-mlogloss:0.06278	validation_1-mlogloss:1.22593
# [91]	validation_0-mlogloss:0.06126	validation_1-mlogloss:1.22596
# [92]	validation_0-mlogloss:0.06017	validation_1-mlogloss:1.22602
# [93]	validation_0-mlogloss:0.05892	validation_1-mlogloss:1.22942
# [94]	validation_0-mlogloss:0.05789	validation_1-mlogloss:1.23489
# [95]	validation_0-mlogloss:0.05641	validation_1-mlogloss:1.23502
# [96]	validation_0-mlogloss:0.05526	validation_1-mlogloss:1.23522
# [97]	validation_0-mlogloss:0.05440	validation_1-mlogloss:1.23668
# [98]	validation_0-mlogloss:0.05304	validation_1-mlogloss:1.23511
# [99]	validation_0-mlogloss:0.05178	validation_1-mlogloss:1.23818
# Classification Report on Validation Set:
#               precision    recall  f1-score   support
#
#            0       0.30      0.50      0.38        90
#            1       0.58      0.49      0.53       186
#            2       0.38      0.29      0.33       118
#
#     accuracy                           0.43       394
#    macro avg       0.42      0.43      0.41       394
# weighted avg       0.46      0.43      0.44       394

# %% [markdown]
# Iteratie 1: (Baseline Model)

# %%
# Labels converteren van [-1, 0, 1] naar [0, 1, 2]
y_train_adj = y_train + 1
y_val_adj = y_val + 1

# Sample weights berekenen op basis van trainingslabels
from sklearn.utils.class_weight import compute_sample_weight
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_adj)

# Sterk vereenvoudigd en zwaar geregulariseerd model
xgb_model = XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    use_label_encoder=False,
    random_state=42,
    max_depth=1,                 # Minimale boomdiepte
    learning_rate=0.03,          # Langzaam leren
    n_estimators=100,            # Weinig bomen
    subsample=0.7,               # Minder rijen per boom
    colsample_bytree=0.7,        # Minder features per boom
    reg_alpha=1.0,               # Sterke L1-penalty
    reg_lambda=20,               # Sterke L2-penalty
    min_child_weight=20,         # Split alleen bij grote groepen
    gamma=1.0                    # Splits enkel bij duidelijke winst
)

# Trainen met early stopping op validatieset
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

xgb_model.fit(
    X_train_flat, 
    y_train_adj,
    sample_weight=sample_weights,
    eval_set=eval_set
)

# Plot de log loss curves
results = xgb_model.evals_result()
plt.figure(figsize=(10, 6))
plt.plot(results['validation_0']['mlogloss'], label='Train')
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('XGBoost Learning Curves (sterk geregulariseerd)')
plt.legend()
plt.grid(True)
plt.show()

# Voorspellingen en evaluatie
y_val_pred = xgb_model.predict(X_val_flat)
y_val_pred = y_val_pred - 1  # Terugconverteren naar originele labels [-1, 0, 1]

print("Validation performance:")
print(classification_report(y_val, y_val_pred))
# Out:
# [0]	validation_0-mlogloss:1.09803	validation_1-mlogloss:1.09910
# [1]	validation_0-mlogloss:1.09748	validation_1-mlogloss:1.09913
# [2]	validation_0-mlogloss:1.09699	validation_1-mlogloss:1.09963
# [3]	validation_0-mlogloss:1.09649	validation_1-mlogloss:1.10058
# [4]	validation_0-mlogloss:1.09602	validation_1-mlogloss:1.10154
# [5]	validation_0-mlogloss:1.09549	validation_1-mlogloss:1.10197
# [6]	validation_0-mlogloss:1.09495	validation_1-mlogloss:1.10288
# [7]	validation_0-mlogloss:1.09442	validation_1-mlogloss:1.10384
# [8]	validation_0-mlogloss:1.09396	validation_1-mlogloss:1.10326
# [9]	validation_0-mlogloss:1.09350	validation_1-mlogloss:1.10360
# [10]	validation_0-mlogloss:1.09294	validation_1-mlogloss:1.10429
# [11]	validation_0-mlogloss:1.09250	validation_1-mlogloss:1.10460
# [12]	validation_0-mlogloss:1.09203	validation_1-mlogloss:1.10585
# [13]	validation_0-mlogloss:1.09153	validation_1-mlogloss:1.10611
# [14]	validation_0-mlogloss:1.09111	validation_1-mlogloss:1.10582
# [15]	validation_0-mlogloss:1.09061	validation_1-mlogloss:1.10640
# [16]	validation_0-mlogloss:1.09023	validation_1-mlogloss:1.10603
# [17]	validation_0-mlogloss:1.08985	validation_1-mlogloss:1.10547
# [18]	validation_0-mlogloss:1.08937	validation_1-mlogloss:1.10587
# [19]	validation_0-mlogloss:1.08897	validation_1-mlogloss:1.10623
# [20]	validation_0-mlogloss:1.08855	validation_1-mlogloss:1.10674
# [21]	validation_0-mlogloss:1.08819	validation_1-mlogloss:1.10638
# [22]	validation_0-mlogloss:1.08785	validation_1-mlogloss:1.10615
# [23]	validation_0-mlogloss:1.08741	validation_1-mlogloss:1.10664
# [24]	validation_0-mlogloss:1.08706	validation_1-mlogloss:1.10710
# [25]	validation_0-mlogloss:1.08669	validation_1-mlogloss:1.10793
# [26]	validation_0-mlogloss:1.08635	validation_1-mlogloss:1.10792
# [27]	validation_0-mlogloss:1.08597	validation_1-mlogloss:1.10805
# c:\Users\boris\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [23:41:43] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [28]	validation_0-mlogloss:1.08557	validation_1-mlogloss:1.10871
# [29]	validation_0-mlogloss:1.08517	validation_1-mlogloss:1.10908
# [30]	validation_0-mlogloss:1.08478	validation_1-mlogloss:1.10962
# [31]	validation_0-mlogloss:1.08438	validation_1-mlogloss:1.11101
# [32]	validation_0-mlogloss:1.08402	validation_1-mlogloss:1.11108
# [33]	validation_0-mlogloss:1.08365	validation_1-mlogloss:1.11159
# [34]	validation_0-mlogloss:1.08329	validation_1-mlogloss:1.11176
# [35]	validation_0-mlogloss:1.08291	validation_1-mlogloss:1.11058
# [36]	validation_0-mlogloss:1.08256	validation_1-mlogloss:1.11180
# [37]	validation_0-mlogloss:1.08225	validation_1-mlogloss:1.11267
# [38]	validation_0-mlogloss:1.08194	validation_1-mlogloss:1.11397
# [39]	validation_0-mlogloss:1.08157	validation_1-mlogloss:1.11295
# [40]	validation_0-mlogloss:1.08122	validation_1-mlogloss:1.11231
# [41]	validation_0-mlogloss:1.08090	validation_1-mlogloss:1.11255
# [42]	validation_0-mlogloss:1.08055	validation_1-mlogloss:1.11314
# [43]	validation_0-mlogloss:1.08020	validation_1-mlogloss:1.11137
# [44]	validation_0-mlogloss:1.07990	validation_1-mlogloss:1.11123
# [45]	validation_0-mlogloss:1.07955	validation_1-mlogloss:1.11150
# [46]	validation_0-mlogloss:1.07926	validation_1-mlogloss:1.11030
# [47]	validation_0-mlogloss:1.07892	validation_1-mlogloss:1.10864
# [48]	validation_0-mlogloss:1.07862	validation_1-mlogloss:1.10949
# [49]	validation_0-mlogloss:1.07831	validation_1-mlogloss:1.10918
# [50]	validation_0-mlogloss:1.07805	validation_1-mlogloss:1.10847
# [51]	validation_0-mlogloss:1.07779	validation_1-mlogloss:1.10879
# [52]	validation_0-mlogloss:1.07745	validation_1-mlogloss:1.10924
# [53]	validation_0-mlogloss:1.07714	validation_1-mlogloss:1.10944
# [54]	validation_0-mlogloss:1.07685	validation_1-mlogloss:1.10957
# [55]	validation_0-mlogloss:1.07655	validation_1-mlogloss:1.11054
# [56]	validation_0-mlogloss:1.07625	validation_1-mlogloss:1.11067
# [57]	validation_0-mlogloss:1.07596	validation_1-mlogloss:1.11115
# [58]	validation_0-mlogloss:1.07561	validation_1-mlogloss:1.11025
# [59]	validation_0-mlogloss:1.07534	validation_1-mlogloss:1.11098
# [60]	validation_0-mlogloss:1.07501	validation_1-mlogloss:1.11122
# [61]	validation_0-mlogloss:1.07469	validation_1-mlogloss:1.11223
# [62]	validation_0-mlogloss:1.07437	validation_1-mlogloss:1.11168
# [63]	validation_0-mlogloss:1.07403	validation_1-mlogloss:1.11127
# [64]	validation_0-mlogloss:1.07377	validation_1-mlogloss:1.11132
# [65]	validation_0-mlogloss:1.07345	validation_1-mlogloss:1.11170
# [66]	validation_0-mlogloss:1.07318	validation_1-mlogloss:1.11190
# [67]	validation_0-mlogloss:1.07291	validation_1-mlogloss:1.11191
# [68]	validation_0-mlogloss:1.07266	validation_1-mlogloss:1.11200
# [69]	validation_0-mlogloss:1.07236	validation_1-mlogloss:1.11123
# [70]	validation_0-mlogloss:1.07207	validation_1-mlogloss:1.11117
# [71]	validation_0-mlogloss:1.07180	validation_1-mlogloss:1.10958
# [72]	validation_0-mlogloss:1.07153	validation_1-mlogloss:1.10886
# [73]	validation_0-mlogloss:1.07131	validation_1-mlogloss:1.10913
# [74]	validation_0-mlogloss:1.07099	validation_1-mlogloss:1.10800
# [75]	validation_0-mlogloss:1.07067	validation_1-mlogloss:1.10724
# [76]	validation_0-mlogloss:1.07041	validation_1-mlogloss:1.10643
# [77]	validation_0-mlogloss:1.07013	validation_1-mlogloss:1.10640
# [78]	validation_0-mlogloss:1.06986	validation_1-mlogloss:1.10686
# [79]	validation_0-mlogloss:1.06960	validation_1-mlogloss:1.10697
# [80]	validation_0-mlogloss:1.06933	validation_1-mlogloss:1.10645
# [81]	validation_0-mlogloss:1.06906	validation_1-mlogloss:1.10666
# [82]	validation_0-mlogloss:1.06878	validation_1-mlogloss:1.10666
# [83]	validation_0-mlogloss:1.06848	validation_1-mlogloss:1.10606
# [84]	validation_0-mlogloss:1.06826	validation_1-mlogloss:1.10571
# [85]	validation_0-mlogloss:1.06804	validation_1-mlogloss:1.10566
# [86]	validation_0-mlogloss:1.06783	validation_1-mlogloss:1.10526
# [87]	validation_0-mlogloss:1.06758	validation_1-mlogloss:1.10483
# [88]	validation_0-mlogloss:1.06729	validation_1-mlogloss:1.10427
# [89]	validation_0-mlogloss:1.06703	validation_1-mlogloss:1.10492
# [90]	validation_0-mlogloss:1.06681	validation_1-mlogloss:1.10405
# [91]	validation_0-mlogloss:1.06653	validation_1-mlogloss:1.10463
# [92]	validation_0-mlogloss:1.06629	validation_1-mlogloss:1.10467
# [93]	validation_0-mlogloss:1.06604	validation_1-mlogloss:1.10332
# [94]	validation_0-mlogloss:1.06582	validation_1-mlogloss:1.10309
# [95]	validation_0-mlogloss:1.06564	validation_1-mlogloss:1.10394
# [96]	validation_0-mlogloss:1.06539	validation_1-mlogloss:1.10445
# [97]	validation_0-mlogloss:1.06517	validation_1-mlogloss:1.10470
# [98]	validation_0-mlogloss:1.06494	validation_1-mlogloss:1.10444
# [99]	validation_0-mlogloss:1.06471	validation_1-mlogloss:1.10445
# Validation performance:
#               precision    recall  f1-score   support
#
#           -1       0.29      0.27      0.28        90
#            0       0.61      0.12      0.21       186
#            1       0.31      0.72      0.43       118
#
#     accuracy                           0.34       394
#    macro avg       0.40      0.37      0.31       394
# weighted avg       0.45      0.34      0.29       394

# %% [markdown]
# ### Iteratie 2: (Baseline Model)

# %%
# # Labels converteren van [-1, 0, 1] naar [0, 1, 2]
# y_train_adj = y_train + 1
# y_val_adj = y_val + 1

# # Sample weights berekenen op basis van trainingslabels
# sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_adj)

# # Hyperparameter grid
# param_dist = {
#     'max_depth': [1, 2, 3],
#     'learning_rate': [0.01, 0.03, 0.05],
#     'n_estimators': [150, 200, 250],
#     'subsample': [0.6, 0.7, 0.8],
#     'colsample_bytree': [0.6, 0.7, 0.8],
#     'reg_alpha': [0.1, 0.5, 1.0],
#     'reg_lambda': [5, 10, 20],
#     'min_child_weight': [5, 10, 20],
#     'gamma': [0.1, 0.5, 1.0]
# }

# # Basis XGBoost model
# xgb_base = XGBClassifier(
#     objective='multi:softmax',
#     num_class=3,
#     eval_metric='mlogloss',
#     random_state=42
# )

# # Randomized search met progress bar
# from sklearn.model_selection import RandomizedSearchCV
# search = RandomizedSearchCV(
#     estimator=xgb_base,
#     param_distributions=param_dist,
#     n_iter=30,
#     scoring='f1_macro',
#     cv=3,
#     verbose=2,
#     n_jobs=1  # Single job to avoid pickling errors
# )

# # Fit zonder callback (gebruik verbose=2 voor voortgang)
# search.fit(X_train_flat, y_train_adj, sample_weight=sample_weights)

# # Beste params en score
# print("\nBeste hyperparameters:")
# for param, value in search.best_params_.items():
#     print(f"{param}: {value}")
# print(f"\nBeste f1_macro score: {search.best_score_:.4f}")

# # Gebruik beste model en train op volledige trainingsset
# best_model = search.best_estimator_

# # Voeg validatie toe voor learning curves
# eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

# # Training met eval_set
# best_model.fit(
#     X_train_flat, 
#     y_train_adj,
#     sample_weight=sample_weights,
#     eval_set=eval_set,
#     verbose=True
# )

# # Plot learning curves
# results = best_model.evals_result()
# plt.figure(figsize=(10, 6))
# plt.plot(results['validation_0']['mlogloss'], label='Train')
# plt.plot(results['validation_1']['mlogloss'], label='Validation')
# plt.xlabel('Iterations')
# plt.ylabel('Log Loss')
# plt.title('Learning Curves van beste model na RandomizedSearchCV')
# plt.legend()
# plt.grid(True)
# plt.show()

# # Voorspellingen en evaluatie op validatieset
# y_val_pred = best_model.predict(X_val_flat)
# y_val_pred = y_val_pred - 1  # Terug naar originele labels [-1, 0, 1]

# print("\nValidation performance van beste model:")
# print(classification_report(y_val, y_val_pred))

# %%
# Train model met beste hyperparameters uit RandomizedSearchCV
model_double_iter = XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    subsample=0.8,
    reg_lambda=10,
    reg_alpha=0.5,
    n_estimators=200,
    min_child_weight=5,
    max_depth=2,
    learning_rate=0.03,
    gamma=0.5,
    colsample_bytree=0.8,
    random_state=42
)



# Train model met sample weights en validatieset
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

model_double_iter.fit(
    X_train_flat,
    y_train_adj,
    sample_weight=sample_weights,
    eval_set=eval_set,
    verbose=True
)

# Plot learning curves
results = model_double_iter.evals_result()
plt.figure(figsize=(10, 6))
plt.plot(results['validation_0']['mlogloss'], label='Train')
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('Learning Curves van model met beste hyperparameters')
plt.legend()
plt.grid(True)
plt.show()

# Voorspellingen en evaluatie op validatieset
y_val_pred = model_double_iter.predict(X_val_flat)
y_val_pred = y_val_pred - 1  # Terug naar originele labels [-1, 0, 1]

print("\nValidation performance:")
print(classification_report(y_val, y_val_pred))
# Out:
# [0]	validation_0-mlogloss:1.09704	validation_1-mlogloss:1.09782
# [1]	validation_0-mlogloss:1.09574	validation_1-mlogloss:1.09759
# [2]	validation_0-mlogloss:1.09461	validation_1-mlogloss:1.09693
# [3]	validation_0-mlogloss:1.09326	validation_1-mlogloss:1.09619
# [4]	validation_0-mlogloss:1.09204	validation_1-mlogloss:1.09647
# [5]	validation_0-mlogloss:1.09055	validation_1-mlogloss:1.09608
# [6]	validation_0-mlogloss:1.08928	validation_1-mlogloss:1.09556
# [7]	validation_0-mlogloss:1.08799	validation_1-mlogloss:1.09529
# [8]	validation_0-mlogloss:1.08675	validation_1-mlogloss:1.09444
# [9]	validation_0-mlogloss:1.08570	validation_1-mlogloss:1.09494
# [10]	validation_0-mlogloss:1.08449	validation_1-mlogloss:1.09553
# [11]	validation_0-mlogloss:1.08332	validation_1-mlogloss:1.09432
# [12]	validation_0-mlogloss:1.08212	validation_1-mlogloss:1.09450
# [13]	validation_0-mlogloss:1.08109	validation_1-mlogloss:1.09415
# [14]	validation_0-mlogloss:1.07993	validation_1-mlogloss:1.09364
# [15]	validation_0-mlogloss:1.07889	validation_1-mlogloss:1.09347
# [16]	validation_0-mlogloss:1.07763	validation_1-mlogloss:1.09317
# [17]	validation_0-mlogloss:1.07663	validation_1-mlogloss:1.09276
# [18]	validation_0-mlogloss:1.07554	validation_1-mlogloss:1.09235
# [19]	validation_0-mlogloss:1.07452	validation_1-mlogloss:1.09255
# [20]	validation_0-mlogloss:1.07352	validation_1-mlogloss:1.09197
# [21]	validation_0-mlogloss:1.07247	validation_1-mlogloss:1.09065
# [22]	validation_0-mlogloss:1.07144	validation_1-mlogloss:1.09074
# [23]	validation_0-mlogloss:1.07042	validation_1-mlogloss:1.09121
# [24]	validation_0-mlogloss:1.06950	validation_1-mlogloss:1.09089
# [25]	validation_0-mlogloss:1.06854	validation_1-mlogloss:1.08995
# [26]	validation_0-mlogloss:1.06761	validation_1-mlogloss:1.09101
# [27]	validation_0-mlogloss:1.06673	validation_1-mlogloss:1.09021
# [28]	validation_0-mlogloss:1.06581	validation_1-mlogloss:1.08946
# [29]	validation_0-mlogloss:1.06477	validation_1-mlogloss:1.08946
# [30]	validation_0-mlogloss:1.06388	validation_1-mlogloss:1.08911
# [31]	validation_0-mlogloss:1.06303	validation_1-mlogloss:1.09044
# [32]	validation_0-mlogloss:1.06221	validation_1-mlogloss:1.08960
# [33]	validation_0-mlogloss:1.06138	validation_1-mlogloss:1.08877
# [34]	validation_0-mlogloss:1.06055	validation_1-mlogloss:1.08853
# [35]	validation_0-mlogloss:1.05964	validation_1-mlogloss:1.08854
# [36]	validation_0-mlogloss:1.05892	validation_1-mlogloss:1.08794
# [37]	validation_0-mlogloss:1.05809	validation_1-mlogloss:1.08706
# [38]	validation_0-mlogloss:1.05738	validation_1-mlogloss:1.08749
# [39]	validation_0-mlogloss:1.05658	validation_1-mlogloss:1.08679
# [40]	validation_0-mlogloss:1.05578	validation_1-mlogloss:1.08638
# [41]	validation_0-mlogloss:1.05488	validation_1-mlogloss:1.08629
# [42]	validation_0-mlogloss:1.05426	validation_1-mlogloss:1.08570
# [43]	validation_0-mlogloss:1.05351	validation_1-mlogloss:1.08466
# [44]	validation_0-mlogloss:1.05282	validation_1-mlogloss:1.08499
# [45]	validation_0-mlogloss:1.05201	validation_1-mlogloss:1.08516
# [46]	validation_0-mlogloss:1.05135	validation_1-mlogloss:1.08426
# [47]	validation_0-mlogloss:1.05069	validation_1-mlogloss:1.08290
# [48]	validation_0-mlogloss:1.05008	validation_1-mlogloss:1.08387
# [49]	validation_0-mlogloss:1.04942	validation_1-mlogloss:1.08411
# [50]	validation_0-mlogloss:1.04878	validation_1-mlogloss:1.08421
# [51]	validation_0-mlogloss:1.04814	validation_1-mlogloss:1.08415
# [52]	validation_0-mlogloss:1.04738	validation_1-mlogloss:1.08405
# [53]	validation_0-mlogloss:1.04670	validation_1-mlogloss:1.08334
# [54]	validation_0-mlogloss:1.04594	validation_1-mlogloss:1.08327
# [55]	validation_0-mlogloss:1.04526	validation_1-mlogloss:1.08288
# [56]	validation_0-mlogloss:1.04464	validation_1-mlogloss:1.08345
# [57]	validation_0-mlogloss:1.04406	validation_1-mlogloss:1.08317
# [58]	validation_0-mlogloss:1.04335	validation_1-mlogloss:1.08362
# [59]	validation_0-mlogloss:1.04270	validation_1-mlogloss:1.08323
# [60]	validation_0-mlogloss:1.04202	validation_1-mlogloss:1.08230
# [61]	validation_0-mlogloss:1.04135	validation_1-mlogloss:1.08305
# [62]	validation_0-mlogloss:1.04067	validation_1-mlogloss:1.08256
# [63]	validation_0-mlogloss:1.03988	validation_1-mlogloss:1.08311
# [64]	validation_0-mlogloss:1.03928	validation_1-mlogloss:1.08332
# [65]	validation_0-mlogloss:1.03866	validation_1-mlogloss:1.08410
# [66]	validation_0-mlogloss:1.03818	validation_1-mlogloss:1.08380
# [67]	validation_0-mlogloss:1.03759	validation_1-mlogloss:1.08314
# [68]	validation_0-mlogloss:1.03699	validation_1-mlogloss:1.08338
# [69]	validation_0-mlogloss:1.03635	validation_1-mlogloss:1.08325
# [70]	validation_0-mlogloss:1.03579	validation_1-mlogloss:1.08323
# [71]	validation_0-mlogloss:1.03517	validation_1-mlogloss:1.08360
# [72]	validation_0-mlogloss:1.03462	validation_1-mlogloss:1.08307
# [73]	validation_0-mlogloss:1.03407	validation_1-mlogloss:1.08297
# [74]	validation_0-mlogloss:1.03351	validation_1-mlogloss:1.08187
# [75]	validation_0-mlogloss:1.03300	validation_1-mlogloss:1.08142
# [76]	validation_0-mlogloss:1.03246	validation_1-mlogloss:1.08050
# [77]	validation_0-mlogloss:1.03195	validation_1-mlogloss:1.07956
# [78]	validation_0-mlogloss:1.03137	validation_1-mlogloss:1.07964
# [79]	validation_0-mlogloss:1.03085	validation_1-mlogloss:1.07827
# [80]	validation_0-mlogloss:1.03022	validation_1-mlogloss:1.07746
# [81]	validation_0-mlogloss:1.02960	validation_1-mlogloss:1.07749
# [82]	validation_0-mlogloss:1.02913	validation_1-mlogloss:1.07723
# [83]	validation_0-mlogloss:1.02846	validation_1-mlogloss:1.07738
# [84]	validation_0-mlogloss:1.02780	validation_1-mlogloss:1.07734
# [85]	validation_0-mlogloss:1.02732	validation_1-mlogloss:1.07642
# [86]	validation_0-mlogloss:1.02674	validation_1-mlogloss:1.07631
# [87]	validation_0-mlogloss:1.02619	validation_1-mlogloss:1.07666
# [88]	validation_0-mlogloss:1.02565	validation_1-mlogloss:1.07666
# [89]	validation_0-mlogloss:1.02520	validation_1-mlogloss:1.07668
# [90]	validation_0-mlogloss:1.02472	validation_1-mlogloss:1.07620
# [91]	validation_0-mlogloss:1.02416	validation_1-mlogloss:1.07586
# [92]	validation_0-mlogloss:1.02358	validation_1-mlogloss:1.07541
# [93]	validation_0-mlogloss:1.02305	validation_1-mlogloss:1.07517
# [94]	validation_0-mlogloss:1.02254	validation_1-mlogloss:1.07493
# [95]	validation_0-mlogloss:1.02200	validation_1-mlogloss:1.07565
# [96]	validation_0-mlogloss:1.02140	validation_1-mlogloss:1.07561
# [97]	validation_0-mlogloss:1.02093	validation_1-mlogloss:1.07506
# [98]	validation_0-mlogloss:1.02045	validation_1-mlogloss:1.07537
# [99]	validation_0-mlogloss:1.01997	validation_1-mlogloss:1.07505
# [100]	validation_0-mlogloss:1.01936	validation_1-mlogloss:1.07579
# [101]	validation_0-mlogloss:1.01888	validation_1-mlogloss:1.07575
# [102]	validation_0-mlogloss:1.01842	validation_1-mlogloss:1.07621
# [103]	validation_0-mlogloss:1.01793	validation_1-mlogloss:1.07606
# [104]	validation_0-mlogloss:1.01743	validation_1-mlogloss:1.07575
# [105]	validation_0-mlogloss:1.01692	validation_1-mlogloss:1.07575
# [106]	validation_0-mlogloss:1.01643	validation_1-mlogloss:1.07623
# [107]	validation_0-mlogloss:1.01597	validation_1-mlogloss:1.07603
# [108]	validation_0-mlogloss:1.01550	validation_1-mlogloss:1.07570
# [109]	validation_0-mlogloss:1.01490	validation_1-mlogloss:1.07583
# [110]	validation_0-mlogloss:1.01451	validation_1-mlogloss:1.07538
# [111]	validation_0-mlogloss:1.01390	validation_1-mlogloss:1.07592
# [112]	validation_0-mlogloss:1.01347	validation_1-mlogloss:1.07547
# [113]	validation_0-mlogloss:1.01301	validation_1-mlogloss:1.07594
# [114]	validation_0-mlogloss:1.01272	validation_1-mlogloss:1.07604
# [115]	validation_0-mlogloss:1.01229	validation_1-mlogloss:1.07587
# [116]	validation_0-mlogloss:1.01171	validation_1-mlogloss:1.07551
# [117]	validation_0-mlogloss:1.01126	validation_1-mlogloss:1.07559
# [118]	validation_0-mlogloss:1.01089	validation_1-mlogloss:1.07579
# [119]	validation_0-mlogloss:1.01051	validation_1-mlogloss:1.07604
# [120]	validation_0-mlogloss:1.00998	validation_1-mlogloss:1.07528
# [121]	validation_0-mlogloss:1.00960	validation_1-mlogloss:1.07578
# [122]	validation_0-mlogloss:1.00915	validation_1-mlogloss:1.07590
# [123]	validation_0-mlogloss:1.00873	validation_1-mlogloss:1.07510
# [124]	validation_0-mlogloss:1.00830	validation_1-mlogloss:1.07534
# [125]	validation_0-mlogloss:1.00783	validation_1-mlogloss:1.07556
# [126]	validation_0-mlogloss:1.00727	validation_1-mlogloss:1.07584
# [127]	validation_0-mlogloss:1.00689	validation_1-mlogloss:1.07616
# [128]	validation_0-mlogloss:1.00638	validation_1-mlogloss:1.07576
# [129]	validation_0-mlogloss:1.00594	validation_1-mlogloss:1.07525
# [130]	validation_0-mlogloss:1.00539	validation_1-mlogloss:1.07525
# [131]	validation_0-mlogloss:1.00497	validation_1-mlogloss:1.07573
# [132]	validation_0-mlogloss:1.00456	validation_1-mlogloss:1.07620
# [133]	validation_0-mlogloss:1.00408	validation_1-mlogloss:1.07618
# [134]	validation_0-mlogloss:1.00360	validation_1-mlogloss:1.07625
# [135]	validation_0-mlogloss:1.00315	validation_1-mlogloss:1.07632
# [136]	validation_0-mlogloss:1.00270	validation_1-mlogloss:1.07591
# [137]	validation_0-mlogloss:1.00223	validation_1-mlogloss:1.07596
# [138]	validation_0-mlogloss:1.00182	validation_1-mlogloss:1.07611
# [139]	validation_0-mlogloss:1.00137	validation_1-mlogloss:1.07557
# [140]	validation_0-mlogloss:1.00085	validation_1-mlogloss:1.07451
# [141]	validation_0-mlogloss:1.00035	validation_1-mlogloss:1.07465
# [142]	validation_0-mlogloss:0.99994	validation_1-mlogloss:1.07470
# [143]	validation_0-mlogloss:0.99956	validation_1-mlogloss:1.07486
# [144]	validation_0-mlogloss:0.99908	validation_1-mlogloss:1.07541
# [145]	validation_0-mlogloss:0.99863	validation_1-mlogloss:1.07549
# [146]	validation_0-mlogloss:0.99823	validation_1-mlogloss:1.07516
# [147]	validation_0-mlogloss:0.99773	validation_1-mlogloss:1.07519
# [148]	validation_0-mlogloss:0.99727	validation_1-mlogloss:1.07494
# [149]	validation_0-mlogloss:0.99689	validation_1-mlogloss:1.07385
# [150]	validation_0-mlogloss:0.99646	validation_1-mlogloss:1.07423
# [151]	validation_0-mlogloss:0.99609	validation_1-mlogloss:1.07355
# [152]	validation_0-mlogloss:0.99569	validation_1-mlogloss:1.07351
# [153]	validation_0-mlogloss:0.99517	validation_1-mlogloss:1.07431
# [154]	validation_0-mlogloss:0.99486	validation_1-mlogloss:1.07482
# [155]	validation_0-mlogloss:0.99449	validation_1-mlogloss:1.07496
# [156]	validation_0-mlogloss:0.99408	validation_1-mlogloss:1.07501
# [157]	validation_0-mlogloss:0.99372	validation_1-mlogloss:1.07499
# [158]	validation_0-mlogloss:0.99336	validation_1-mlogloss:1.07500
# [159]	validation_0-mlogloss:0.99290	validation_1-mlogloss:1.07483
# [160]	validation_0-mlogloss:0.99246	validation_1-mlogloss:1.07523
# [161]	validation_0-mlogloss:0.99205	validation_1-mlogloss:1.07500
# [162]	validation_0-mlogloss:0.99167	validation_1-mlogloss:1.07548
# [163]	validation_0-mlogloss:0.99130	validation_1-mlogloss:1.07560
# [164]	validation_0-mlogloss:0.99083	validation_1-mlogloss:1.07548
# [165]	validation_0-mlogloss:0.99049	validation_1-mlogloss:1.07506
# [166]	validation_0-mlogloss:0.99006	validation_1-mlogloss:1.07497
# [167]	validation_0-mlogloss:0.98958	validation_1-mlogloss:1.07423
# [168]	validation_0-mlogloss:0.98918	validation_1-mlogloss:1.07425
# [169]	validation_0-mlogloss:0.98872	validation_1-mlogloss:1.07420
# [170]	validation_0-mlogloss:0.98822	validation_1-mlogloss:1.07469
# [171]	validation_0-mlogloss:0.98788	validation_1-mlogloss:1.07515
# [172]	validation_0-mlogloss:0.98747	validation_1-mlogloss:1.07475
# [173]	validation_0-mlogloss:0.98704	validation_1-mlogloss:1.07569
# [174]	validation_0-mlogloss:0.98666	validation_1-mlogloss:1.07640
# [175]	validation_0-mlogloss:0.98626	validation_1-mlogloss:1.07625
# [176]	validation_0-mlogloss:0.98590	validation_1-mlogloss:1.07688
# [177]	validation_0-mlogloss:0.98549	validation_1-mlogloss:1.07683
# [178]	validation_0-mlogloss:0.98505	validation_1-mlogloss:1.07685
# [179]	validation_0-mlogloss:0.98468	validation_1-mlogloss:1.07643
# [180]	validation_0-mlogloss:0.98430	validation_1-mlogloss:1.07707
# [181]	validation_0-mlogloss:0.98394	validation_1-mlogloss:1.07715
# [182]	validation_0-mlogloss:0.98351	validation_1-mlogloss:1.07705
# [183]	validation_0-mlogloss:0.98314	validation_1-mlogloss:1.07688
# [184]	validation_0-mlogloss:0.98273	validation_1-mlogloss:1.07716
# [185]	validation_0-mlogloss:0.98236	validation_1-mlogloss:1.07758
# [186]	validation_0-mlogloss:0.98198	validation_1-mlogloss:1.07789
# [187]	validation_0-mlogloss:0.98162	validation_1-mlogloss:1.07742
# [188]	validation_0-mlogloss:0.98132	validation_1-mlogloss:1.07679
# [189]	validation_0-mlogloss:0.98092	validation_1-mlogloss:1.07651
# [190]	validation_0-mlogloss:0.98060	validation_1-mlogloss:1.07669
# [191]	validation_0-mlogloss:0.98024	validation_1-mlogloss:1.07623
# [192]	validation_0-mlogloss:0.97985	validation_1-mlogloss:1.07606
# [193]	validation_0-mlogloss:0.97937	validation_1-mlogloss:1.07593
# [194]	validation_0-mlogloss:0.97892	validation_1-mlogloss:1.07574
# [195]	validation_0-mlogloss:0.97848	validation_1-mlogloss:1.07630
# [196]	validation_0-mlogloss:0.97810	validation_1-mlogloss:1.07667
# [197]	validation_0-mlogloss:0.97769	validation_1-mlogloss:1.07626
# [198]	validation_0-mlogloss:0.97727	validation_1-mlogloss:1.07580
# [199]	validation_0-mlogloss:0.97677	validation_1-mlogloss:1.07619
# Validation performance:
#               precision    recall  f1-score   support
#
#           -1       0.29      0.48      0.36        90
#            0       0.68      0.44      0.53       186
#            1       0.37      0.39      0.38       118
#
#     accuracy                           0.43       394
#    macro avg       0.45      0.43      0.42       394
# weighted avg       0.50      0.43      0.45       394

# %% [markdown]
# Analyse Iteratie 3: Uit

# %% [markdown]
# # Baseline model testen

# %%
# Test model op testset
y_test_pred = model_double_iter.predict(X_test_flat)
y_test_pred = y_test_pred - 1  # Terugzetten naar [-1, 0, 1]

print("\n Test performance:")
print(classification_report(y_test, y_test_pred))
# Out:
# 📊 Test performance:
#               precision    recall  f1-score   support
#
#           -1       0.33      0.84      0.48       121
#            0       0.60      0.33      0.43       158
#            1       0.00      0.00      0.00       116
#
#     accuracy                           0.39       395
#    macro avg       0.31      0.39      0.30       395
# weighted avg       0.34      0.39      0.32       395

# %% [markdown]
# # Mempool Data Inladen + Data Verkennen

# %% [markdown]
# ### Total transaction count (avarage per day) Inladen

# %%
import json
import pandas as pd

# 1. JSON-bestand laden
with open("mempool-count (2).json", "r") as f:
    data = json.load(f)

# 2. Data extraheren
records = data['mempool-count']
df = pd.DataFrame(records)

# 3. UNIX naar datum 
df['x'] = pd.to_datetime(df['x'], unit='ms')
df = df.rename(columns={'x': 'date', 'y': 'mempool_transaction_count'})
df = df.set_index('date').sort_index()

# 4. Resample naar 1 dag
df_daily = df.resample('1D').mean()

# misdata aanvullen (interpolatie of fill)
df_daily['mempool_transaction_count'] = df_daily['mempool_transaction_count'].interpolate(method='linear')

# 5. Reset index voor verder gebruik
df_daily = df_daily.reset_index()

# 6. Bekijk resultaat
print(df_daily.head(10))

#  opslaan
df_daily.to_csv("mempool_transaction_count_daily_filled.csv", index=False)
# Out:
#         date  mempool_transaction_count
# 0 2016-06-15               17325.729167
# 1 2016-06-16               13925.367188
# 2 2016-06-17               10525.005208
# 3 2016-06-18                6564.291667
# 4 2016-06-19                2603.578125
# 5 2016-06-20                3236.781250
# 6 2016-06-21                3869.984375
# 7 2016-06-22                4503.187500
# 8 2016-06-23                5105.632812
# 9 2016-06-24                5708.078125

# %% [markdown]
# ## Total Transaction count Verkennen

# %%
# Basic data exploration
print("\nDataset Info:")
print(df_daily.info())

print("\nBasic Statistics:")
print(df_daily.describe())

print("\nMissing Values:")
print(df_daily.isnull().sum())

# Check for outliers using IQR method
Q1 = df_daily['mempool_transaction_count'].quantile(0.25)
Q3 = df_daily['mempool_transaction_count'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df_daily[(df_daily['mempool_transaction_count'] < lower_bound) | 
                    (df_daily['mempool_transaction_count'] > upper_bound)]

print("\nNumber of outliers:", len(outliers))
print("\nPercentage of outliers: {:.2f}%".format((len(outliers)/len(df_daily))*100))

# Visualize distribution
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.boxplot(y=df_daily['mempool_transaction_count'])
plt.title('Boxplot of Mempool Transaction Count')

plt.subplot(1,2,2)
sns.histplot(data=df_daily, x='mempool_transaction_count', kde=True)
plt.title('Distribution of Mempool Transaction Count')
plt.tight_layout()
plt.show()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3252 entries, 0 to 3251
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   date                       3252 non-null   datetime64[ns]
#  1   mempool_transaction_count  3252 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 50.9 KB
# None
#
# Basic Statistics:
#                       date  mempool_transaction_count
# count                 3252                3252.000000
# mean   2020-11-26 12:00:00               39648.725459
# min    2016-06-15 00:00:00                1007.567708
# 25%    2018-09-05 18:00:00                4272.298177
# 50%    2020-11-26 12:00:00                9205.049045
# 75%    2023-02-17 06:00:00               47726.050781
# max    2025-05-10 00:00:00              296700.505208
# std                    NaN               57495.204669
#
# Missing Values:
# date                         0
# mempool_transaction_count    0
# dtype: int64
#
# Number of outliers: 493
#
# Percentage of outliers: 15.16%

# %%
# Print de laatste datum in de dataset
print("Laatste datum in dataset:", df_daily['date'].max())
# Out:
# Laatste datum in dataset: 2025-05-10 00:00:00

# %%
# Hernoemen van de dataset
daily_transaction_count = df_daily

# Filter op datums vanaf 2018-02-01
daily_transaction_count = daily_transaction_count[daily_transaction_count['date'] >= '2018-02-01']

print(daily_transaction_count.head())
# Out:
#           date  mempool_transaction_count
# 596 2018-02-01               17755.520833
# 597 2018-02-02               17401.867188
# 598 2018-02-03               17048.213542
# 599 2018-02-04               12023.375000
# 600 2018-02-05                6998.536458

# %% [markdown]
# # Mempool total size (in bytes) Data Inladen en verkennen

# %%
import pandas as pd
import json

# Laad het JSON-bestand
with open('mempool-size.json', 'r') as file:
    raw_data = json.load(file)

# Haal de lijst onder "mempool-size" op
data = raw_data['mempool-size']

# Zet om naar DataFrame
df_mempool = pd.DataFrame(data)

# Zet UNIX milliseconden naar datetime
df_mempool['x'] = pd.to_datetime(df_mempool['x'], unit='ms')

df_mempool.rename(columns={'x': 'Timestamp', 'y': 'MempoolSizeBytes'}, inplace=True)

# Zet Timestamp als index
df_mempool.set_index('Timestamp', inplace=True)

# Bekijk de eerste rijen
print(df_mempool.head())
# Out:
#                      MempoolSizeBytes
# Timestamp
# 2016-06-15 14:45:00      2.346226e+07
# 2016-06-17 18:45:00      2.622095e+07
# 2016-06-19 22:45:00      4.464119e+06
# 2016-06-22 02:45:00      5.215474e+06
# 2016-06-24 06:45:00      1.134712e+07

# %%
# Resample data naar dagelijkse intervallen en interpoleer ontbrekende waarden
daily_mempoolsize = df_mempool.resample('D').mean().interpolate()

# Reset de index zodat Timestamp weer een kolom wordt
daily_mempoolsize = daily_mempoolsize.reset_index()

# Filter op datums vanaf 2018-02-01 om consistent te zijn met andere data
daily_mempoolsize = daily_mempoolsize[daily_mempoolsize['Timestamp'] >= '2018-02-01']

print(daily_mempoolsize.head())
# Out:
#      Timestamp  MempoolSizeBytes
# 596 2018-02-01      5.210158e+07
# 597 2018-02-02      5.232593e+07
# 598 2018-02-03      5.255029e+07
# 599 2018-02-04      3.624007e+07
# 600 2018-02-05      1.992984e+07

# %% [markdown]
# ### Data Mempool size Verkennen

# %%
# Basic data exploration
print("\nDataset Info:")
print(df_mempool.info())

print("\nBasic Statistics:")
print(df_mempool.describe())

print("\nMissing Values:")
print(df_mempool.isnull().sum())

# Check for outliers using IQR method
Q1 = df_mempool['MempoolSizeBytes'].quantile(0.25)
Q3 = df_mempool['MempoolSizeBytes'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df_mempool[(df_mempool['MempoolSizeBytes'] < lower_bound) | 
                      (df_mempool['MempoolSizeBytes'] > upper_bound)]

print("\nNumber of outliers:", len(outliers))
print("\nPercentage of outliers: {:.2f}%".format((len(outliers)/len(df_mempool))*100))

# Visualize distribution
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.boxplot(y=df_mempool['MempoolSizeBytes'])
plt.title('Boxplot of Mempool Size (Bytes)')

plt.subplot(1,2,2)
sns.histplot(data=df_mempool, x='MempoolSizeBytes', kde=True)
plt.title('Distribution of Mempool Size (Bytes)')
plt.tight_layout()
plt.show()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1501 entries, 2016-06-15 14:45:00 to 2025-05-10 20:45:00
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MempoolSizeBytes  1501 non-null   float64
# dtypes: float64(1)
# memory usage: 23.5 KB
# None
#
# Basic Statistics:
#        MempoolSizeBytes
# count      1.501000e+03
# mean       3.937602e+07
# std        5.604891e+07
# min        4.699322e+05
# 25%        2.657121e+06
# 50%        9.505765e+06
# 75%        6.581515e+07
# max        3.724396e+08
#
# Missing Values:
# MempoolSizeBytes    0
# dtype: int64
#
# Number of outliers: 62
#
# Percentage of outliers: 4.13%

# %%
# Print de laatste datum in daily_mempoolsize
print(f"Laatste datum in mempool size data: {daily_mempoolsize['Timestamp'].max()}")
# Out:
# Laatste datum in mempool size data: 2025-05-10 00:00:00

# %% [markdown]
# # Total Transaction Fees (BTC) Gemiddel per dag
# ### Data Inladen

# %%
import requests
import pandas as pd

url = "https://api.blockchain.info/charts/transaction-fees?timespan=all&rollingAverage=1days&format=json"
data = requests.get(url).json()
df = pd.DataFrame(data['values'])
df['x'] = pd.to_datetime(df['x'], unit='s')
df.rename(columns={'x': 'Date', 'y': 'TotalFees_BTC'}, inplace=True)
df.set_index('Date', inplace=True)

# %%
# Resample data naar dagelijkse intervallen en interpoleer ontbrekende waarden
daily_fees = df.resample('D').mean().interpolate()

# Reset de index zodat Date weer een kolom wordt
daily_fees = daily_fees.reset_index()

# Filter op datums vanaf 2018-02-01 om consistent te zijn met andere data
daily_fees = daily_fees[daily_fees['Date'] >= '2018-02-01']

print(daily_fees.head())
# Out:
#            Date  TotalFees_BTC
# 3302 2018-02-01     153.614337
# 3303 2018-02-02     150.271053
# 3304 2018-02-03     146.927769
# 3305 2018-02-04     141.076100
# 3306 2018-02-05     135.224430

# %% [markdown]
# ### Data total transcation fee vekennen

# %%
# Visualize the time series data
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.plot(daily_fees['Date'], daily_fees['TotalFees_BTC'])
plt.title('Total Transaction Fees (BTC) Over Time')
plt.xlabel('Date')
plt.ylabel('Total Fees (BTC)')
plt.xticks(rotation=45)

# Yearly box plot
plt.subplot(1,2,2)
daily_fees['Year'] = daily_fees['Date'].dt.year
sns.boxplot(x='Year', y='TotalFees_BTC', data=daily_fees)
plt.title('Transaction Fee Distribution by Year')
plt.xlabel('Year')
plt.ylabel('Total Fees (BTC)')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Basic data exploration
print("\nDataset Info:")
print(daily_fees.info())

print("\nBasic Statistics:")
print(daily_fees.describe())

print("\nMissing Values:")
print(daily_fees.isnull().sum())

# Check for outliers using IQR method
Q1 = daily_fees['TotalFees_BTC'].quantile(0.25)
Q3 = daily_fees['TotalFees_BTC'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = daily_fees[(daily_fees['TotalFees_BTC'] < lower_bound) | 
                     (daily_fees['TotalFees_BTC'] > upper_bound)]

print("\nNumber of outliers:", len(outliers))
print("\nPercentage of outliers: {:.2f}%".format((len(outliers)/len(daily_fees))*100))

# Visualize distribution
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.boxplot(y=daily_fees['TotalFees_BTC'])
plt.title('Boxplot of Total Transaction Fees (BTC)')

plt.subplot(1,2,2)
sns.histplot(data=daily_fees, x='TotalFees_BTC', kde=True)
plt.title('Distribution of Total Transaction Fees (BTC)')
plt.tight_layout()
plt.show()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2663 entries, 3302 to 5964
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           2663 non-null   datetime64[ns]
#  1   TotalFees_BTC  2663 non-null   float64
#  2   Year           2663 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(1)
# memory usage: 72.8 KB
# None
#
# Basic Statistics:
#                       Date  TotalFees_BTC         Year
# count                 2663    2663.000000  2663.000000
# mean   2021-09-24 00:00:00      47.943267  2021.241457
# min    2018-02-01 00:00:00       3.148434  2018.000000
# 25%    2019-11-28 12:00:00      15.376604  2019.000000
# 50%    2021-09-24 00:00:00      24.560464  2021.000000
# 75%    2023-07-21 12:00:00      57.387198  2023.000000
# max    2025-05-17 00:00:00    1257.715445  2025.000000
# std                    NaN      67.808544     2.122094
#
# Missing Values:
# Date             0
# TotalFees_BTC    0
# Year             0
# dtype: int64
#
# Number of outliers: 224
#
# Percentage of outliers: 8.41%

# %%
# Print de laatste datum in daily_fees
print(f"Laatste datum in transaction fees data: {daily_fees['Date'].max()}")
# Out:
# Laatste datum in transaction fees data: 2025-05-17 00:00:00

# %% [markdown]
# # Feature Engineering van Mempool Data

# %% [markdown]
# ### Gemiddelde Fee per transaction Feature maken (Feature Engineering) en deze feature data verkennen

# %%
# Hernoem 'date' naar 'Date' in daily_transaction_count voor consistentie
daily_transaction_count = daily_transaction_count.rename(columns={'date': 'Date'})

# Bereken gemiddelde fee per transactie
avg_fees = pd.merge(daily_fees, daily_transaction_count, on='Date', how='inner')
avg_fees['avg_fee_per_tx'] = avg_fees['TotalFees_BTC'] / avg_fees['mempool_transaction_count']

# Print eerste paar rijen om te controleren
print(avg_fees.head())
# Out:
#         Date  TotalFees_BTC  Year  mempool_transaction_count  avg_fee_per_tx
# 0 2018-02-01     153.614337  2018               17755.520833        0.008652
# 1 2018-02-02     150.271053  2018               17401.867188        0.008635
# 2 2018-02-03     146.927769  2018               17048.213542        0.008618
# 3 2018-02-04     141.076100  2018               12023.375000        0.011733
# 4 2018-02-05     135.224430  2018                6998.536458        0.019322

# %%
avg_fees['avg_fee_per_tx_sats'] = avg_fees['avg_fee_per_tx'] * 1e8

print("Gemiddelde fees per transactie (in satoshis):")
print(avg_fees['avg_fee_per_tx_sats'].describe())
# Out:
# Gemiddelde fees per transactie (in satoshis):
# count    2.656000e+03
# mean     4.170535e+05
# std      4.344920e+05
# min      3.077085e+03
# 25%      1.026467e+05
# 50%      3.221100e+05
# 75%      5.540457e+05
# max      4.896868e+06
# Name: avg_fee_per_tx_sats, dtype: float64

# %% [markdown]
# ### Dataset gemiddelde fee per transactie verkennen

# %%
# Visualisatie van gemiddelde transactiekosten
plt.figure(figsize=(12,6))

# Plot 1 -> Time series of average fee per transaction
plt.subplot(1,2,1)
plt.plot(avg_fees['Date'], avg_fees['avg_fee_per_tx'], color='blue', alpha=0.7)
plt.title('Average Transaction Fees Over Time (BTC)')
plt.xticks(rotation=45)
plt.ylabel('Transaction Fee (BTC)')
plt.grid(True, alpha=0.3)

# Plot 2: Boxplot of average fees
plt.subplot(1,2,2)
sns.boxplot(y=avg_fees['avg_fee_per_tx'], color='skyblue')
plt.title('Distribution of Average Transaction Fees')
plt.ylabel('Transaction Fee (BTC)')

plt.tight_layout()
plt.show()

# Histogram and KDE plot
plt.figure(figsize=(12,6))

# Plot 1: Histogram with KDE
plt.subplot(1,2,1)
sns.histplot(data=avg_fees, x='avg_fee_per_tx', kde=True, color='blue', alpha=0.6)
plt.title('Distribution of Average Transaction Fees')
plt.xlabel('Transaction Fee (BTC)')
plt.ylabel('Number of Observations')

# Plot 2: Violin plot
plt.subplot(1,2,2)
sns.violinplot(y=avg_fees['avg_fee_per_tx'], color='skyblue')
plt.title('Violin Plot of Transaction Fees')
plt.ylabel('Transaction Fee (BTC)')

plt.tight_layout()
plt.show()

# Monthly average and trend
plt.figure(figsize=(12,6))

# Plot 1: Monthly average
avg_fees['Month'] = avg_fees['Date'].dt.to_period('M')
monthly_avg = avg_fees.groupby('Month')['avg_fee_per_tx'].mean()

plt.subplot(1,2,1)
plt.plot(monthly_avg.index.astype(str), monthly_avg.values, color='blue', marker='o')
plt.title('Monthly Average of Transaction Fees')
plt.xticks(rotation=45)
plt.ylabel('Average Transaction Fee (BTC)')
plt.grid(True, alpha=0.3)

# Plot 2: Rolling mean
plt.subplot(1,2,2)
plt.plot(avg_fees['Date'], avg_fees['avg_fee_per_tx'].rolling(window=30).mean(), 
         color='blue', label='30-day moving average')
plt.plot(avg_fees['Date'], avg_fees['avg_fee_per_tx'], 
         color='lightgray', alpha=0.5, label='Daily values')
plt.title('Trend in Transaction Fees')
plt.xticks(rotation=45)
plt.ylabel('Transaction Fee (BTC)')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Omzetten van Avg fee per transactie in BTC naar USD

# %%
# Make sure both dataframes have datetime columns with same name
avg_fees['Date'] = pd.to_datetime(avg_fees['Date'])
df_combined['Date'] = pd.to_datetime(df_combined['Timestamp'])

# Merge data on date
merged = pd.merge(avg_fees, df_combined[['Date', 'Close']], on='Date', how='inner')

# Calculate fee in USD
merged['avg_fee_usd'] = merged['avg_fee_per_tx'] * merged['Close']

plt.figure(figsize=(12,6))

# Plot 1: Fees in USD
plt.subplot(1,2,1)
plt.plot(merged['Date'], merged['avg_fee_usd'], color='blue')
plt.title('Average Transaction Fees in USD')
plt.xlabel('Date')
plt.ylabel('Fee (USD)')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)

# Plot 2: Fees in BTC
plt.subplot(1,2,2)
plt.plot(merged['Date'], merged['avg_fee_per_tx'], color='orange')
plt.title('Average Transaction Fees in BTC')
plt.xlabel('Date')
plt.ylabel('Fee (BTC)')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

merged
# Out:
#            Date  TotalFees_BTC  Year  mempool_transaction_count  \
# 0    2018-02-01     153.614337  2018               17755.520833
# 1    2018-02-02     150.271053  2018               17401.867188
# 2    2018-02-03     146.927769  2018               17048.213542
# 3    2018-02-04     141.076100  2018               12023.375000
# 4    2018-02-05     135.224430  2018                6998.536458
# ...         ...            ...   ...                        ...
# 2651 2025-05-06       5.548709  2025                5294.166667
# 2652 2025-05-07       5.988170  2025                4905.541667
# 2653 2025-05-08       6.427630  2025                4516.916667
# 2654 2025-05-09       6.867091  2025                4407.296875
# 2655 2025-05-10       6.718259  2025                4297.677083
#
#       avg_fee_per_tx  avg_fee_per_tx_sats    Month      Close  avg_fee_usd
# 0           0.008652         8.651638e+05  2018-02    8970.00    77.605192
# 1           0.008635         8.635341e+05  2018-02    8580.00    74.091224
# 2           0.008618         8.618367e+05  2018-02    9386.72    80.898202
# 3           0.011733         1.173349e+06  2018-02    8301.65    97.407292
# 4           0.019322         1.932182e+06  2018-02    6877.61   132.887911
# ...              ...                  ...      ...        ...          ...
# 2651        0.001048         1.048080e+05  2025-05   96814.00   101.468797
# 2652        0.001221         1.220695e+05  2025-05   97054.00   118.473324
# 2653        0.001423         1.423013e+05  2025-05  103261.00   146.941729
# 2654        0.001558         1.558119e+05  2025-05  102991.00   160.472189
# 2655        0.001563         1.563230e+05  2025-05  104809.00   163.840616
#
# [2656 rows x 9 columns]

# %% [markdown]
# ### Log transformaties

# %%
# Log transformatie van gemiddelde fees per transactie
avg_fees['avg_fee_per_tx_log'] = np.log1p(avg_fees['avg_fee_per_tx'])

print("Log-getransformeerde gemiddelde fees per transactie:")
print(avg_fees['avg_fee_per_tx_log'].describe())
# Out:
# Log-getransformeerde gemiddelde fees per transactie:
# count    2656.000000
# mean        0.004153
# std         0.004304
# min         0.000031
# 25%         0.001026
# 50%         0.003216
# 75%         0.005525
# max         0.047807
# Name: avg_fee_per_tx_log, dtype: float64

# %%
# Print de laatste datum in avg_fees
print(f"Laatste datum in avg_fees data: {avg_fees['Date'].max()}")
# Out:
# Laatste datum in avg_fees data: 2025-05-10 00:00:00

# %% [markdown]
# Log transformatie van daily mempool size (in bytes)

# %%
# Log transformatie van mempool size
daily_mempoolsize['log_mempool_size'] = np.log1p(daily_mempoolsize['MempoolSizeBytes'])
daily_mempoolsize
# Out:
#       Timestamp  MempoolSizeBytes  log_mempool_size
# 596  2018-02-01      5.210158e+07         17.768706
# 597  2018-02-02      5.232593e+07         17.773003
# 598  2018-02-03      5.255029e+07         17.777281
# 599  2018-02-04      3.624007e+07         17.405676
# 600  2018-02-05      1.992984e+07         16.807729
# ...         ...               ...               ...
# 3247 2025-05-06      2.914383e+06         14.885169
# 3248 2025-05-07      5.357911e+06         15.494085
# 3249 2025-05-08      7.801438e+06         15.869819
# 3250 2025-05-09      7.244612e+06         15.795769
# 3251 2025-05-10      6.687787e+06         15.715794
#
# [2656 rows x 3 columns]

# %% [markdown]
# ### Percentuele verandering per dag van de mempool size in bytes

# %%
# Add percentage change column for mempool size
daily_mempoolsize['mempool_size_pct_change'] = daily_mempoolsize['MempoolSizeBytes'].pct_change().fillna(method='bfill')
daily_mempoolsize
# Out:
# C:\Users\boris\AppData\Local\Temp\ipykernel_15404\2684330719.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_mempoolsize['mempool_size_pct_change'] = daily_mempoolsize['MempoolSizeBytes'].pct_change().fillna(method='bfill')
#       Timestamp  MempoolSizeBytes  log_mempool_size  mempool_size_pct_change
# 596  2018-02-01      5.210158e+07         17.768706                 0.004306
# 597  2018-02-02      5.232593e+07         17.773003                 0.004306
# 598  2018-02-03      5.255029e+07         17.777281                 0.004288
# 599  2018-02-04      3.624007e+07         17.405676                -0.310374
# 600  2018-02-05      1.992984e+07         16.807729                -0.450061
# ...         ...               ...               ...                      ...
# 3247 2025-05-06      2.914383e+06         14.885169                 0.086380
# 3248 2025-05-07      5.357911e+06         15.494085                 0.838437
# 3249 2025-05-08      7.801438e+06         15.869819                 0.456060
# 3250 2025-05-09      7.244612e+06         15.795769                -0.071375
# 3251 2025-05-10      6.687787e+06         15.715794                -0.076861
#
# [2656 rows x 4 columns]

# %%
# Import pandas 
import pandas as pd

# Voeg alle kolommen van avg_fees en daily_mempoolsize samen
mempool_features = pd.merge(avg_fees, daily_mempoolsize, 
                          left_on='Date', right_on='Timestamp', how='inner')

# Verwijder de redundante Timestamp kolom
mempool_features = mempool_features.drop('Timestamp', axis=1)

# Zet Date als index
mempool_features = mempool_features.set_index('Date')

print(mempool_features.head(5))
# Out:
#             TotalFees_BTC  Year  mempool_transaction_count  avg_fee_per_tx  \
# Date
# 2018-02-01     153.614337  2018               17755.520833        0.008652
# 2018-02-02     150.271053  2018               17401.867188        0.008635
# 2018-02-03     146.927769  2018               17048.213542        0.008618
# 2018-02-04     141.076100  2018               12023.375000        0.011733
# 2018-02-05     135.224430  2018                6998.536458        0.019322
#
#             avg_fee_per_tx_sats    Month  avg_fee_per_tx_log  \
# Date
# 2018-02-01         8.651638e+05  2018-02            0.008614
# 2018-02-02         8.635341e+05  2018-02            0.008598
# 2018-02-03         8.618367e+05  2018-02            0.008581
# 2018-02-04         1.173349e+06  2018-02            0.011665
# 2018-02-05         1.932182e+06  2018-02            0.019138
#
#             MempoolSizeBytes  log_mempool_size  mempool_size_pct_change
# Date
# 2018-02-01      5.210158e+07         17.768706                 0.004306
# 2018-02-02      5.232593e+07         17.773003                 0.004306
# 2018-02-03      5.255029e+07         17.777281                 0.004288
# 2018-02-04      3.624007e+07         17.405676                -0.310374
# 2018-02-05      1.992984e+07         16.807729                -0.450061

# %%
merged
# Out:
#            Date  TotalFees_BTC  Year  mempool_transaction_count  \
# 0    2018-02-01     153.614337  2018               17755.520833
# 1    2018-02-02     150.271053  2018               17401.867188
# 2    2018-02-03     146.927769  2018               17048.213542
# 3    2018-02-04     141.076100  2018               12023.375000
# 4    2018-02-05     135.224430  2018                6998.536458
# ...         ...            ...   ...                        ...
# 2651 2025-05-06       5.548709  2025                5294.166667
# 2652 2025-05-07       5.988170  2025                4905.541667
# 2653 2025-05-08       6.427630  2025                4516.916667
# 2654 2025-05-09       6.867091  2025                4407.296875
# 2655 2025-05-10       6.718259  2025                4297.677083
#
#       avg_fee_per_tx  avg_fee_per_tx_sats    Month      Close  avg_fee_usd
# 0           0.008652         8.651638e+05  2018-02    8970.00    77.605192
# 1           0.008635         8.635341e+05  2018-02    8580.00    74.091224
# 2           0.008618         8.618367e+05  2018-02    9386.72    80.898202
# 3           0.011733         1.173349e+06  2018-02    8301.65    97.407292
# 4           0.019322         1.932182e+06  2018-02    6877.61   132.887911
# ...              ...                  ...      ...        ...          ...
# 2651        0.001048         1.048080e+05  2025-05   96814.00   101.468797
# 2652        0.001221         1.220695e+05  2025-05   97054.00   118.473324
# 2653        0.001423         1.423013e+05  2025-05  103261.00   146.941729
# 2654        0.001558         1.558119e+05  2025-05  102991.00   160.472189
# 2655        0.001563         1.563230e+05  2025-05  104809.00   163.840616
#
# [2656 rows x 9 columns]

# %%
# Voeg avg_fee_usd toe aan mempool_features
# We moeten eerst de indexen gelijk maken voordat we de kolom toevoegen
merged_copy = merged.copy()
merged_copy.set_index('Date', inplace=True)

mempool_features['avg_fee_usd'] = merged_copy['avg_fee_usd']

# Print om te controleren
mempool_features
# Out:
#             TotalFees_BTC  Year  mempool_transaction_count  avg_fee_per_tx  \
# Date
# 2018-02-01     153.614337  2018               17755.520833        0.008652
# 2018-02-02     150.271053  2018               17401.867188        0.008635
# 2018-02-03     146.927769  2018               17048.213542        0.008618
# 2018-02-04     141.076100  2018               12023.375000        0.011733
# 2018-02-05     135.224430  2018                6998.536458        0.019322
# ...                   ...   ...                        ...             ...
# 2025-05-06       5.548709  2025                5294.166667        0.001048
# 2025-05-07       5.988170  2025                4905.541667        0.001221
# 2025-05-08       6.427630  2025                4516.916667        0.001423
# 2025-05-09       6.867091  2025                4407.296875        0.001558
# 2025-05-10       6.718259  2025                4297.677083        0.001563
#
#             avg_fee_per_tx_sats    Month  avg_fee_per_tx_log  \
# Date
# 2018-02-01         8.651638e+05  2018-02            0.008614
# 2018-02-02         8.635341e+05  2018-02            0.008598
# 2018-02-03         8.618367e+05  2018-02            0.008581
# 2018-02-04         1.173349e+06  2018-02            0.011665
# 2018-02-05         1.932182e+06  2018-02            0.019138
# ...                         ...      ...                 ...
# 2025-05-06         1.048080e+05  2025-05            0.001048
# 2025-05-07         1.220695e+05  2025-05            0.001220
# 2025-05-08         1.423013e+05  2025-05            0.001422
# 2025-05-09         1.558119e+05  2025-05            0.001557
# 2025-05-10         1.563230e+05  2025-05            0.001562
#
#             MempoolSizeBytes  log_mempool_size  mempool_size_pct_change  \
# Date
# 2018-02-01      5.210158e+07         17.768706                 0.004306
# 2018-02-02      5.232593e+07         17.773003                 0.004306
# 2018-02-03      5.255029e+07         17.777281                 0.004288
# 2018-02-04      3.624007e+07         17.405676                -0.310374
# 2018-02-05      1.992984e+07         16.807729                -0.450061
# ...                      ...               ...                      ...
# 2025-05-06      2.914383e+06         14.885169                 0.086380
# 2025-05-07      5.357911e+06         15.494085                 0.838437
# 2025-05-08      7.801438e+06         15.869819                 0.456060
# 2025-05-09      7.244612e+06         15.795769                -0.071375
# 2025-05-10      6.687787e+06         15.715794                -0.076861
#
#             avg_fee_usd
# Date
# 2018-02-01    77.605192
# 2018-02-02    74.091224
# 2018-02-03    80.898202
# 2018-02-04    97.407292
# 2018-02-05   132.887911
# ...                 ...
# 2025-05-06   101.468797
# 2025-05-07   118.473324
# 2025-05-08   146.941729
# 2025-05-09   160.472189
# 2025-05-10   163.840616
#
# [2656 rows x 11 columns]

# %% [markdown]
# # Nieuw dataset maken met alle nieuwe features
# ### (baseline + mempool features)

# %%
# kopie van df_combined om de originele data te behouden
df_eindmodel = df_combined.copy()

# Merge df_combined met mempool_features op basis van Timestamp/Date
df_eindmodel = pd.merge(
    df_eindmodel,
    mempool_features,
    left_on='Timestamp',
    right_index=True,
    how='inner'
)

# Print eerste paar rijen om te controleren
df_eindmodel
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2651 2025-05-06   94725.00   96895.00   93376.00   96814.00   1074.635037
# 2652 2025-05-07   96815.00   97717.00   95823.00   97054.00   1333.272379
# 2653 2025-05-08   97059.00  104159.00   96907.00  103261.00   2303.463144
# 2654 2025-05-09  103234.00  104332.00  102350.00  102991.00   1336.085909
# 2655 2025-05-10  102992.00  104985.00  102845.00  104809.00    624.265066
#
#                MA7          MA30  fear_greed_index  market_regime  ...  Year  \
# 0     10602.648571  12637.540000              30.0              0  ...  2018
# 1     10250.204286  12429.063333              15.0              0  ...  2018
# 2      9956.165714  12249.274000              40.0              0  ...  2018
# 3      9484.974286  11980.415000              24.0              0  ...  2018
# 4      8862.992857  11650.574333              11.0              0  ...  2018
# ...            ...           ...               ...            ...  ...   ...
# 2651  95630.285714  89083.466667              59.0              0  ...  2025
# 2652  96040.714286  89681.033333              67.0              0  ...  2025
# 2653  97001.571429  90581.600000              65.0              0  ...  2025
# 2654  97868.142857  91261.466667              73.0              0  ...  2025
# 2655  99138.571429  92103.666667              70.0              0  ...  2025
#
#       mempool_transaction_count  avg_fee_per_tx avg_fee_per_tx_sats    Month  \
# 0                  17755.520833        0.008652        8.651638e+05  2018-02
# 1                  17401.867188        0.008635        8.635341e+05  2018-02
# 2                  17048.213542        0.008618        8.618367e+05  2018-02
# 3                  12023.375000        0.011733        1.173349e+06  2018-02
# 4                   6998.536458        0.019322        1.932182e+06  2018-02
# ...                         ...             ...                 ...      ...
# 2651                5294.166667        0.001048        1.048080e+05  2025-05
# 2652                4905.541667        0.001221        1.220695e+05  2025-05
# 2653                4516.916667        0.001423        1.423013e+05  2025-05
# 2654                4407.296875        0.001558        1.558119e+05  2025-05
# 2655                4297.677083        0.001563        1.563230e+05  2025-05
#
#       avg_fee_per_tx_log  MempoolSizeBytes  log_mempool_size  \
# 0               0.008614      5.210158e+07         17.768706
# 1               0.008598      5.232593e+07         17.773003
# 2               0.008581      5.255029e+07         17.777281
# 3               0.011665      3.624007e+07         17.405676
# 4               0.019138      1.992984e+07         16.807729
# ...                  ...               ...               ...
# 2651            0.001048      2.914383e+06         14.885169
# 2652            0.001220      5.357911e+06         15.494085
# 2653            0.001422      7.801438e+06         15.869819
# 2654            0.001557      7.244612e+06         15.795769
# 2655            0.001562      6.687787e+06         15.715794
#
#       mempool_size_pct_change avg_fee_usd
# 0                    0.004306   77.605192
# 1                    0.004306   74.091224
# 2                    0.004288   80.898202
# 3                   -0.310374   97.407292
# 4                   -0.450061  132.887911
# ...                       ...         ...
# 2651                 0.086380  101.468797
# 2652                 0.838437  118.473324
# 2653                 0.456060  146.941729
# 2654                -0.071375  160.472189
# 2655                -0.076861  163.840616
#
# [2656 rows x 25 columns]

# %%
# Print de eerste en laatste datum in de dataset
print(f"Eerste datum in dataset: {df_eindmodel['Timestamp'].min()}")
print(f"Laatste datum in dataset: {df_eindmodel['Timestamp'].max()}")
# Out:
# Eerste datum in dataset: 2018-02-01 00:00:00
# Laatste datum in dataset: 2025-05-10 00:00:00

# %% [markdown]
# ## Model 1 (Baseline + gem fee per transaction)

# %%
df_eindmodel
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2651 2025-05-06   94725.00   96895.00   93376.00   96814.00   1074.635037
# 2652 2025-05-07   96815.00   97717.00   95823.00   97054.00   1333.272379
# 2653 2025-05-08   97059.00  104159.00   96907.00  103261.00   2303.463144
# 2654 2025-05-09  103234.00  104332.00  102350.00  102991.00   1336.085909
# 2655 2025-05-10  102992.00  104985.00  102845.00  104809.00    624.265066
#
#                MA7          MA30  fear_greed_index  market_regime  ...  Year  \
# 0     10602.648571  12637.540000              30.0              0  ...  2018
# 1     10250.204286  12429.063333              15.0              0  ...  2018
# 2      9956.165714  12249.274000              40.0              0  ...  2018
# 3      9484.974286  11980.415000              24.0              0  ...  2018
# 4      8862.992857  11650.574333              11.0              0  ...  2018
# ...            ...           ...               ...            ...  ...   ...
# 2651  95630.285714  89083.466667              59.0              0  ...  2025
# 2652  96040.714286  89681.033333              67.0              0  ...  2025
# 2653  97001.571429  90581.600000              65.0              0  ...  2025
# 2654  97868.142857  91261.466667              73.0              0  ...  2025
# 2655  99138.571429  92103.666667              70.0              0  ...  2025
#
#       mempool_transaction_count  avg_fee_per_tx avg_fee_per_tx_sats    Month  \
# 0                  17755.520833        0.008652        8.651638e+05  2018-02
# 1                  17401.867188        0.008635        8.635341e+05  2018-02
# 2                  17048.213542        0.008618        8.618367e+05  2018-02
# 3                  12023.375000        0.011733        1.173349e+06  2018-02
# 4                   6998.536458        0.019322        1.932182e+06  2018-02
# ...                         ...             ...                 ...      ...
# 2651                5294.166667        0.001048        1.048080e+05  2025-05
# 2652                4905.541667        0.001221        1.220695e+05  2025-05
# 2653                4516.916667        0.001423        1.423013e+05  2025-05
# 2654                4407.296875        0.001558        1.558119e+05  2025-05
# 2655                4297.677083        0.001563        1.563230e+05  2025-05
#
#       avg_fee_per_tx_log  MempoolSizeBytes  log_mempool_size  \
# 0               0.008614      5.210158e+07         17.768706
# 1               0.008598      5.232593e+07         17.773003
# 2               0.008581      5.255029e+07         17.777281
# 3               0.011665      3.624007e+07         17.405676
# 4               0.019138      1.992984e+07         16.807729
# ...                  ...               ...               ...
# 2651            0.001048      2.914383e+06         14.885169
# 2652            0.001220      5.357911e+06         15.494085
# 2653            0.001422      7.801438e+06         15.869819
# 2654            0.001557      7.244612e+06         15.795769
# 2655            0.001562      6.687787e+06         15.715794
#
#       mempool_size_pct_change avg_fee_usd
# 0                    0.004306   77.605192
# 1                    0.004306   74.091224
# 2                    0.004288   80.898202
# 3                   -0.310374   97.407292
# 4                   -0.450061  132.887911
# ...                       ...         ...
# 2651                 0.086380  101.468797
# 2652                 0.838437  118.473324
# 2653                 0.456060  146.941729
# 2654                -0.071375  160.472189
# 2655                -0.076861  163.840616
#
# [2656 rows x 25 columns]

# %%
# Drop  kolommen die ik niet mee wil nemen in model training
columns_to_drop = [
    'return_pct',
    'next_close', 
    'TotalFees_BTC',
    'mempool_transaction_count',
    'avg_fee_per_tx',
    'avg_fee_per_tx_sats',
    'MempoolSizeBytes'
]

df_eindmodel = df_eindmodel.drop(columns=columns_to_drop)

# %%
window_size = 30
feature_columns = [col for col in df_eindmodel.columns if col not in ['Timestamp', 'y']]  # alle inputfeatures

X = []
y = []

for i in range(len(df_eindmodel) - window_size):
    X.append(df_eindmodel[feature_columns].iloc[i:i+window_size].values)
    y.append(df_eindmodel['y'].iloc[i + window_size])  # gebruik bestaande label

X = np.array(X)
y = np.array(y)

print(f'X shape: {X.shape}')
print(f'y shape: {y.shape}')
# Out:
# X shape: (2626, 30, 10)
# y shape: (2626,)

# %%
# Bepaal totale lengte
n_total = X.shape[0]

# Bepaal de indices voor de splitsing (70% train, 15% val, 15% test)
train_end = int(n_total * 0.7)
val_end = int(n_total * 0.85)

# Splits X en y op basis van tijdsvolgorde
X_train, y_train = X[:train_end], y[:train_end]
X_val, y_val = X[train_end:val_end], y[train_end:val_end]
X_test, y_test = X[val_end:], y[val_end:]

# Print shapes om te checken
print("Train:", X_train.shape, y_train.shape)
print("Validation:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# Train: (1838, 30, 10) (1838,)
# Validation: (394, 30, 10) (394,)
# Test: (394, 30, 10) (394,)

# %%
X_train.shape
# Out:
# (1838, 30, 10)

# %%
# Train model met aangepaste parameters
model = XGBClassifier(
    objective='multi:softprob',
    num_class=3,
    random_state=42,
    max_depth=3,              # Maximum depth van bomen
    learning_rate=0.05,        # Learning rate / eta
    n_estimators=120,         # Aantal boosting rondes
    min_child_weight=1,       # Minimum som van instance weight in een child
    gamma=1,                  # Minimum loss reduction voor split
    subsample=0.8,           # Fractie samples voor training
    colsample_bytree=0.6,    # Fractie features per boom
    reg_alpha=0,             # L1 regularization
    reg_lambda=5,            # L2 regularization
    scale_pos_weight=1       # Balans positieve/negatieve weights
)

# learning curves
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

# Training met eval_set
model.fit(
    X_train_flat, 
    y_train_adj,
    sample_weight=sample_weights,
    eval_set=eval_set,
    verbose=True
)

# Plot learning curves
results = model.evals_result()
plt.figure(figsize=(10, 6))
plt.plot(results['validation_0']['mlogloss'], label='Train')
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('Learning Curves met aangepaste parameters')
plt.legend()
plt.grid(True)
plt.show()

# Voorspellingen en evaluatie op validatieset
y_val_pred = model.predict(X_val_flat)
y_val_pred = y_val_pred - 1  # Terug naar originele labels [-1, 0, 1]

print("Validation performance:")
print(classification_report(y_val, y_val_pred))
# Out:
# [0]	validation_0-mlogloss:1.09443	validation_1-mlogloss:1.09857
# [1]	validation_0-mlogloss:1.09062	validation_1-mlogloss:1.09789
# [2]	validation_0-mlogloss:1.08728	validation_1-mlogloss:1.09504
# [3]	validation_0-mlogloss:1.08359	validation_1-mlogloss:1.09481
# [4]	validation_0-mlogloss:1.07982	validation_1-mlogloss:1.09489
# [5]	validation_0-mlogloss:1.07620	validation_1-mlogloss:1.09338
# [6]	validation_0-mlogloss:1.07278	validation_1-mlogloss:1.09298
# [7]	validation_0-mlogloss:1.06922	validation_1-mlogloss:1.09348
# [8]	validation_0-mlogloss:1.06611	validation_1-mlogloss:1.09446
# [9]	validation_0-mlogloss:1.06300	validation_1-mlogloss:1.09349
# [10]	validation_0-mlogloss:1.05998	validation_1-mlogloss:1.09286
# [11]	validation_0-mlogloss:1.05699	validation_1-mlogloss:1.09038
# [12]	validation_0-mlogloss:1.05412	validation_1-mlogloss:1.09022
# [13]	validation_0-mlogloss:1.05140	validation_1-mlogloss:1.09105
# [14]	validation_0-mlogloss:1.04879	validation_1-mlogloss:1.09213
# [15]	validation_0-mlogloss:1.04621	validation_1-mlogloss:1.09041
# [16]	validation_0-mlogloss:1.04358	validation_1-mlogloss:1.08779
# c:\Users\boris\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:34:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [17]	validation_0-mlogloss:1.04110	validation_1-mlogloss:1.08755
# [18]	validation_0-mlogloss:1.03851	validation_1-mlogloss:1.08650
# [19]	validation_0-mlogloss:1.03596	validation_1-mlogloss:1.08544
# [20]	validation_0-mlogloss:1.03346	validation_1-mlogloss:1.08511
# [21]	validation_0-mlogloss:1.03121	validation_1-mlogloss:1.08510
# [22]	validation_0-mlogloss:1.02883	validation_1-mlogloss:1.08404
# [23]	validation_0-mlogloss:1.02625	validation_1-mlogloss:1.08270
# [24]	validation_0-mlogloss:1.02426	validation_1-mlogloss:1.08227
# [25]	validation_0-mlogloss:1.02213	validation_1-mlogloss:1.08070
# [26]	validation_0-mlogloss:1.01982	validation_1-mlogloss:1.08153
# [27]	validation_0-mlogloss:1.01763	validation_1-mlogloss:1.07970
# [28]	validation_0-mlogloss:1.01547	validation_1-mlogloss:1.07802
# [29]	validation_0-mlogloss:1.01268	validation_1-mlogloss:1.07723
# [30]	validation_0-mlogloss:1.01059	validation_1-mlogloss:1.07654
# [31]	validation_0-mlogloss:1.00900	validation_1-mlogloss:1.07635
# [32]	validation_0-mlogloss:1.00696	validation_1-mlogloss:1.07507
# [33]	validation_0-mlogloss:1.00499	validation_1-mlogloss:1.07362
# [34]	validation_0-mlogloss:1.00315	validation_1-mlogloss:1.07188
# [35]	validation_0-mlogloss:1.00128	validation_1-mlogloss:1.07071
# [36]	validation_0-mlogloss:0.99966	validation_1-mlogloss:1.07079
# [37]	validation_0-mlogloss:0.99774	validation_1-mlogloss:1.07078
# [38]	validation_0-mlogloss:0.99567	validation_1-mlogloss:1.07221
# [39]	validation_0-mlogloss:0.99401	validation_1-mlogloss:1.07157
# [40]	validation_0-mlogloss:0.99196	validation_1-mlogloss:1.07166
# [41]	validation_0-mlogloss:0.99025	validation_1-mlogloss:1.07178
# [42]	validation_0-mlogloss:0.98874	validation_1-mlogloss:1.07240
# [43]	validation_0-mlogloss:0.98678	validation_1-mlogloss:1.07120
# [44]	validation_0-mlogloss:0.98499	validation_1-mlogloss:1.07263
# [45]	validation_0-mlogloss:0.98344	validation_1-mlogloss:1.07284
# [46]	validation_0-mlogloss:0.98162	validation_1-mlogloss:1.07324
# [47]	validation_0-mlogloss:0.97986	validation_1-mlogloss:1.07273
# [48]	validation_0-mlogloss:0.97819	validation_1-mlogloss:1.07307
# [49]	validation_0-mlogloss:0.97671	validation_1-mlogloss:1.07274
# [50]	validation_0-mlogloss:0.97526	validation_1-mlogloss:1.07138
# [51]	validation_0-mlogloss:0.97355	validation_1-mlogloss:1.07149
# [52]	validation_0-mlogloss:0.97185	validation_1-mlogloss:1.07087
# [53]	validation_0-mlogloss:0.96994	validation_1-mlogloss:1.07049
# [54]	validation_0-mlogloss:0.96824	validation_1-mlogloss:1.07041
# [55]	validation_0-mlogloss:0.96644	validation_1-mlogloss:1.06945
# [56]	validation_0-mlogloss:0.96479	validation_1-mlogloss:1.06901
# [57]	validation_0-mlogloss:0.96332	validation_1-mlogloss:1.06887
# [58]	validation_0-mlogloss:0.96191	validation_1-mlogloss:1.06889
# [59]	validation_0-mlogloss:0.96032	validation_1-mlogloss:1.06912
# [60]	validation_0-mlogloss:0.95893	validation_1-mlogloss:1.06954
# [61]	validation_0-mlogloss:0.95745	validation_1-mlogloss:1.06949
# [62]	validation_0-mlogloss:0.95565	validation_1-mlogloss:1.06877
# [63]	validation_0-mlogloss:0.95416	validation_1-mlogloss:1.06821
# [64]	validation_0-mlogloss:0.95263	validation_1-mlogloss:1.06869
# [65]	validation_0-mlogloss:0.95105	validation_1-mlogloss:1.06944
# [66]	validation_0-mlogloss:0.94978	validation_1-mlogloss:1.06994
# [67]	validation_0-mlogloss:0.94833	validation_1-mlogloss:1.07090
# [68]	validation_0-mlogloss:0.94671	validation_1-mlogloss:1.07058
# [69]	validation_0-mlogloss:0.94509	validation_1-mlogloss:1.07001
# [70]	validation_0-mlogloss:0.94365	validation_1-mlogloss:1.07080
# [71]	validation_0-mlogloss:0.94201	validation_1-mlogloss:1.07124
# [72]	validation_0-mlogloss:0.94052	validation_1-mlogloss:1.06946
# [73]	validation_0-mlogloss:0.93907	validation_1-mlogloss:1.06967
# [74]	validation_0-mlogloss:0.93776	validation_1-mlogloss:1.06862
# [75]	validation_0-mlogloss:0.93623	validation_1-mlogloss:1.06898
# [76]	validation_0-mlogloss:0.93506	validation_1-mlogloss:1.06727
# [77]	validation_0-mlogloss:0.93377	validation_1-mlogloss:1.06625
# [78]	validation_0-mlogloss:0.93234	validation_1-mlogloss:1.06644
# [79]	validation_0-mlogloss:0.93105	validation_1-mlogloss:1.06706
# [80]	validation_0-mlogloss:0.93014	validation_1-mlogloss:1.06636
# [81]	validation_0-mlogloss:0.92874	validation_1-mlogloss:1.06668
# [82]	validation_0-mlogloss:0.92768	validation_1-mlogloss:1.06705
# [83]	validation_0-mlogloss:0.92622	validation_1-mlogloss:1.06705
# [84]	validation_0-mlogloss:0.92522	validation_1-mlogloss:1.06689
# [85]	validation_0-mlogloss:0.92423	validation_1-mlogloss:1.06712
# [86]	validation_0-mlogloss:0.92293	validation_1-mlogloss:1.06673
# [87]	validation_0-mlogloss:0.92168	validation_1-mlogloss:1.06549
# [88]	validation_0-mlogloss:0.92069	validation_1-mlogloss:1.06540
# [89]	validation_0-mlogloss:0.91957	validation_1-mlogloss:1.06491
# [90]	validation_0-mlogloss:0.91829	validation_1-mlogloss:1.06418
# [91]	validation_0-mlogloss:0.91715	validation_1-mlogloss:1.06423
# [92]	validation_0-mlogloss:0.91560	validation_1-mlogloss:1.06503
# [93]	validation_0-mlogloss:0.91458	validation_1-mlogloss:1.06374
# [94]	validation_0-mlogloss:0.91320	validation_1-mlogloss:1.06269
# [95]	validation_0-mlogloss:0.91216	validation_1-mlogloss:1.06326
# [96]	validation_0-mlogloss:0.91052	validation_1-mlogloss:1.06327
# [97]	validation_0-mlogloss:0.90929	validation_1-mlogloss:1.06433
# [98]	validation_0-mlogloss:0.90800	validation_1-mlogloss:1.06425
# [99]	validation_0-mlogloss:0.90684	validation_1-mlogloss:1.06315
# [100]	validation_0-mlogloss:0.90554	validation_1-mlogloss:1.06245
# [101]	validation_0-mlogloss:0.90438	validation_1-mlogloss:1.06184
# [102]	validation_0-mlogloss:0.90328	validation_1-mlogloss:1.06261
# [103]	validation_0-mlogloss:0.90177	validation_1-mlogloss:1.06278
# [104]	validation_0-mlogloss:0.90055	validation_1-mlogloss:1.06260
# [105]	validation_0-mlogloss:0.89917	validation_1-mlogloss:1.06233
# [106]	validation_0-mlogloss:0.89757	validation_1-mlogloss:1.06264
# [107]	validation_0-mlogloss:0.89625	validation_1-mlogloss:1.06275
# [108]	validation_0-mlogloss:0.89525	validation_1-mlogloss:1.06262
# [109]	validation_0-mlogloss:0.89382	validation_1-mlogloss:1.06269
# [110]	validation_0-mlogloss:0.89289	validation_1-mlogloss:1.06306
# [111]	validation_0-mlogloss:0.89161	validation_1-mlogloss:1.06197
# [112]	validation_0-mlogloss:0.89046	validation_1-mlogloss:1.06214
# [113]	validation_0-mlogloss:0.88903	validation_1-mlogloss:1.06275
# [114]	validation_0-mlogloss:0.88768	validation_1-mlogloss:1.06389
# [115]	validation_0-mlogloss:0.88662	validation_1-mlogloss:1.06368
# [116]	validation_0-mlogloss:0.88546	validation_1-mlogloss:1.06240
# [117]	validation_0-mlogloss:0.88416	validation_1-mlogloss:1.06285
# [118]	validation_0-mlogloss:0.88317	validation_1-mlogloss:1.06423
# [119]	validation_0-mlogloss:0.88213	validation_1-mlogloss:1.06392
# Validation performance:
#               precision    recall  f1-score   support
#
#           -1       0.22      0.40      0.28        90
#            0       0.52      0.39      0.44       186
#            1       0.34      0.26      0.30       118
#
#     accuracy                           0.35       394
#    macro avg       0.36      0.35      0.34       394
# weighted avg       0.40      0.35      0.36       394

# %%
# Labels converteren van [-1, 0, 1] naar [0, 1, 2]
y_train_adj = y_train + 1
y_val_adj = y_val + 1

# Sample weights berekenen op basis van trainingslabels
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_adj)

# Hyperparameter grid
param_dist = {
    'max_depth': [1, 2, 3],
    'learning_rate': [0.01, 0.03, 0.05],
    'n_estimators': [150, 200, 250],
    'subsample': [0.6, 0.7, 0.8],
    'colsample_bytree': [0.6, 0.7, 0.8],
    'reg_alpha': [0.1, 0.5, 1.0],
    'reg_lambda': [5, 10, 20],
    'min_child_weight': [5, 10, 20],
    'gamma': [0.1, 0.5, 1.0]
}

# Basis XGBoost model
xgb_base = XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    eval_metric='mlogloss',
    random_state=42
)

# Randomized search met progress bar
from sklearn.model_selection import RandomizedSearchCV
search = RandomizedSearchCV(
    estimator=xgb_base,
    param_distributions=param_dist,
    n_iter=30,
    scoring='f1_macro',
    cv=3,
    verbose=2,
    n_jobs=1  # Single job to avoid pickling errors
)

# Fit zonder callback (gebruik verbose=2 voor voortgang)
search.fit(X_train_flat, y_train_adj, sample_weight=sample_weights)

# Beste params en score
print("\nBeste hyperparameters:")
for param, value in search.best_params_.items():
    print(f"{param}: {value}")
print(f"\nBeste f1_macro score: {search.best_score_:.4f}")

# Gebruik beste model en train op volledige trainingsset
best_model = search.best_estimator_

# Voeg validatie toe voor learning curves
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

# Training met eval_set
best_model.fit(
    X_train_flat, 
    y_train_adj,
    sample_weight=sample_weights,
    eval_set=eval_set,
    verbose=True
)

# Plot learning curves
results = best_model.evals_result()
plt.figure(figsize=(10, 6))
plt.plot(results['validation_0']['mlogloss'], label='Train')
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('Learning Curves van beste model na RandomizedSearchCV')
plt.legend()
plt.grid(True)
plt.show()

# Voorspellingen en evaluatie op validatieset
y_val_pred = best_model.predict(X_val_flat)
y_val_pred = y_val_pred - 1  # Terug naar originele labels [-1, 0, 1]

print("\nValidation performance van beste model:")
print(classification_report(y_val, y_val_pred))
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [CV] END colsample_bytree=0.8, gamma=1.0, learning_rate=0.01, max_depth=2, min_child_weight=5, n_estimators=250, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=1.0, learning_rate=0.01, max_depth=2, min_child_weight=5, n_estimators=250, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=1.0, learning_rate=0.01, max_depth=2, min_child_weight=5, n_estimators=250, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1.0, reg_lambda=20, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1.0, reg_lambda=20, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=1.0, reg_lambda=20, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   1.5s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=150, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=150, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=150, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=200, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=200, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=200, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.03, max_depth=2, min_child_weight=5, n_estimators=200, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.03, max_depth=2, min_child_weight=5, n_estimators=200, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.03, max_depth=2, min_child_weight=5, n_estimators=200, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.05, max_depth=2, min_child_weight=10, n_estimators=250, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.05, max_depth=2, min_child_weight=10, n_estimators=250, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.05, max_depth=2, min_child_weight=10, n_estimators=250, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=250, reg_alpha=1.0, reg_lambda=5, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=250, reg_alpha=1.0, reg_lambda=5, subsample=0.7; total time=   2.0s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=250, reg_alpha=1.0, reg_lambda=5, subsample=0.7; total time=   2.0s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=1, min_child_weight=5, n_estimators=200, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=1, min_child_weight=5, n_estimators=200, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=1, min_child_weight=5, n_estimators=200, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=2, min_child_weight=10, n_estimators=200, reg_alpha=1.0, reg_lambda=10, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=2, min_child_weight=10, n_estimators=200, reg_alpha=1.0, reg_lambda=10, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=2, min_child_weight=10, n_estimators=200, reg_alpha=1.0, reg_lambda=10, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.05, max_depth=2, min_child_weight=20, n_estimators=150, reg_alpha=1.0, reg_lambda=10, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.05, max_depth=2, min_child_weight=20, n_estimators=150, reg_alpha=1.0, reg_lambda=10, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.05, max_depth=2, min_child_weight=20, n_estimators=150, reg_alpha=1.0, reg_lambda=10, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.05, max_depth=2, min_child_weight=5, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.05, max_depth=2, min_child_weight=5, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.05, max_depth=2, min_child_weight=5, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=250, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=250, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.03, max_depth=3, min_child_weight=5, n_estimators=250, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.8, gamma=1.0, learning_rate=0.05, max_depth=1, min_child_weight=20, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.8, gamma=1.0, learning_rate=0.05, max_depth=1, min_child_weight=20, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=1.0, learning_rate=0.05, max_depth=1, min_child_weight=20, n_estimators=150, reg_alpha=0.5, reg_lambda=10, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=1, min_child_weight=10, n_estimators=250, reg_alpha=0.1, reg_lambda=5, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=1, min_child_weight=10, n_estimators=250, reg_alpha=0.1, reg_lambda=5, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=1, min_child_weight=10, n_estimators=250, reg_alpha=0.1, reg_lambda=5, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=200, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=200, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=200, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   1.6s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=2, min_child_weight=10, n_estimators=150, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=2, min_child_weight=10, n_estimators=150, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.05, max_depth=2, min_child_weight=10, n_estimators=150, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=250, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=250, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   2.4s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=250, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   2.3s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=250, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=250, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   2.4s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.05, max_depth=3, min_child_weight=10, n_estimators=250, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.05, max_depth=1, min_child_weight=5, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.05, max_depth=1, min_child_weight=5, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.05, max_depth=1, min_child_weight=5, n_estimators=150, reg_alpha=0.5, reg_lambda=20, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=200, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=200, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.01, max_depth=3, min_child_weight=10, n_estimators=200, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=2, min_child_weight=20, n_estimators=150, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=2, min_child_weight=20, n_estimators=150, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=2, min_child_weight=20, n_estimators=150, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=250, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=250, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=250, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=20, n_estimators=250, reg_alpha=0.1, reg_lambda=20, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=20, n_estimators=250, reg_alpha=0.1, reg_lambda=20, subsample=0.8; total time=   2.7s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=20, n_estimators=250, reg_alpha=0.1, reg_lambda=20, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.03, max_depth=2, min_child_weight=10, n_estimators=150, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.03, max_depth=2, min_child_weight=10, n_estimators=150, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.03, max_depth=2, min_child_weight=10, n_estimators=150, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=1, min_child_weight=5, n_estimators=250, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=1, min_child_weight=5, n_estimators=250, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=1, min_child_weight=5, n_estimators=250, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=20, n_estimators=250, reg_alpha=1.0, reg_lambda=5, subsample=0.6; total time=   2.5s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=20, n_estimators=250, reg_alpha=1.0, reg_lambda=5, subsample=0.6; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.03, max_depth=3, min_child_weight=20, n_estimators=250, reg_alpha=1.0, reg_lambda=5, subsample=0.6; total time=   2.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=250, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   2.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=250, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   2.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.03, max_depth=3, min_child_weight=10, n_estimators=250, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.03, max_depth=2, min_child_weight=10, n_estimators=200, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.03, max_depth=2, min_child_weight=10, n_estimators=200, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.03, max_depth=2, min_child_weight=10, n_estimators=200, reg_alpha=1.0, reg_lambda=20, subsample=0.7; total time=   1.3s
#
# Beste hyperparameters:
# subsample: 0.7
# reg_lambda: 5
# reg_alpha: 0.1
# n_estimators: 200
# min_child_weight: 5
# max_depth: 3
# learning_rate: 0.05
# gamma: 0.5
# colsample_bytree: 0.6
#
# Beste f1_macro score: 0.3239
# [0]	validation_0-mlogloss:1.09405	validation_1-mlogloss:1.09840
# [1]	validation_0-mlogloss:1.09025	validation_1-mlogloss:1.09790
# [2]	validation_0-mlogloss:1.08654	validation_1-mlogloss:1.09847
# [3]	validation_0-mlogloss:1.08318	validation_1-mlogloss:1.09703
# [4]	validation_0-mlogloss:1.07942	validation_1-mlogloss:1.09658
# [5]	validation_0-mlogloss:1.07615	validation_1-mlogloss:1.09782
# [6]	validation_0-mlogloss:1.07285	validation_1-mlogloss:1.09793
# [7]	validation_0-mlogloss:1.06988	validation_1-mlogloss:1.09735
# [8]	validation_0-mlogloss:1.06697	validation_1-mlogloss:1.09612
# [9]	validation_0-mlogloss:1.06433	validation_1-mlogloss:1.09573
# [10]	validation_0-mlogloss:1.06159	validation_1-mlogloss:1.09304
# [11]	validation_0-mlogloss:1.05899	validation_1-mlogloss:1.09404
# [12]	validation_0-mlogloss:1.05591	validation_1-mlogloss:1.09157
# [13]	validation_0-mlogloss:1.05273	validation_1-mlogloss:1.09065
# [14]	validation_0-mlogloss:1.04967	validation_1-mlogloss:1.09151
# [15]	validation_0-mlogloss:1.04697	validation_1-mlogloss:1.09206
# [16]	validation_0-mlogloss:1.04440	validation_1-mlogloss:1.08995
# [17]	validation_0-mlogloss:1.04225	validation_1-mlogloss:1.08787
# [18]	validation_0-mlogloss:1.03994	validation_1-mlogloss:1.08530
# [19]	validation_0-mlogloss:1.03707	validation_1-mlogloss:1.08404
# [20]	validation_0-mlogloss:1.03472	validation_1-mlogloss:1.08151
# [21]	validation_0-mlogloss:1.03257	validation_1-mlogloss:1.08249
# [22]	validation_0-mlogloss:1.03028	validation_1-mlogloss:1.08214
# [23]	validation_0-mlogloss:1.02790	validation_1-mlogloss:1.08209
# [24]	validation_0-mlogloss:1.02595	validation_1-mlogloss:1.08259
# [25]	validation_0-mlogloss:1.02350	validation_1-mlogloss:1.08136
# [26]	validation_0-mlogloss:1.02107	validation_1-mlogloss:1.08131
# [27]	validation_0-mlogloss:1.01888	validation_1-mlogloss:1.08183
# [28]	validation_0-mlogloss:1.01670	validation_1-mlogloss:1.08214
# [29]	validation_0-mlogloss:1.01469	validation_1-mlogloss:1.08132
# [30]	validation_0-mlogloss:1.01257	validation_1-mlogloss:1.08095
# [31]	validation_0-mlogloss:1.01046	validation_1-mlogloss:1.08271
# [32]	validation_0-mlogloss:1.00856	validation_1-mlogloss:1.08166
# [33]	validation_0-mlogloss:1.00674	validation_1-mlogloss:1.08131
# [34]	validation_0-mlogloss:1.00455	validation_1-mlogloss:1.08152
# [35]	validation_0-mlogloss:1.00289	validation_1-mlogloss:1.08055
# [36]	validation_0-mlogloss:1.00100	validation_1-mlogloss:1.08213
# [37]	validation_0-mlogloss:0.99910	validation_1-mlogloss:1.08115
# [38]	validation_0-mlogloss:0.99713	validation_1-mlogloss:1.08017
# [39]	validation_0-mlogloss:0.99524	validation_1-mlogloss:1.08024
# [40]	validation_0-mlogloss:0.99358	validation_1-mlogloss:1.08241
# [41]	validation_0-mlogloss:0.99158	validation_1-mlogloss:1.08283
# [42]	validation_0-mlogloss:0.98967	validation_1-mlogloss:1.07961
# [43]	validation_0-mlogloss:0.98772	validation_1-mlogloss:1.07993
# [44]	validation_0-mlogloss:0.98595	validation_1-mlogloss:1.08009
# [45]	validation_0-mlogloss:0.98437	validation_1-mlogloss:1.07858
# [46]	validation_0-mlogloss:0.98265	validation_1-mlogloss:1.07696
# [47]	validation_0-mlogloss:0.98095	validation_1-mlogloss:1.07741
# [48]	validation_0-mlogloss:0.97946	validation_1-mlogloss:1.07799
# [49]	validation_0-mlogloss:0.97763	validation_1-mlogloss:1.07837
# [50]	validation_0-mlogloss:0.97607	validation_1-mlogloss:1.07842
# [51]	validation_0-mlogloss:0.97429	validation_1-mlogloss:1.08031
# [52]	validation_0-mlogloss:0.97270	validation_1-mlogloss:1.08176
# [53]	validation_0-mlogloss:0.97139	validation_1-mlogloss:1.08243
# [54]	validation_0-mlogloss:0.97023	validation_1-mlogloss:1.08278
# [55]	validation_0-mlogloss:0.96865	validation_1-mlogloss:1.08328
# [56]	validation_0-mlogloss:0.96731	validation_1-mlogloss:1.08300
# [57]	validation_0-mlogloss:0.96588	validation_1-mlogloss:1.08061
# [58]	validation_0-mlogloss:0.96413	validation_1-mlogloss:1.07896
# [59]	validation_0-mlogloss:0.96297	validation_1-mlogloss:1.07861
# [60]	validation_0-mlogloss:0.96139	validation_1-mlogloss:1.08043
# [61]	validation_0-mlogloss:0.95992	validation_1-mlogloss:1.08176
# [62]	validation_0-mlogloss:0.95857	validation_1-mlogloss:1.08205
# [63]	validation_0-mlogloss:0.95739	validation_1-mlogloss:1.08227
# [64]	validation_0-mlogloss:0.95587	validation_1-mlogloss:1.08128
# [65]	validation_0-mlogloss:0.95403	validation_1-mlogloss:1.08002
# [66]	validation_0-mlogloss:0.95236	validation_1-mlogloss:1.07984
# [67]	validation_0-mlogloss:0.95068	validation_1-mlogloss:1.07980
# [68]	validation_0-mlogloss:0.94975	validation_1-mlogloss:1.07956
# [69]	validation_0-mlogloss:0.94855	validation_1-mlogloss:1.08018
# [70]	validation_0-mlogloss:0.94710	validation_1-mlogloss:1.08097
# [71]	validation_0-mlogloss:0.94556	validation_1-mlogloss:1.08200
# [72]	validation_0-mlogloss:0.94414	validation_1-mlogloss:1.07950
# [73]	validation_0-mlogloss:0.94307	validation_1-mlogloss:1.07937
# [74]	validation_0-mlogloss:0.94156	validation_1-mlogloss:1.07963
# [75]	validation_0-mlogloss:0.94033	validation_1-mlogloss:1.07976
# [76]	validation_0-mlogloss:0.93862	validation_1-mlogloss:1.07833
# [77]	validation_0-mlogloss:0.93705	validation_1-mlogloss:1.07796
# [78]	validation_0-mlogloss:0.93558	validation_1-mlogloss:1.07780
# [79]	validation_0-mlogloss:0.93399	validation_1-mlogloss:1.07688
# [80]	validation_0-mlogloss:0.93244	validation_1-mlogloss:1.07656
# [81]	validation_0-mlogloss:0.93094	validation_1-mlogloss:1.07555
# [82]	validation_0-mlogloss:0.92963	validation_1-mlogloss:1.07535
# [83]	validation_0-mlogloss:0.92878	validation_1-mlogloss:1.07555
# [84]	validation_0-mlogloss:0.92722	validation_1-mlogloss:1.07588
# [85]	validation_0-mlogloss:0.92586	validation_1-mlogloss:1.07455
# [86]	validation_0-mlogloss:0.92431	validation_1-mlogloss:1.07443
# [87]	validation_0-mlogloss:0.92310	validation_1-mlogloss:1.07353
# [88]	validation_0-mlogloss:0.92183	validation_1-mlogloss:1.07238
# [89]	validation_0-mlogloss:0.92052	validation_1-mlogloss:1.07373
# [90]	validation_0-mlogloss:0.91923	validation_1-mlogloss:1.07317
# [91]	validation_0-mlogloss:0.91794	validation_1-mlogloss:1.07343
# [92]	validation_0-mlogloss:0.91670	validation_1-mlogloss:1.07279
# [93]	validation_0-mlogloss:0.91534	validation_1-mlogloss:1.07349
# [94]	validation_0-mlogloss:0.91392	validation_1-mlogloss:1.07282
# [95]	validation_0-mlogloss:0.91269	validation_1-mlogloss:1.07249
# [96]	validation_0-mlogloss:0.91152	validation_1-mlogloss:1.07173
# [97]	validation_0-mlogloss:0.91033	validation_1-mlogloss:1.07060
# [98]	validation_0-mlogloss:0.90936	validation_1-mlogloss:1.07082
# [99]	validation_0-mlogloss:0.90809	validation_1-mlogloss:1.07038
# [100]	validation_0-mlogloss:0.90668	validation_1-mlogloss:1.06874
# [101]	validation_0-mlogloss:0.90534	validation_1-mlogloss:1.06791
# [102]	validation_0-mlogloss:0.90413	validation_1-mlogloss:1.06728
# [103]	validation_0-mlogloss:0.90248	validation_1-mlogloss:1.06690
# [104]	validation_0-mlogloss:0.90132	validation_1-mlogloss:1.06662
# [105]	validation_0-mlogloss:0.90019	validation_1-mlogloss:1.06614
# [106]	validation_0-mlogloss:0.89915	validation_1-mlogloss:1.06565
# [107]	validation_0-mlogloss:0.89786	validation_1-mlogloss:1.06584
# [108]	validation_0-mlogloss:0.89648	validation_1-mlogloss:1.06546
# [109]	validation_0-mlogloss:0.89550	validation_1-mlogloss:1.06455
# [110]	validation_0-mlogloss:0.89435	validation_1-mlogloss:1.06732
# [111]	validation_0-mlogloss:0.89296	validation_1-mlogloss:1.06734
# [112]	validation_0-mlogloss:0.89165	validation_1-mlogloss:1.06800
# [113]	validation_0-mlogloss:0.89041	validation_1-mlogloss:1.06912
# [114]	validation_0-mlogloss:0.88924	validation_1-mlogloss:1.06924
# [115]	validation_0-mlogloss:0.88811	validation_1-mlogloss:1.06973
# [116]	validation_0-mlogloss:0.88664	validation_1-mlogloss:1.07007
# [117]	validation_0-mlogloss:0.88539	validation_1-mlogloss:1.06927
# [118]	validation_0-mlogloss:0.88431	validation_1-mlogloss:1.06915
# [119]	validation_0-mlogloss:0.88310	validation_1-mlogloss:1.06876
# [120]	validation_0-mlogloss:0.88213	validation_1-mlogloss:1.06941
# [121]	validation_0-mlogloss:0.88094	validation_1-mlogloss:1.06972
# [122]	validation_0-mlogloss:0.87982	validation_1-mlogloss:1.06910
# [123]	validation_0-mlogloss:0.87866	validation_1-mlogloss:1.06932
# [124]	validation_0-mlogloss:0.87752	validation_1-mlogloss:1.07012
# [125]	validation_0-mlogloss:0.87638	validation_1-mlogloss:1.07001
# [126]	validation_0-mlogloss:0.87525	validation_1-mlogloss:1.07040
# [127]	validation_0-mlogloss:0.87399	validation_1-mlogloss:1.07020
# [128]	validation_0-mlogloss:0.87292	validation_1-mlogloss:1.06965
# [129]	validation_0-mlogloss:0.87206	validation_1-mlogloss:1.06968
# [130]	validation_0-mlogloss:0.87072	validation_1-mlogloss:1.06995
# [131]	validation_0-mlogloss:0.86986	validation_1-mlogloss:1.07061
# [132]	validation_0-mlogloss:0.86896	validation_1-mlogloss:1.06912
# [133]	validation_0-mlogloss:0.86792	validation_1-mlogloss:1.06933
# [134]	validation_0-mlogloss:0.86689	validation_1-mlogloss:1.06975
# [135]	validation_0-mlogloss:0.86586	validation_1-mlogloss:1.06982
# [136]	validation_0-mlogloss:0.86503	validation_1-mlogloss:1.07035
# [137]	validation_0-mlogloss:0.86366	validation_1-mlogloss:1.07137
# [138]	validation_0-mlogloss:0.86288	validation_1-mlogloss:1.07044
# [139]	validation_0-mlogloss:0.86184	validation_1-mlogloss:1.07060
# [140]	validation_0-mlogloss:0.86104	validation_1-mlogloss:1.07141
# [141]	validation_0-mlogloss:0.85990	validation_1-mlogloss:1.07082
# [142]	validation_0-mlogloss:0.85871	validation_1-mlogloss:1.07029
# [143]	validation_0-mlogloss:0.85742	validation_1-mlogloss:1.06850
# [144]	validation_0-mlogloss:0.85663	validation_1-mlogloss:1.06949
# [145]	validation_0-mlogloss:0.85550	validation_1-mlogloss:1.06910
# [146]	validation_0-mlogloss:0.85456	validation_1-mlogloss:1.06715
# [147]	validation_0-mlogloss:0.85355	validation_1-mlogloss:1.06552
# [148]	validation_0-mlogloss:0.85243	validation_1-mlogloss:1.06660
# [149]	validation_0-mlogloss:0.85132	validation_1-mlogloss:1.06678
# [150]	validation_0-mlogloss:0.85038	validation_1-mlogloss:1.06667
# [151]	validation_0-mlogloss:0.84947	validation_1-mlogloss:1.06667
# [152]	validation_0-mlogloss:0.84851	validation_1-mlogloss:1.06696
# [153]	validation_0-mlogloss:0.84710	validation_1-mlogloss:1.06726
# [154]	validation_0-mlogloss:0.84635	validation_1-mlogloss:1.06755
# [155]	validation_0-mlogloss:0.84522	validation_1-mlogloss:1.06776
# [156]	validation_0-mlogloss:0.84380	validation_1-mlogloss:1.06819
# [157]	validation_0-mlogloss:0.84257	validation_1-mlogloss:1.06763
# [158]	validation_0-mlogloss:0.84164	validation_1-mlogloss:1.06747
# [159]	validation_0-mlogloss:0.84067	validation_1-mlogloss:1.06754
# [160]	validation_0-mlogloss:0.83967	validation_1-mlogloss:1.06856
# [161]	validation_0-mlogloss:0.83850	validation_1-mlogloss:1.06859
# [162]	validation_0-mlogloss:0.83753	validation_1-mlogloss:1.06918
# [163]	validation_0-mlogloss:0.83650	validation_1-mlogloss:1.06897
# [164]	validation_0-mlogloss:0.83562	validation_1-mlogloss:1.07070
# [165]	validation_0-mlogloss:0.83458	validation_1-mlogloss:1.07037
# [166]	validation_0-mlogloss:0.83347	validation_1-mlogloss:1.07057
# [167]	validation_0-mlogloss:0.83231	validation_1-mlogloss:1.07178
# [168]	validation_0-mlogloss:0.83112	validation_1-mlogloss:1.07048
# [169]	validation_0-mlogloss:0.83022	validation_1-mlogloss:1.07097
# [170]	validation_0-mlogloss:0.82929	validation_1-mlogloss:1.07106
# [171]	validation_0-mlogloss:0.82846	validation_1-mlogloss:1.07093
# [172]	validation_0-mlogloss:0.82746	validation_1-mlogloss:1.07226
# [173]	validation_0-mlogloss:0.82635	validation_1-mlogloss:1.07330
# [174]	validation_0-mlogloss:0.82518	validation_1-mlogloss:1.07399
# [175]	validation_0-mlogloss:0.82432	validation_1-mlogloss:1.07443
# [176]	validation_0-mlogloss:0.82328	validation_1-mlogloss:1.07400
# [177]	validation_0-mlogloss:0.82219	validation_1-mlogloss:1.07406
# [178]	validation_0-mlogloss:0.82106	validation_1-mlogloss:1.07332
# [179]	validation_0-mlogloss:0.82004	validation_1-mlogloss:1.07364
# [180]	validation_0-mlogloss:0.81892	validation_1-mlogloss:1.07408
# [181]	validation_0-mlogloss:0.81790	validation_1-mlogloss:1.07312
# [182]	validation_0-mlogloss:0.81709	validation_1-mlogloss:1.07288
# [183]	validation_0-mlogloss:0.81596	validation_1-mlogloss:1.07303
# [184]	validation_0-mlogloss:0.81505	validation_1-mlogloss:1.07284
# [185]	validation_0-mlogloss:0.81414	validation_1-mlogloss:1.07228
# [186]	validation_0-mlogloss:0.81320	validation_1-mlogloss:1.07260
# [187]	validation_0-mlogloss:0.81187	validation_1-mlogloss:1.07181
# [188]	validation_0-mlogloss:0.81112	validation_1-mlogloss:1.07264
# [189]	validation_0-mlogloss:0.81016	validation_1-mlogloss:1.07172
# [190]	validation_0-mlogloss:0.80898	validation_1-mlogloss:1.07040
# [191]	validation_0-mlogloss:0.80808	validation_1-mlogloss:1.06975
# [192]	validation_0-mlogloss:0.80708	validation_1-mlogloss:1.06957
# [193]	validation_0-mlogloss:0.80592	validation_1-mlogloss:1.06918
# [194]	validation_0-mlogloss:0.80487	validation_1-mlogloss:1.06990
# [195]	validation_0-mlogloss:0.80386	validation_1-mlogloss:1.06987
# [196]	validation_0-mlogloss:0.80286	validation_1-mlogloss:1.06923
# [197]	validation_0-mlogloss:0.80184	validation_1-mlogloss:1.06972
# [198]	validation_0-mlogloss:0.80087	validation_1-mlogloss:1.06964
# [199]	validation_0-mlogloss:0.79992	validation_1-mlogloss:1.06905
# Validation performance van beste model:
#               precision    recall  f1-score   support
#
#           -1       0.26      0.39      0.31        90
#            0       0.65      0.47      0.54       186
#            1       0.36      0.38      0.37       118
#
#     accuracy                           0.42       394
#    macro avg       0.42      0.41      0.41       394
# weighted avg       0.47      0.42      0.44       394

# %%
# Labels converteren van [-1, 0, 1] naar [0, 1, 2]
y_train_adj = y_train + 1
y_val_adj = y_val + 1

# Sample weights berekenen op basis van trainingslabels
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_adj)

# XGBoost model met gekozen hyperparameters
model = XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    eval_metric='mlogloss',
    random_state=42,
    subsample=0.8,
    reg_lambda=10,
    reg_alpha=0.5,
    n_estimators=125,
    min_child_weight=20,
    max_depth=3,
    learning_rate=0.05,
    gamma=0.5,
    colsample_bytree=0.7,
    n_jobs=1
)

# Voeg validatie toe voor learning curves
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

# Training met eval_set
model.fit(
    X_train_flat,
    y_train_adj,
    sample_weight=sample_weights,
    eval_set=eval_set,
    verbose=True
)

# Plot learning curves
results = model.evals_result()
plt.figure(figsize=(10, 6))
plt.plot(results['validation_0']['mlogloss'], label='Train')
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('Learning Curves')
plt.legend()
plt.grid(True)
plt.show()

# Voorspellingen en evaluatie op validatieset
y_val_pred = model.predict(X_val_flat)
y_val_pred = y_val_pred - 1  # Terug naar originele labels [-1, 0, 1]

print("\nValidation performance:")
print(classification_report(y_val, y_val_pred))
# Out:
# [0]	validation_0-mlogloss:1.09478	validation_1-mlogloss:1.09747
# [1]	validation_0-mlogloss:1.09077	validation_1-mlogloss:1.09980
# [2]	validation_0-mlogloss:1.08721	validation_1-mlogloss:1.10011
# [3]	validation_0-mlogloss:1.08402	validation_1-mlogloss:1.10069
# [4]	validation_0-mlogloss:1.08109	validation_1-mlogloss:1.10024
# [5]	validation_0-mlogloss:1.07832	validation_1-mlogloss:1.09776
# [6]	validation_0-mlogloss:1.07542	validation_1-mlogloss:1.09587
# [7]	validation_0-mlogloss:1.07275	validation_1-mlogloss:1.09488
# [8]	validation_0-mlogloss:1.07016	validation_1-mlogloss:1.09475
# [9]	validation_0-mlogloss:1.06803	validation_1-mlogloss:1.09419
# [10]	validation_0-mlogloss:1.06542	validation_1-mlogloss:1.09278
# [11]	validation_0-mlogloss:1.06299	validation_1-mlogloss:1.09229
# [12]	validation_0-mlogloss:1.06063	validation_1-mlogloss:1.09005
# [13]	validation_0-mlogloss:1.05816	validation_1-mlogloss:1.09022
# [14]	validation_0-mlogloss:1.05565	validation_1-mlogloss:1.09019
# [15]	validation_0-mlogloss:1.05327	validation_1-mlogloss:1.08930
# [16]	validation_0-mlogloss:1.05108	validation_1-mlogloss:1.09075
# [17]	validation_0-mlogloss:1.04940	validation_1-mlogloss:1.09177
# [18]	validation_0-mlogloss:1.04722	validation_1-mlogloss:1.08976
# [19]	validation_0-mlogloss:1.04501	validation_1-mlogloss:1.08914
# [20]	validation_0-mlogloss:1.04302	validation_1-mlogloss:1.08688
# [21]	validation_0-mlogloss:1.04094	validation_1-mlogloss:1.08677
# [22]	validation_0-mlogloss:1.03922	validation_1-mlogloss:1.08730
# [23]	validation_0-mlogloss:1.03687	validation_1-mlogloss:1.08749
# [24]	validation_0-mlogloss:1.03511	validation_1-mlogloss:1.08596
# [25]	validation_0-mlogloss:1.03293	validation_1-mlogloss:1.08562
# [26]	validation_0-mlogloss:1.03097	validation_1-mlogloss:1.08600
# [27]	validation_0-mlogloss:1.02864	validation_1-mlogloss:1.08703
# [28]	validation_0-mlogloss:1.02668	validation_1-mlogloss:1.08616
# [29]	validation_0-mlogloss:1.02491	validation_1-mlogloss:1.08592
# [30]	validation_0-mlogloss:1.02310	validation_1-mlogloss:1.08534
# [31]	validation_0-mlogloss:1.02157	validation_1-mlogloss:1.08482
# [32]	validation_0-mlogloss:1.01993	validation_1-mlogloss:1.08587
# [33]	validation_0-mlogloss:1.01822	validation_1-mlogloss:1.08678
# [34]	validation_0-mlogloss:1.01692	validation_1-mlogloss:1.08666
# [35]	validation_0-mlogloss:1.01551	validation_1-mlogloss:1.08620
# [36]	validation_0-mlogloss:1.01397	validation_1-mlogloss:1.08512
# [37]	validation_0-mlogloss:1.01242	validation_1-mlogloss:1.08370
# [38]	validation_0-mlogloss:1.01080	validation_1-mlogloss:1.08356
# [39]	validation_0-mlogloss:1.00926	validation_1-mlogloss:1.08433
# [40]	validation_0-mlogloss:1.00778	validation_1-mlogloss:1.08408
# [41]	validation_0-mlogloss:1.00657	validation_1-mlogloss:1.08411
# [42]	validation_0-mlogloss:1.00523	validation_1-mlogloss:1.08486
# [43]	validation_0-mlogloss:1.00360	validation_1-mlogloss:1.08385
# [44]	validation_0-mlogloss:1.00215	validation_1-mlogloss:1.08357
# [45]	validation_0-mlogloss:1.00093	validation_1-mlogloss:1.08344
# [46]	validation_0-mlogloss:0.99938	validation_1-mlogloss:1.08369
# [47]	validation_0-mlogloss:0.99795	validation_1-mlogloss:1.08313
# [48]	validation_0-mlogloss:0.99650	validation_1-mlogloss:1.08446
# [49]	validation_0-mlogloss:0.99519	validation_1-mlogloss:1.08414
# [50]	validation_0-mlogloss:0.99343	validation_1-mlogloss:1.08454
# [51]	validation_0-mlogloss:0.99210	validation_1-mlogloss:1.08315
# [52]	validation_0-mlogloss:0.99062	validation_1-mlogloss:1.08254
# [53]	validation_0-mlogloss:0.98929	validation_1-mlogloss:1.08183
# [54]	validation_0-mlogloss:0.98802	validation_1-mlogloss:1.08232
# [55]	validation_0-mlogloss:0.98660	validation_1-mlogloss:1.08338
# [56]	validation_0-mlogloss:0.98489	validation_1-mlogloss:1.08376
# [57]	validation_0-mlogloss:0.98341	validation_1-mlogloss:1.08329
# [58]	validation_0-mlogloss:0.98207	validation_1-mlogloss:1.08327
# [59]	validation_0-mlogloss:0.98073	validation_1-mlogloss:1.08367
# [60]	validation_0-mlogloss:0.97945	validation_1-mlogloss:1.08299
# [61]	validation_0-mlogloss:0.97808	validation_1-mlogloss:1.08273
# [62]	validation_0-mlogloss:0.97682	validation_1-mlogloss:1.08190
# [63]	validation_0-mlogloss:0.97543	validation_1-mlogloss:1.08091
# [64]	validation_0-mlogloss:0.97425	validation_1-mlogloss:1.07996
# [65]	validation_0-mlogloss:0.97289	validation_1-mlogloss:1.07909
# [66]	validation_0-mlogloss:0.97151	validation_1-mlogloss:1.07923
# [67]	validation_0-mlogloss:0.97014	validation_1-mlogloss:1.07926
# [68]	validation_0-mlogloss:0.96866	validation_1-mlogloss:1.07897
# [69]	validation_0-mlogloss:0.96715	validation_1-mlogloss:1.07840
# [70]	validation_0-mlogloss:0.96571	validation_1-mlogloss:1.07815
# [71]	validation_0-mlogloss:0.96461	validation_1-mlogloss:1.07732
# [72]	validation_0-mlogloss:0.96373	validation_1-mlogloss:1.07808
# [73]	validation_0-mlogloss:0.96240	validation_1-mlogloss:1.07863
# [74]	validation_0-mlogloss:0.96152	validation_1-mlogloss:1.07838
# [75]	validation_0-mlogloss:0.96035	validation_1-mlogloss:1.07818
# [76]	validation_0-mlogloss:0.95917	validation_1-mlogloss:1.07696
# [77]	validation_0-mlogloss:0.95811	validation_1-mlogloss:1.07641
# [78]	validation_0-mlogloss:0.95705	validation_1-mlogloss:1.07679
# [79]	validation_0-mlogloss:0.95593	validation_1-mlogloss:1.07617
# [80]	validation_0-mlogloss:0.95510	validation_1-mlogloss:1.07537
# [81]	validation_0-mlogloss:0.95384	validation_1-mlogloss:1.07436
# [82]	validation_0-mlogloss:0.95293	validation_1-mlogloss:1.07417
# [83]	validation_0-mlogloss:0.95173	validation_1-mlogloss:1.07505
# [84]	validation_0-mlogloss:0.95044	validation_1-mlogloss:1.07581
# [85]	validation_0-mlogloss:0.94952	validation_1-mlogloss:1.07468
# [86]	validation_0-mlogloss:0.94796	validation_1-mlogloss:1.07486
# [87]	validation_0-mlogloss:0.94696	validation_1-mlogloss:1.07497
# [88]	validation_0-mlogloss:0.94600	validation_1-mlogloss:1.07518
# [89]	validation_0-mlogloss:0.94487	validation_1-mlogloss:1.07485
# [90]	validation_0-mlogloss:0.94359	validation_1-mlogloss:1.07472
# [91]	validation_0-mlogloss:0.94258	validation_1-mlogloss:1.07521
# [92]	validation_0-mlogloss:0.94143	validation_1-mlogloss:1.07521
# [93]	validation_0-mlogloss:0.94022	validation_1-mlogloss:1.07474
# [94]	validation_0-mlogloss:0.93924	validation_1-mlogloss:1.07433
# [95]	validation_0-mlogloss:0.93835	validation_1-mlogloss:1.07501
# [96]	validation_0-mlogloss:0.93754	validation_1-mlogloss:1.07426
# [97]	validation_0-mlogloss:0.93645	validation_1-mlogloss:1.07358
# [98]	validation_0-mlogloss:0.93508	validation_1-mlogloss:1.07333
# [99]	validation_0-mlogloss:0.93372	validation_1-mlogloss:1.07296
# [100]	validation_0-mlogloss:0.93245	validation_1-mlogloss:1.07222
# [101]	validation_0-mlogloss:0.93163	validation_1-mlogloss:1.07187
# [102]	validation_0-mlogloss:0.93086	validation_1-mlogloss:1.07174
# [103]	validation_0-mlogloss:0.92989	validation_1-mlogloss:1.07157
# [104]	validation_0-mlogloss:0.92895	validation_1-mlogloss:1.07234
# [105]	validation_0-mlogloss:0.92819	validation_1-mlogloss:1.07271
# [106]	validation_0-mlogloss:0.92750	validation_1-mlogloss:1.07224
# [107]	validation_0-mlogloss:0.92639	validation_1-mlogloss:1.07162
# [108]	validation_0-mlogloss:0.92541	validation_1-mlogloss:1.07111
# [109]	validation_0-mlogloss:0.92437	validation_1-mlogloss:1.07085
# [110]	validation_0-mlogloss:0.92343	validation_1-mlogloss:1.07309
# [111]	validation_0-mlogloss:0.92240	validation_1-mlogloss:1.07398
# [112]	validation_0-mlogloss:0.92111	validation_1-mlogloss:1.07438
# [113]	validation_0-mlogloss:0.92033	validation_1-mlogloss:1.07421
# [114]	validation_0-mlogloss:0.91964	validation_1-mlogloss:1.07504
# [115]	validation_0-mlogloss:0.91870	validation_1-mlogloss:1.07413
# [116]	validation_0-mlogloss:0.91797	validation_1-mlogloss:1.07389
# [117]	validation_0-mlogloss:0.91711	validation_1-mlogloss:1.07429
# [118]	validation_0-mlogloss:0.91631	validation_1-mlogloss:1.07423
# [119]	validation_0-mlogloss:0.91537	validation_1-mlogloss:1.07386
# [120]	validation_0-mlogloss:0.91431	validation_1-mlogloss:1.07427
# [121]	validation_0-mlogloss:0.91339	validation_1-mlogloss:1.07420
# [122]	validation_0-mlogloss:0.91256	validation_1-mlogloss:1.07418
# [123]	validation_0-mlogloss:0.91147	validation_1-mlogloss:1.07432
# [124]	validation_0-mlogloss:0.91057	validation_1-mlogloss:1.07406
# Validation performance:
#               precision    recall  f1-score   support
#
#           -1       0.31      0.58      0.40        90
#            0       0.69      0.47      0.56       186
#            1       0.37      0.31      0.34       118
#
#     accuracy                           0.45       394
#    macro avg       0.46      0.45      0.44       394
# weighted avg       0.51      0.45      0.46       394

# %% [markdown]
# ## Mempool model 1 testen:
# ### Baseline + mempool (avg fee per transactie)

# %%
# Voorspellingen en evaluatie op testset
y_test_pred = model.predict(X_test_flat)
y_test_pred = y_test_pred - 1  # Terug naar originele labels [-1, 0, 1]
# Ensure test predictions and actual labels have same length
y_test_pred = y_test_pred[:len(y_test)]

print("\nTest performance:")
print(classification_report(y_test, y_test_pred))
# Out:
# Test performance:
#               precision    recall  f1-score   support
#
#           -1       0.35      0.84      0.49       120
#            0       0.62      0.35      0.45       158
#            1       0.50      0.06      0.11       116
#
#     accuracy                           0.42       394
#    macro avg       0.49      0.42      0.35       394
# weighted avg       0.50      0.42      0.36       394

# %% [markdown]
# ------------------------------------------------------------------

# %% [markdown]
# ## Model 2 (Baseline Model + mempool size)

# %%
# Log transformatie van mempool size
daily_mempoolsize['log_mempool_size'] = np.log1p(daily_mempoolsize['MempoolSizeBytes'])
daily_mempoolsize
# Out:
#       Timestamp  MempoolSizeBytes  log_mempool_size
# 596  2018-02-01      5.210158e+07         17.768706
# 597  2018-02-02      5.232593e+07         17.773003
# 598  2018-02-03      5.255029e+07         17.777281
# 599  2018-02-04      3.624007e+07         17.405676
# 600  2018-02-05      1.992984e+07         16.807729
# ...         ...               ...               ...
# 3247 2025-05-06      2.914383e+06         14.885169
# 3248 2025-05-07      5.357911e+06         15.494085
# 3249 2025-05-08      7.801438e+06         15.869819
# 3250 2025-05-09      7.244612e+06         15.795769
# 3251 2025-05-10      6.687787e+06         15.715794
#
# [2656 rows x 3 columns]

# %%
# Add percentage change column for mempool size
daily_mempoolsize['mempool_size_pct_change'] = daily_mempoolsize['MempoolSizeBytes'].pct_change().fillna(method='bfill')
daily_mempoolsize
# Out:
# C:\Users\boris\AppData\Local\Temp\ipykernel_10432\2684330719.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   daily_mempoolsize['mempool_size_pct_change'] = daily_mempoolsize['MempoolSizeBytes'].pct_change().fillna(method='bfill')
#       Timestamp  MempoolSizeBytes  log_mempool_size  mempool_size_pct_change
# 596  2018-02-01      5.210158e+07         17.768706                 0.004306
# 597  2018-02-02      5.232593e+07         17.773003                 0.004306
# 598  2018-02-03      5.255029e+07         17.777281                 0.004288
# 599  2018-02-04      3.624007e+07         17.405676                -0.310374
# 600  2018-02-05      1.992984e+07         16.807729                -0.450061
# ...         ...               ...               ...                      ...
# 3247 2025-05-06      2.914383e+06         14.885169                 0.086380
# 3248 2025-05-07      5.357911e+06         15.494085                 0.838437
# 3249 2025-05-08      7.801438e+06         15.869819                 0.456060
# 3250 2025-05-09      7.244612e+06         15.795769                -0.071375
# 3251 2025-05-10      6.687787e+06         15.715794                -0.076861
#
# [2656 rows x 4 columns]

# %%
# Merge mempool features with main dataframe
df_eindmodel = pd.merge(df_eindmodel, 
                       daily_mempoolsize[['Timestamp', 'log_mempool_size', 'mempool_size_pct_change']], 
                       on='Timestamp', 
                       how='left')

# %%
df_eindmodel
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2651 2025-05-06   94725.00   96895.00   93376.00   96814.00   1074.635037
# 2652 2025-05-07   96815.00   97717.00   95823.00   97054.00   1333.272379
# 2653 2025-05-08   97059.00  104159.00   96907.00  103261.00   2303.463144
# 2654 2025-05-09  103234.00  104332.00  102350.00  102991.00   1336.085909
# 2655 2025-05-10  102992.00  104985.00  102845.00  104809.00    624.265066
#
#                MA7          MA30  fear_greed_index  market_regime  y  \
# 0     10602.648571  12637.540000              30.0              0 -1
# 1     10250.204286  12429.063333              15.0              0  1
# 2      9956.165714  12249.274000              40.0              0 -1
# 3      9484.974286  11980.415000              24.0              0 -1
# 4      8862.992857  11650.574333              11.0              0  1
# ...            ...           ...               ...            ... ..
# 2651  95630.285714  89083.466667              59.0              0  0
# 2652  96040.714286  89681.033333              67.0              0  1
# 2653  97001.571429  90581.600000              65.0              0  0
# 2654  97868.142857  91261.466667              73.0              0  1
# 2655  99138.571429  92103.666667              70.0              0  0
#
#       avg_fee_per_tx_log  log_mempool_size  mempool_size_pct_change
# 0               0.008614         17.768706                 0.004306
# 1               0.008598         17.773003                 0.004306
# 2               0.008581         17.777281                 0.004288
# 3               0.011665         17.405676                -0.310374
# 4               0.019138         16.807729                -0.450061
# ...                  ...               ...                      ...
# 2651            0.001048         14.885169                 0.086380
# 2652            0.001220         15.494085                 0.838437
# 2653            0.001422         15.869819                 0.456060
# 2654            0.001557         15.795769                -0.071375
# 2655            0.001562         15.715794                -0.076861
#
# [2656 rows x 14 columns]

# %%
df_eindmodel = df_eindmodel.drop('avg_fee_per_tx_log', axis=1)

# %%
print("Columns in df_eindmodel:")
for col in df_eindmodel.columns:
    print(col)
# Out:
# Columns in df_eindmodel:
# Timestamp
# Open
# High
# Low
# Close
# Volume
# MA7
# MA30
# fear_greed_index
# market_regime
# y
# log_mempool_size
# mempool_size_pct_change

# %%
window_size = 30
feature_columns = [col for col in df_eindmodel.columns if col not in ['Timestamp', 'y']]  # alle inputfeatures

X = []
y = []

for i in range(len(df_eindmodel) - window_size):
    X.append(df_eindmodel[feature_columns].iloc[i:i+window_size].values)
    y.append(df_eindmodel['y'].iloc[i + window_size])  # gebruik bestaande label

X = np.array(X)
y = np.array(y)

print(f'X shape: {X.shape}')
print(f'y shape: {y.shape}')
# Out:
# X shape: (2626, 30, 11)
# y shape: (2626,)

# %%
# Bepaal totale lengte
n_total = X.shape[0]

# Bepaal de indices voor de splitsing (70% train, 15% val, 15% test)
train_end = int(n_total * 0.7)
val_end = int(n_total * 0.85)

# Splits X en y op basis van tijdsvolgorde
X_train, y_train = X[:train_end], y[:train_end]
X_val, y_val = X[train_end:val_end], y[train_end:val_end]
X_test, y_test = X[val_end:], y[val_end:]

# Print shapes om te checken
print("Train:", X_train.shape, y_train.shape)
print("Validation:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# Train: (1838, 30, 11) (1838,)
# Validation: (394, 30, 11) (394,)
# Test: (394, 30, 11) (394,)

# %% [markdown]
# # Model trainen met standaard instellingen:

# %%
# Import required libraries
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_sample_weight

# Labels converteren van [-1, 0, 1] naar [0, 1, 2]
y_train_adj = y_train + 1
y_val_adj = y_val + 1

# Sample weights berekenen op basis van trainingslabels
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_adj)

# Basis XGBoost model met standaard instellingen
model = XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    eval_metric='mlogloss',
    random_state=42
)

# Flatten input data
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat = X_val.reshape(X_val.shape[0], -1)

# Voeg validatie toe voor learning curves
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

# Training met eval_set
model.fit(
    X_train_flat, 
    y_train_adj,
    sample_weight=sample_weights,
    eval_set=eval_set,
    verbose=True
)

# Plot alleen validation loss
results = model.evals_result()
plt.figure(figsize=(10, 6))
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('Learning Curve - Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Voorspellingen en evaluatie op validatieset
y_val_pred = model.predict(X_val_flat)
y_val_pred = y_val_pred - 1  # Terug naar originele labels [-1, 0, 1]
# Out:
# [0]	validation_0-mlogloss:1.01298	validation_1-mlogloss:1.07539
# [1]	validation_0-mlogloss:0.94448	validation_1-mlogloss:1.07289
# [2]	validation_0-mlogloss:0.88190	validation_1-mlogloss:1.09543
# [3]	validation_0-mlogloss:0.82909	validation_1-mlogloss:1.08840
# [4]	validation_0-mlogloss:0.79148	validation_1-mlogloss:1.07803
# [5]	validation_0-mlogloss:0.74998	validation_1-mlogloss:1.07912
# [6]	validation_0-mlogloss:0.72414	validation_1-mlogloss:1.08225
# [7]	validation_0-mlogloss:0.70654	validation_1-mlogloss:1.08585
# [8]	validation_0-mlogloss:0.67655	validation_1-mlogloss:1.08680
# [9]	validation_0-mlogloss:0.65808	validation_1-mlogloss:1.08996
# [10]	validation_0-mlogloss:0.63871	validation_1-mlogloss:1.08990
# [11]	validation_0-mlogloss:0.61898	validation_1-mlogloss:1.09619
# [12]	validation_0-mlogloss:0.59027	validation_1-mlogloss:1.09244
# [13]	validation_0-mlogloss:0.57768	validation_1-mlogloss:1.09904
# [14]	validation_0-mlogloss:0.54862	validation_1-mlogloss:1.09432
# [15]	validation_0-mlogloss:0.52675	validation_1-mlogloss:1.09688
# [16]	validation_0-mlogloss:0.51080	validation_1-mlogloss:1.10067
# [17]	validation_0-mlogloss:0.49433	validation_1-mlogloss:1.10245
# [18]	validation_0-mlogloss:0.48367	validation_1-mlogloss:1.10498
# [19]	validation_0-mlogloss:0.46475	validation_1-mlogloss:1.10586
# [20]	validation_0-mlogloss:0.45412	validation_1-mlogloss:1.10694
# [21]	validation_0-mlogloss:0.44109	validation_1-mlogloss:1.10957
# [22]	validation_0-mlogloss:0.42713	validation_1-mlogloss:1.11506
# [23]	validation_0-mlogloss:0.41207	validation_1-mlogloss:1.12283
# [24]	validation_0-mlogloss:0.40221	validation_1-mlogloss:1.12964
# [25]	validation_0-mlogloss:0.39037	validation_1-mlogloss:1.13061
# [26]	validation_0-mlogloss:0.37927	validation_1-mlogloss:1.13110
# [27]	validation_0-mlogloss:0.36407	validation_1-mlogloss:1.13671
# [28]	validation_0-mlogloss:0.35613	validation_1-mlogloss:1.13691
# [29]	validation_0-mlogloss:0.34335	validation_1-mlogloss:1.13595
# [30]	validation_0-mlogloss:0.33504	validation_1-mlogloss:1.13698
# [31]	validation_0-mlogloss:0.32472	validation_1-mlogloss:1.14494
# [32]	validation_0-mlogloss:0.31210	validation_1-mlogloss:1.14645
# [33]	validation_0-mlogloss:0.30536	validation_1-mlogloss:1.14648
# [34]	validation_0-mlogloss:0.29743	validation_1-mlogloss:1.15171
# [35]	validation_0-mlogloss:0.28944	validation_1-mlogloss:1.15743
# [36]	validation_0-mlogloss:0.28112	validation_1-mlogloss:1.15943
# [37]	validation_0-mlogloss:0.26992	validation_1-mlogloss:1.16428
# [38]	validation_0-mlogloss:0.26321	validation_1-mlogloss:1.16428
# [39]	validation_0-mlogloss:0.25570	validation_1-mlogloss:1.16331
# [40]	validation_0-mlogloss:0.24863	validation_1-mlogloss:1.16643
# [41]	validation_0-mlogloss:0.24072	validation_1-mlogloss:1.16519
# [42]	validation_0-mlogloss:0.23489	validation_1-mlogloss:1.16710
# [43]	validation_0-mlogloss:0.22867	validation_1-mlogloss:1.16808
# [44]	validation_0-mlogloss:0.22201	validation_1-mlogloss:1.16918
# [45]	validation_0-mlogloss:0.21454	validation_1-mlogloss:1.16653
# [46]	validation_0-mlogloss:0.20888	validation_1-mlogloss:1.17045
# [47]	validation_0-mlogloss:0.20319	validation_1-mlogloss:1.17092
# [48]	validation_0-mlogloss:0.19774	validation_1-mlogloss:1.17178
# [49]	validation_0-mlogloss:0.18937	validation_1-mlogloss:1.17012
# [50]	validation_0-mlogloss:0.18459	validation_1-mlogloss:1.17135
# [51]	validation_0-mlogloss:0.17779	validation_1-mlogloss:1.18401
# [52]	validation_0-mlogloss:0.17382	validation_1-mlogloss:1.18327
# [53]	validation_0-mlogloss:0.16984	validation_1-mlogloss:1.18339
# [54]	validation_0-mlogloss:0.16424	validation_1-mlogloss:1.18714
# [55]	validation_0-mlogloss:0.16138	validation_1-mlogloss:1.18870
# [56]	validation_0-mlogloss:0.15838	validation_1-mlogloss:1.19721
# [57]	validation_0-mlogloss:0.15222	validation_1-mlogloss:1.19516
# [58]	validation_0-mlogloss:0.14891	validation_1-mlogloss:1.19279
# [59]	validation_0-mlogloss:0.14379	validation_1-mlogloss:1.19104
# [60]	validation_0-mlogloss:0.13827	validation_1-mlogloss:1.19179
# [61]	validation_0-mlogloss:0.13440	validation_1-mlogloss:1.19489
# [62]	validation_0-mlogloss:0.13024	validation_1-mlogloss:1.18985
# [63]	validation_0-mlogloss:0.12755	validation_1-mlogloss:1.19262
# [64]	validation_0-mlogloss:0.12261	validation_1-mlogloss:1.19182
# [65]	validation_0-mlogloss:0.11985	validation_1-mlogloss:1.19231
# [66]	validation_0-mlogloss:0.11644	validation_1-mlogloss:1.19363
# [67]	validation_0-mlogloss:0.11479	validation_1-mlogloss:1.19508
# [68]	validation_0-mlogloss:0.11130	validation_1-mlogloss:1.19659
# [69]	validation_0-mlogloss:0.10837	validation_1-mlogloss:1.19608
# [70]	validation_0-mlogloss:0.10468	validation_1-mlogloss:1.19555
# [71]	validation_0-mlogloss:0.10133	validation_1-mlogloss:1.19216
# [72]	validation_0-mlogloss:0.09948	validation_1-mlogloss:1.19116
# [73]	validation_0-mlogloss:0.09763	validation_1-mlogloss:1.18974
# [74]	validation_0-mlogloss:0.09498	validation_1-mlogloss:1.19181
# [75]	validation_0-mlogloss:0.09322	validation_1-mlogloss:1.19086
# [76]	validation_0-mlogloss:0.09104	validation_1-mlogloss:1.19346
# [77]	validation_0-mlogloss:0.08855	validation_1-mlogloss:1.19152
# [78]	validation_0-mlogloss:0.08590	validation_1-mlogloss:1.19418
# [79]	validation_0-mlogloss:0.08475	validation_1-mlogloss:1.19630
# [80]	validation_0-mlogloss:0.08233	validation_1-mlogloss:1.19660
# [81]	validation_0-mlogloss:0.08014	validation_1-mlogloss:1.19756
# [82]	validation_0-mlogloss:0.07812	validation_1-mlogloss:1.19706
# [83]	validation_0-mlogloss:0.07636	validation_1-mlogloss:1.20566
# [84]	validation_0-mlogloss:0.07543	validation_1-mlogloss:1.20820
# [85]	validation_0-mlogloss:0.07325	validation_1-mlogloss:1.20793
# [86]	validation_0-mlogloss:0.07187	validation_1-mlogloss:1.20945
# [87]	validation_0-mlogloss:0.07049	validation_1-mlogloss:1.21376
# [88]	validation_0-mlogloss:0.06898	validation_1-mlogloss:1.21376
# [89]	validation_0-mlogloss:0.06701	validation_1-mlogloss:1.21362
# [90]	validation_0-mlogloss:0.06505	validation_1-mlogloss:1.21432
# [91]	validation_0-mlogloss:0.06324	validation_1-mlogloss:1.21523
# [92]	validation_0-mlogloss:0.06195	validation_1-mlogloss:1.22129
# [93]	validation_0-mlogloss:0.06015	validation_1-mlogloss:1.22020
# [94]	validation_0-mlogloss:0.05918	validation_1-mlogloss:1.22057
# [95]	validation_0-mlogloss:0.05778	validation_1-mlogloss:1.22116
# [96]	validation_0-mlogloss:0.05650	validation_1-mlogloss:1.22005
# [97]	validation_0-mlogloss:0.05536	validation_1-mlogloss:1.22902
# [98]	validation_0-mlogloss:0.05368	validation_1-mlogloss:1.22808
# [99]	validation_0-mlogloss:0.05239	validation_1-mlogloss:1.23098

# %% [markdown]
# # Model trainen met Grid Search

# %%
# Labels converteren van [-1, 0, 1] naar [0, 1, 2]
y_train_adj = y_train + 1
y_val_adj = y_val + 1

# Sample weights berekenen op basis van trainingslabels
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_adj)

# Hyperparameter grid
param_dist = {
    'max_depth': [3, 6, 9],
    'learning_rate': [0.008, 0.01, 0.012],
    'n_estimators': [100, 120, 140],
    'subsample': [0.6, 0.7, 0.8],
    'colsample_bytree': [0.6, 0.7, 0.8],
    'reg_alpha': [0.1, 0.5, 1.0],
    'reg_lambda': [5, 10, 20],
    'min_child_weight': [5, 10, 20],
    'gamma': [0.1, 0.5, 1.0]
}

# Basis XGBoost model
xgb_base = XGBClassifier(
    objective='multi:softmax',
    num_class=3,
    eval_metric='mlogloss',
    random_state=42
)

# Flatten input data
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat = X_val.reshape(X_val.shape[0], -1)

# Randomized search met progress bar
search = RandomizedSearchCV(
    estimator=xgb_base,
    param_distributions=param_dist,
    n_iter=30,
    scoring='f1_macro',
    cv=3,
    verbose=2,
    n_jobs=1  
)

# Fit zonder callback (gebruik verbose=2 voor voortgang)
search.fit(X_train_flat, y_train_adj, sample_weight=sample_weights)

# Beste params en score
print("\nBeste hyperparameters:")
for param, value in search.best_params_.items():
    print(f"{param}: {value}")
print(f"\nBeste f1_macro score: {search.best_score_:.4f}")

# Gebruik beste model en train op volledige trainingsset
best_model = search.best_estimator_

# Voeg validatie toe voor learning curves
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

# Training met eval_set
best_model.fit(
    X_train_flat, 
    y_train_adj,
    sample_weight=sample_weights,
    eval_set=eval_set,
    verbose=True
)

# Plot alleen validation loss
results = best_model.evals_result()
plt.figure(figsize=(10, 6))
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('Learning Curve - Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Voorspellingen en evaluatie op validatieset
y_val_pred = best_model.predict(X_val_flat)
y_val_pred = y_val_pred - 1  # Terug naar originele labels [-1, 0, 1]

print("\nValidation performance van beste model:")
print(classification_report(y_val, y_val_pred))
# Out:
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.008, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=20, subsample=0.7; total time=   3.2s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.008, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=20, subsample=0.7; total time=   3.1s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.008, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=20, subsample=0.7; total time=   2.9s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=140, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   4.3s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=140, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   6.2s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=140, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   6.1s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.012, max_depth=6, min_child_weight=10, n_estimators=140, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   4.7s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.012, max_depth=6, min_child_weight=10, n_estimators=140, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   6.8s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.012, max_depth=6, min_child_weight=10, n_estimators=140, reg_alpha=0.1, reg_lambda=10, subsample=0.7; total time=   5.7s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.01, max_depth=3, min_child_weight=20, n_estimators=120, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.01, max_depth=3, min_child_weight=20, n_estimators=120, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.01, max_depth=3, min_child_weight=20, n_estimators=120, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   4.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=20, subsample=0.6; total time=   4.8s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.008, max_depth=3, min_child_weight=20, n_estimators=140, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   2.0s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.008, max_depth=3, min_child_weight=20, n_estimators=140, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   2.0s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.008, max_depth=3, min_child_weight=20, n_estimators=140, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.008, max_depth=3, min_child_weight=10, n_estimators=100, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   1.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.008, max_depth=3, min_child_weight=10, n_estimators=100, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   1.7s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.008, max_depth=3, min_child_weight=10, n_estimators=100, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=6, min_child_weight=20, n_estimators=140, reg_alpha=0.5, reg_lambda=5, subsample=0.7; total time=   4.0s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=6, min_child_weight=20, n_estimators=140, reg_alpha=0.5, reg_lambda=5, subsample=0.7; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=6, min_child_weight=20, n_estimators=140, reg_alpha=0.5, reg_lambda=5, subsample=0.7; total time=   4.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=3, min_child_weight=20, n_estimators=120, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=3, min_child_weight=20, n_estimators=120, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=3, min_child_weight=20, n_estimators=120, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   3.8s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=1.0, reg_lambda=10, subsample=0.8; total time=   5.2s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.008, max_depth=6, min_child_weight=20, n_estimators=140, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.008, max_depth=6, min_child_weight=20, n_estimators=140, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.008, max_depth=6, min_child_weight=20, n_estimators=140, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   4.1s
# [CV] END colsample_bytree=0.8, gamma=1.0, learning_rate=0.008, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   7.0s
# [CV] END colsample_bytree=0.8, gamma=1.0, learning_rate=0.008, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.8, gamma=1.0, learning_rate=0.008, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.012, max_depth=3, min_child_weight=5, n_estimators=120, reg_alpha=0.1, reg_lambda=20, subsample=0.6; total time=   2.0s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.012, max_depth=3, min_child_weight=5, n_estimators=120, reg_alpha=0.1, reg_lambda=20, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0.5, learning_rate=0.012, max_depth=3, min_child_weight=5, n_estimators=120, reg_alpha=0.1, reg_lambda=20, subsample=0.6; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.012, max_depth=6, min_child_weight=5, n_estimators=120, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.012, max_depth=6, min_child_weight=5, n_estimators=120, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   4.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.012, max_depth=6, min_child_weight=5, n_estimators=120, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   4.7s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.012, max_depth=9, min_child_weight=20, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   3.0s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.012, max_depth=9, min_child_weight=20, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   3.2s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.012, max_depth=9, min_child_weight=20, n_estimators=120, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   3.3s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.01, max_depth=6, min_child_weight=20, n_estimators=100, reg_alpha=1.0, reg_lambda=5, subsample=0.7; total time=   2.6s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.01, max_depth=6, min_child_weight=20, n_estimators=100, reg_alpha=1.0, reg_lambda=5, subsample=0.7; total time=   2.6s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.01, max_depth=6, min_child_weight=20, n_estimators=100, reg_alpha=1.0, reg_lambda=5, subsample=0.7; total time=   2.5s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.012, max_depth=9, min_child_weight=10, n_estimators=120, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   4.3s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.012, max_depth=9, min_child_weight=10, n_estimators=120, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   4.4s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.012, max_depth=9, min_child_weight=10, n_estimators=120, reg_alpha=0.1, reg_lambda=10, subsample=0.6; total time=   4.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=6, min_child_weight=5, n_estimators=120, reg_alpha=0.1, reg_lambda=20, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=6, min_child_weight=5, n_estimators=120, reg_alpha=0.1, reg_lambda=20, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=6, min_child_weight=5, n_estimators=120, reg_alpha=0.1, reg_lambda=20, subsample=0.6; total time=   4.2s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=100, reg_alpha=0.5, reg_lambda=5, subsample=0.6; total time=   3.6s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=100, reg_alpha=0.5, reg_lambda=5, subsample=0.6; total time=   3.9s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.01, max_depth=9, min_child_weight=10, n_estimators=100, reg_alpha=0.5, reg_lambda=5, subsample=0.6; total time=   3.8s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=9, min_child_weight=20, n_estimators=120, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   3.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=9, min_child_weight=20, n_estimators=120, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   3.6s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=9, min_child_weight=20, n_estimators=120, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   3.5s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=140, reg_alpha=0.5, reg_lambda=5, subsample=0.7; total time=   1.7s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=140, reg_alpha=0.5, reg_lambda=5, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.7, gamma=0.5, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=140, reg_alpha=0.5, reg_lambda=5, subsample=0.7; total time=   1.9s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.008, max_depth=3, min_child_weight=20, n_estimators=140, reg_alpha=1.0, reg_lambda=20, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.008, max_depth=3, min_child_weight=20, n_estimators=140, reg_alpha=1.0, reg_lambda=20, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0.5, learning_rate=0.008, max_depth=3, min_child_weight=20, n_estimators=140, reg_alpha=1.0, reg_lambda=20, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   6.3s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.008, max_depth=3, min_child_weight=10, n_estimators=140, reg_alpha=1.0, reg_lambda=10, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.008, max_depth=3, min_child_weight=10, n_estimators=140, reg_alpha=1.0, reg_lambda=10, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.7, gamma=1.0, learning_rate=0.008, max_depth=3, min_child_weight=10, n_estimators=140, reg_alpha=1.0, reg_lambda=10, subsample=0.6; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.008, max_depth=6, min_child_weight=10, n_estimators=140, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   4.2s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.008, max_depth=6, min_child_weight=10, n_estimators=140, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   4.3s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.008, max_depth=6, min_child_weight=10, n_estimators=140, reg_alpha=1.0, reg_lambda=5, subsample=0.8; total time=   4.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   3.8s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   3.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.008, max_depth=6, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=10, subsample=0.7; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.008, max_depth=3, min_child_weight=10, n_estimators=100, reg_alpha=0.1, reg_lambda=5, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.008, max_depth=3, min_child_weight=10, n_estimators=100, reg_alpha=0.1, reg_lambda=5, subsample=0.6; total time=   1.3s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.008, max_depth=3, min_child_weight=10, n_estimators=100, reg_alpha=0.1, reg_lambda=5, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.012, max_depth=9, min_child_weight=20, n_estimators=100, reg_alpha=0.1, reg_lambda=20, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.012, max_depth=9, min_child_weight=20, n_estimators=100, reg_alpha=0.1, reg_lambda=20, subsample=0.8; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.012, max_depth=9, min_child_weight=20, n_estimators=100, reg_alpha=0.1, reg_lambda=20, subsample=0.8; total time=   2.8s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.01, max_depth=9, min_child_weight=20, n_estimators=120, reg_alpha=1.0, reg_lambda=20, subsample=0.6; total time=   2.5s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.01, max_depth=9, min_child_weight=20, n_estimators=120, reg_alpha=1.0, reg_lambda=20, subsample=0.6; total time=   2.5s
# [CV] END colsample_bytree=0.6, gamma=1.0, learning_rate=0.01, max_depth=9, min_child_weight=20, n_estimators=120, reg_alpha=1.0, reg_lambda=20, subsample=0.6; total time=   2.4s
#
# Beste hyperparameters:
# subsample: 0.8
# reg_lambda: 5
# reg_alpha: 0.5
# n_estimators: 100
# min_child_weight: 5
# max_depth: 9
# learning_rate: 0.008
# gamma: 1.0
# colsample_bytree: 0.8
#
# Beste f1_macro score: 0.3114
# [0]	validation_0-mlogloss:1.09599	validation_1-mlogloss:1.09812
# [1]	validation_0-mlogloss:1.09353	validation_1-mlogloss:1.09831
# [2]	validation_0-mlogloss:1.09092	validation_1-mlogloss:1.09866
# [3]	validation_0-mlogloss:1.08850	validation_1-mlogloss:1.09866
# [4]	validation_0-mlogloss:1.08593	validation_1-mlogloss:1.09830
# [5]	validation_0-mlogloss:1.08339	validation_1-mlogloss:1.09856
# [6]	validation_0-mlogloss:1.08075	validation_1-mlogloss:1.09792
# [7]	validation_0-mlogloss:1.07826	validation_1-mlogloss:1.09764
# [8]	validation_0-mlogloss:1.07583	validation_1-mlogloss:1.09773
# [9]	validation_0-mlogloss:1.07335	validation_1-mlogloss:1.09811
# [10]	validation_0-mlogloss:1.07090	validation_1-mlogloss:1.09752
# [11]	validation_0-mlogloss:1.06831	validation_1-mlogloss:1.09751
# [12]	validation_0-mlogloss:1.06576	validation_1-mlogloss:1.09691
# [13]	validation_0-mlogloss:1.06351	validation_1-mlogloss:1.09630
# [14]	validation_0-mlogloss:1.06088	validation_1-mlogloss:1.09667
# [15]	validation_0-mlogloss:1.05846	validation_1-mlogloss:1.09652
# [16]	validation_0-mlogloss:1.05612	validation_1-mlogloss:1.09627
# [17]	validation_0-mlogloss:1.05371	validation_1-mlogloss:1.09626
# [18]	validation_0-mlogloss:1.05136	validation_1-mlogloss:1.09552
# [19]	validation_0-mlogloss:1.04913	validation_1-mlogloss:1.09545
# [20]	validation_0-mlogloss:1.04667	validation_1-mlogloss:1.09466
# [21]	validation_0-mlogloss:1.04439	validation_1-mlogloss:1.09412
# [22]	validation_0-mlogloss:1.04203	validation_1-mlogloss:1.09436
# [23]	validation_0-mlogloss:1.03978	validation_1-mlogloss:1.09448
# [24]	validation_0-mlogloss:1.03741	validation_1-mlogloss:1.09383
# [25]	validation_0-mlogloss:1.03509	validation_1-mlogloss:1.09384
# [26]	validation_0-mlogloss:1.03279	validation_1-mlogloss:1.09388
# [27]	validation_0-mlogloss:1.03044	validation_1-mlogloss:1.09393
# [28]	validation_0-mlogloss:1.02817	validation_1-mlogloss:1.09394
# [29]	validation_0-mlogloss:1.02588	validation_1-mlogloss:1.09412
# [30]	validation_0-mlogloss:1.02362	validation_1-mlogloss:1.09316
# [31]	validation_0-mlogloss:1.02137	validation_1-mlogloss:1.09308
# [32]	validation_0-mlogloss:1.01906	validation_1-mlogloss:1.09341
# [33]	validation_0-mlogloss:1.01680	validation_1-mlogloss:1.09333
# [34]	validation_0-mlogloss:1.01454	validation_1-mlogloss:1.09282
# [35]	validation_0-mlogloss:1.01232	validation_1-mlogloss:1.09285
# [36]	validation_0-mlogloss:1.01004	validation_1-mlogloss:1.09217
# [37]	validation_0-mlogloss:1.00770	validation_1-mlogloss:1.09235
# [38]	validation_0-mlogloss:1.00545	validation_1-mlogloss:1.09219
# [39]	validation_0-mlogloss:1.00340	validation_1-mlogloss:1.09190
# [40]	validation_0-mlogloss:1.00119	validation_1-mlogloss:1.09164
# [41]	validation_0-mlogloss:0.99891	validation_1-mlogloss:1.09158
# [42]	validation_0-mlogloss:0.99659	validation_1-mlogloss:1.09208
# [43]	validation_0-mlogloss:0.99449	validation_1-mlogloss:1.09180
# [44]	validation_0-mlogloss:0.99227	validation_1-mlogloss:1.09150
# [45]	validation_0-mlogloss:0.99008	validation_1-mlogloss:1.09111
# [46]	validation_0-mlogloss:0.98788	validation_1-mlogloss:1.09114
# [47]	validation_0-mlogloss:0.98572	validation_1-mlogloss:1.09117
# [48]	validation_0-mlogloss:0.98367	validation_1-mlogloss:1.09178
# [49]	validation_0-mlogloss:0.98158	validation_1-mlogloss:1.09208
# [50]	validation_0-mlogloss:0.97953	validation_1-mlogloss:1.09226
# [51]	validation_0-mlogloss:0.97740	validation_1-mlogloss:1.09258
# [52]	validation_0-mlogloss:0.97532	validation_1-mlogloss:1.09227
# [53]	validation_0-mlogloss:0.97316	validation_1-mlogloss:1.09276
# [54]	validation_0-mlogloss:0.97105	validation_1-mlogloss:1.09307
# [55]	validation_0-mlogloss:0.96890	validation_1-mlogloss:1.09276
# [56]	validation_0-mlogloss:0.96677	validation_1-mlogloss:1.09225
# [57]	validation_0-mlogloss:0.96475	validation_1-mlogloss:1.09252
# [58]	validation_0-mlogloss:0.96259	validation_1-mlogloss:1.09287
# [59]	validation_0-mlogloss:0.96051	validation_1-mlogloss:1.09254
# [60]	validation_0-mlogloss:0.95834	validation_1-mlogloss:1.09271
# [61]	validation_0-mlogloss:0.95619	validation_1-mlogloss:1.09306
# [62]	validation_0-mlogloss:0.95431	validation_1-mlogloss:1.09266
# [63]	validation_0-mlogloss:0.95214	validation_1-mlogloss:1.09236
# [64]	validation_0-mlogloss:0.95024	validation_1-mlogloss:1.09230
# [65]	validation_0-mlogloss:0.94826	validation_1-mlogloss:1.09209
# [66]	validation_0-mlogloss:0.94613	validation_1-mlogloss:1.09246
# [67]	validation_0-mlogloss:0.94417	validation_1-mlogloss:1.09269
# [68]	validation_0-mlogloss:0.94201	validation_1-mlogloss:1.09302
# [69]	validation_0-mlogloss:0.94008	validation_1-mlogloss:1.09260
# [70]	validation_0-mlogloss:0.93819	validation_1-mlogloss:1.09205
# [71]	validation_0-mlogloss:0.93627	validation_1-mlogloss:1.09202
# [72]	validation_0-mlogloss:0.93434	validation_1-mlogloss:1.09211
# [73]	validation_0-mlogloss:0.93240	validation_1-mlogloss:1.09225
# [74]	validation_0-mlogloss:0.93041	validation_1-mlogloss:1.09233
# [75]	validation_0-mlogloss:0.92843	validation_1-mlogloss:1.09230
# [76]	validation_0-mlogloss:0.92652	validation_1-mlogloss:1.09211
# [77]	validation_0-mlogloss:0.92482	validation_1-mlogloss:1.09144
# [78]	validation_0-mlogloss:0.92298	validation_1-mlogloss:1.09108
# [79]	validation_0-mlogloss:0.92111	validation_1-mlogloss:1.09109
# [80]	validation_0-mlogloss:0.91931	validation_1-mlogloss:1.09147
# [81]	validation_0-mlogloss:0.91750	validation_1-mlogloss:1.09197
# [82]	validation_0-mlogloss:0.91561	validation_1-mlogloss:1.09227
# [83]	validation_0-mlogloss:0.91385	validation_1-mlogloss:1.09174
# [84]	validation_0-mlogloss:0.91195	validation_1-mlogloss:1.09222
# [85]	validation_0-mlogloss:0.91004	validation_1-mlogloss:1.09231
# [86]	validation_0-mlogloss:0.90830	validation_1-mlogloss:1.09238
# [87]	validation_0-mlogloss:0.90643	validation_1-mlogloss:1.09205
# [88]	validation_0-mlogloss:0.90466	validation_1-mlogloss:1.09177
# [89]	validation_0-mlogloss:0.90281	validation_1-mlogloss:1.09157
# [90]	validation_0-mlogloss:0.90093	validation_1-mlogloss:1.09169
# [91]	validation_0-mlogloss:0.89911	validation_1-mlogloss:1.09136
# [92]	validation_0-mlogloss:0.89730	validation_1-mlogloss:1.09140
# [93]	validation_0-mlogloss:0.89542	validation_1-mlogloss:1.09094
# [94]	validation_0-mlogloss:0.89365	validation_1-mlogloss:1.09079
# [95]	validation_0-mlogloss:0.89172	validation_1-mlogloss:1.09052
# [96]	validation_0-mlogloss:0.89007	validation_1-mlogloss:1.08969
# [97]	validation_0-mlogloss:0.88822	validation_1-mlogloss:1.08977
# [98]	validation_0-mlogloss:0.88632	validation_1-mlogloss:1.09008
# [99]	validation_0-mlogloss:0.88468	validation_1-mlogloss:1.08982
# Validation performance van beste model:
#               precision    recall  f1-score   support
#
#           -1       0.28      0.47      0.35        90
#            0       0.68      0.39      0.49       186
#            1       0.32      0.38      0.35       118
#
#     accuracy                           0.40       394
#    macro avg       0.43      0.41      0.40       394
# weighted avg       0.48      0.40      0.42       394

# %%
# Train model met aangepaste parameters
model = XGBClassifier(
    objective='multi:softprob',
    num_class=3,
    random_state=42,
    max_depth=20,              # Maximum depth van bomen
    learning_rate=0.005,      # Learning rate / eta
    n_estimators=250,         # Aantal boosting rondes
    min_child_weight=5,       # Minimum som van instance weight in een child
    gamma=0.5,                # Minimum loss reduction voor split
    subsample=0.8,            # Fractie samples voor training
    colsample_bytree=0.8,     # Fractie features per boom
    reg_alpha=0.5,           # L1 regularization
    reg_lambda=5             # L2 regularization
)

# Flatten de 3D input data naar 2D voor XGBoost
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat = X_val.reshape(X_val.shape[0], -1)

# Labels aanpassen van [-1,0,1] naar [0,1,2] voor classificatie
y_train_adj = y_train + 1
y_val_adj = y_val + 1

# Bereken sample weights voor gebalanceerde klassen
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train_adj)

# Voeg validatie toe voor learning curves
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

# Training met eval_set
model.fit(
    X_train_flat, 
    y_train_adj,
    sample_weight=sample_weights,
    eval_set=eval_set,
    verbose=True
)

# Plot learning curves
results = model.evals_result()
plt.figure(figsize=(10, 6))
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('Learning Curve - Validation')
plt.legend()
plt.grid(True)
plt.show()

# Voorspellingen en evaluatie op validatieset
y_val_pred = model.predict(X_val_flat)
y_val_pred = y_val_pred - 1  # Terug naar originele labels [-1, 0, 1]

print("\nValidation performance:")
print(classification_report(y_val, y_val_pred))
# Out:
# [0]	validation_0-mlogloss:1.09686	validation_1-mlogloss:1.09834
# [1]	validation_0-mlogloss:1.09514	validation_1-mlogloss:1.09846
# [2]	validation_0-mlogloss:1.09338	validation_1-mlogloss:1.09839
# [3]	validation_0-mlogloss:1.09165	validation_1-mlogloss:1.09848
# [4]	validation_0-mlogloss:1.08990	validation_1-mlogloss:1.09869
# [5]	validation_0-mlogloss:1.08821	validation_1-mlogloss:1.09886
# [6]	validation_0-mlogloss:1.08643	validation_1-mlogloss:1.09844
# [7]	validation_0-mlogloss:1.08469	validation_1-mlogloss:1.09826
# [8]	validation_0-mlogloss:1.08299	validation_1-mlogloss:1.09835
# [9]	validation_0-mlogloss:1.08131	validation_1-mlogloss:1.09864
# [10]	validation_0-mlogloss:1.07963	validation_1-mlogloss:1.09818
# [11]	validation_0-mlogloss:1.07785	validation_1-mlogloss:1.09832
# [12]	validation_0-mlogloss:1.07610	validation_1-mlogloss:1.09809
# [13]	validation_0-mlogloss:1.07446	validation_1-mlogloss:1.09769
# [14]	validation_0-mlogloss:1.07272	validation_1-mlogloss:1.09790
# [15]	validation_0-mlogloss:1.07104	validation_1-mlogloss:1.09791
# [16]	validation_0-mlogloss:1.06938	validation_1-mlogloss:1.09790
# [17]	validation_0-mlogloss:1.06768	validation_1-mlogloss:1.09809
# [18]	validation_0-mlogloss:1.06600	validation_1-mlogloss:1.09772
# [19]	validation_0-mlogloss:1.06434	validation_1-mlogloss:1.09765
# [20]	validation_0-mlogloss:1.06262	validation_1-mlogloss:1.09720
# [21]	validation_0-mlogloss:1.06095	validation_1-mlogloss:1.09689
# [22]	validation_0-mlogloss:1.05923	validation_1-mlogloss:1.09708
# [23]	validation_0-mlogloss:1.05752	validation_1-mlogloss:1.09703
# [24]	validation_0-mlogloss:1.05586	validation_1-mlogloss:1.09647
# [25]	validation_0-mlogloss:1.05416	validation_1-mlogloss:1.09659
# [26]	validation_0-mlogloss:1.05251	validation_1-mlogloss:1.09655
# [27]	validation_0-mlogloss:1.05084	validation_1-mlogloss:1.09646
# [28]	validation_0-mlogloss:1.04923	validation_1-mlogloss:1.09643
# [29]	validation_0-mlogloss:1.04762	validation_1-mlogloss:1.09613
# [30]	validation_0-mlogloss:1.04599	validation_1-mlogloss:1.09547
# [31]	validation_0-mlogloss:1.04442	validation_1-mlogloss:1.09531
# [32]	validation_0-mlogloss:1.04281	validation_1-mlogloss:1.09522
# [33]	validation_0-mlogloss:1.04122	validation_1-mlogloss:1.09501
# [34]	validation_0-mlogloss:1.03959	validation_1-mlogloss:1.09465
# [35]	validation_0-mlogloss:1.03798	validation_1-mlogloss:1.09456
# [36]	validation_0-mlogloss:1.03636	validation_1-mlogloss:1.09424
# [37]	validation_0-mlogloss:1.03473	validation_1-mlogloss:1.09432
# [38]	validation_0-mlogloss:1.03313	validation_1-mlogloss:1.09423
# [39]	validation_0-mlogloss:1.03151	validation_1-mlogloss:1.09409
# [40]	validation_0-mlogloss:1.02994	validation_1-mlogloss:1.09423
# [41]	validation_0-mlogloss:1.02836	validation_1-mlogloss:1.09411
# [42]	validation_0-mlogloss:1.02676	validation_1-mlogloss:1.09412
# [43]	validation_0-mlogloss:1.02520	validation_1-mlogloss:1.09388
# [44]	validation_0-mlogloss:1.02358	validation_1-mlogloss:1.09381
# [45]	validation_0-mlogloss:1.02197	validation_1-mlogloss:1.09372
# [46]	validation_0-mlogloss:1.02031	validation_1-mlogloss:1.09379
# [47]	validation_0-mlogloss:1.01877	validation_1-mlogloss:1.09398
# [48]	validation_0-mlogloss:1.01721	validation_1-mlogloss:1.09437
# [49]	validation_0-mlogloss:1.01566	validation_1-mlogloss:1.09444
# [50]	validation_0-mlogloss:1.01412	validation_1-mlogloss:1.09454
# [51]	validation_0-mlogloss:1.01257	validation_1-mlogloss:1.09484
# [52]	validation_0-mlogloss:1.01104	validation_1-mlogloss:1.09472
# [53]	validation_0-mlogloss:1.00951	validation_1-mlogloss:1.09502
# [54]	validation_0-mlogloss:1.00793	validation_1-mlogloss:1.09534
# [55]	validation_0-mlogloss:1.00637	validation_1-mlogloss:1.09524
# [56]	validation_0-mlogloss:1.00484	validation_1-mlogloss:1.09490
# [57]	validation_0-mlogloss:1.00333	validation_1-mlogloss:1.09474
# [58]	validation_0-mlogloss:1.00180	validation_1-mlogloss:1.09446
# [59]	validation_0-mlogloss:1.00024	validation_1-mlogloss:1.09432
# [60]	validation_0-mlogloss:0.99869	validation_1-mlogloss:1.09442
# [61]	validation_0-mlogloss:0.99719	validation_1-mlogloss:1.09466
# [62]	validation_0-mlogloss:0.99573	validation_1-mlogloss:1.09429
# [63]	validation_0-mlogloss:0.99420	validation_1-mlogloss:1.09413
# [64]	validation_0-mlogloss:0.99269	validation_1-mlogloss:1.09402
# [65]	validation_0-mlogloss:0.99120	validation_1-mlogloss:1.09377
# [66]	validation_0-mlogloss:0.98966	validation_1-mlogloss:1.09364
# [67]	validation_0-mlogloss:0.98818	validation_1-mlogloss:1.09383
# [68]	validation_0-mlogloss:0.98664	validation_1-mlogloss:1.09373
# [69]	validation_0-mlogloss:0.98514	validation_1-mlogloss:1.09407
# [70]	validation_0-mlogloss:0.98370	validation_1-mlogloss:1.09407
# [71]	validation_0-mlogloss:0.98223	validation_1-mlogloss:1.09385
# [72]	validation_0-mlogloss:0.98075	validation_1-mlogloss:1.09378
# [73]	validation_0-mlogloss:0.97928	validation_1-mlogloss:1.09397
# [74]	validation_0-mlogloss:0.97786	validation_1-mlogloss:1.09422
# [75]	validation_0-mlogloss:0.97640	validation_1-mlogloss:1.09462
# [76]	validation_0-mlogloss:0.97495	validation_1-mlogloss:1.09459
# [77]	validation_0-mlogloss:0.97347	validation_1-mlogloss:1.09422
# [78]	validation_0-mlogloss:0.97196	validation_1-mlogloss:1.09403
# [79]	validation_0-mlogloss:0.97047	validation_1-mlogloss:1.09413
# [80]	validation_0-mlogloss:0.96896	validation_1-mlogloss:1.09406
# [81]	validation_0-mlogloss:0.96754	validation_1-mlogloss:1.09403
# [82]	validation_0-mlogloss:0.96611	validation_1-mlogloss:1.09419
# [83]	validation_0-mlogloss:0.96464	validation_1-mlogloss:1.09419
# [84]	validation_0-mlogloss:0.96321	validation_1-mlogloss:1.09453
# [85]	validation_0-mlogloss:0.96177	validation_1-mlogloss:1.09460
# [86]	validation_0-mlogloss:0.96033	validation_1-mlogloss:1.09480
# [87]	validation_0-mlogloss:0.95890	validation_1-mlogloss:1.09461
# [88]	validation_0-mlogloss:0.95748	validation_1-mlogloss:1.09442
# [89]	validation_0-mlogloss:0.95606	validation_1-mlogloss:1.09443
# [90]	validation_0-mlogloss:0.95461	validation_1-mlogloss:1.09454
# [91]	validation_0-mlogloss:0.95315	validation_1-mlogloss:1.09477
# [92]	validation_0-mlogloss:0.95177	validation_1-mlogloss:1.09483
# [93]	validation_0-mlogloss:0.95032	validation_1-mlogloss:1.09487
# [94]	validation_0-mlogloss:0.94891	validation_1-mlogloss:1.09510
# [95]	validation_0-mlogloss:0.94749	validation_1-mlogloss:1.09495
# [96]	validation_0-mlogloss:0.94605	validation_1-mlogloss:1.09470
# [97]	validation_0-mlogloss:0.94456	validation_1-mlogloss:1.09501
# [98]	validation_0-mlogloss:0.94310	validation_1-mlogloss:1.09507
# [99]	validation_0-mlogloss:0.94170	validation_1-mlogloss:1.09502
# [100]	validation_0-mlogloss:0.94026	validation_1-mlogloss:1.09495
# [101]	validation_0-mlogloss:0.93886	validation_1-mlogloss:1.09510
# [102]	validation_0-mlogloss:0.93746	validation_1-mlogloss:1.09523
# [103]	validation_0-mlogloss:0.93610	validation_1-mlogloss:1.09531
# [104]	validation_0-mlogloss:0.93470	validation_1-mlogloss:1.09526
# [105]	validation_0-mlogloss:0.93333	validation_1-mlogloss:1.09522
# [106]	validation_0-mlogloss:0.93203	validation_1-mlogloss:1.09496
# [107]	validation_0-mlogloss:0.93064	validation_1-mlogloss:1.09492
# [108]	validation_0-mlogloss:0.92927	validation_1-mlogloss:1.09515
# [109]	validation_0-mlogloss:0.92786	validation_1-mlogloss:1.09495
# [110]	validation_0-mlogloss:0.92657	validation_1-mlogloss:1.09501
# [111]	validation_0-mlogloss:0.92525	validation_1-mlogloss:1.09512
# [112]	validation_0-mlogloss:0.92390	validation_1-mlogloss:1.09535
# [113]	validation_0-mlogloss:0.92259	validation_1-mlogloss:1.09541
# [114]	validation_0-mlogloss:0.92127	validation_1-mlogloss:1.09504
# [115]	validation_0-mlogloss:0.91991	validation_1-mlogloss:1.09461
# [116]	validation_0-mlogloss:0.91852	validation_1-mlogloss:1.09417
# [117]	validation_0-mlogloss:0.91716	validation_1-mlogloss:1.09401
# [118]	validation_0-mlogloss:0.91585	validation_1-mlogloss:1.09355
# [119]	validation_0-mlogloss:0.91451	validation_1-mlogloss:1.09331
# [120]	validation_0-mlogloss:0.91315	validation_1-mlogloss:1.09333
# [121]	validation_0-mlogloss:0.91184	validation_1-mlogloss:1.09334
# [122]	validation_0-mlogloss:0.91050	validation_1-mlogloss:1.09359
# [123]	validation_0-mlogloss:0.90919	validation_1-mlogloss:1.09360
# [124]	validation_0-mlogloss:0.90788	validation_1-mlogloss:1.09343
# [125]	validation_0-mlogloss:0.90657	validation_1-mlogloss:1.09349
# [126]	validation_0-mlogloss:0.90526	validation_1-mlogloss:1.09337
# [127]	validation_0-mlogloss:0.90398	validation_1-mlogloss:1.09400
# [128]	validation_0-mlogloss:0.90265	validation_1-mlogloss:1.09398
# [129]	validation_0-mlogloss:0.90137	validation_1-mlogloss:1.09408
# [130]	validation_0-mlogloss:0.90006	validation_1-mlogloss:1.09444
# [131]	validation_0-mlogloss:0.89872	validation_1-mlogloss:1.09472
# [132]	validation_0-mlogloss:0.89745	validation_1-mlogloss:1.09492
# [133]	validation_0-mlogloss:0.89615	validation_1-mlogloss:1.09483
# [134]	validation_0-mlogloss:0.89490	validation_1-mlogloss:1.09477
# [135]	validation_0-mlogloss:0.89360	validation_1-mlogloss:1.09493
# [136]	validation_0-mlogloss:0.89232	validation_1-mlogloss:1.09484
# [137]	validation_0-mlogloss:0.89105	validation_1-mlogloss:1.09465
# [138]	validation_0-mlogloss:0.88980	validation_1-mlogloss:1.09492
# [139]	validation_0-mlogloss:0.88853	validation_1-mlogloss:1.09526
# [140]	validation_0-mlogloss:0.88725	validation_1-mlogloss:1.09492
# [141]	validation_0-mlogloss:0.88603	validation_1-mlogloss:1.09495
# [142]	validation_0-mlogloss:0.88476	validation_1-mlogloss:1.09472
# [143]	validation_0-mlogloss:0.88348	validation_1-mlogloss:1.09434
# [144]	validation_0-mlogloss:0.88221	validation_1-mlogloss:1.09400
# [145]	validation_0-mlogloss:0.88098	validation_1-mlogloss:1.09415
# [146]	validation_0-mlogloss:0.87973	validation_1-mlogloss:1.09419
# [147]	validation_0-mlogloss:0.87849	validation_1-mlogloss:1.09431
# [148]	validation_0-mlogloss:0.87722	validation_1-mlogloss:1.09432
# [149]	validation_0-mlogloss:0.87593	validation_1-mlogloss:1.09391
# [150]	validation_0-mlogloss:0.87471	validation_1-mlogloss:1.09388
# [151]	validation_0-mlogloss:0.87350	validation_1-mlogloss:1.09392
# [152]	validation_0-mlogloss:0.87229	validation_1-mlogloss:1.09388
# [153]	validation_0-mlogloss:0.87104	validation_1-mlogloss:1.09396
# [154]	validation_0-mlogloss:0.86981	validation_1-mlogloss:1.09404
# [155]	validation_0-mlogloss:0.86861	validation_1-mlogloss:1.09392
# [156]	validation_0-mlogloss:0.86738	validation_1-mlogloss:1.09365
# [157]	validation_0-mlogloss:0.86622	validation_1-mlogloss:1.09365
# [158]	validation_0-mlogloss:0.86496	validation_1-mlogloss:1.09349
# [159]	validation_0-mlogloss:0.86372	validation_1-mlogloss:1.09331
# [160]	validation_0-mlogloss:0.86256	validation_1-mlogloss:1.09326
# [161]	validation_0-mlogloss:0.86133	validation_1-mlogloss:1.09333
# [162]	validation_0-mlogloss:0.86015	validation_1-mlogloss:1.09300
# [163]	validation_0-mlogloss:0.85895	validation_1-mlogloss:1.09265
# [164]	validation_0-mlogloss:0.85775	validation_1-mlogloss:1.09246
# [165]	validation_0-mlogloss:0.85660	validation_1-mlogloss:1.09256
# [166]	validation_0-mlogloss:0.85537	validation_1-mlogloss:1.09276
# [167]	validation_0-mlogloss:0.85416	validation_1-mlogloss:1.09284
# [168]	validation_0-mlogloss:0.85298	validation_1-mlogloss:1.09276
# [169]	validation_0-mlogloss:0.85183	validation_1-mlogloss:1.09265
# [170]	validation_0-mlogloss:0.85065	validation_1-mlogloss:1.09258
# [171]	validation_0-mlogloss:0.84946	validation_1-mlogloss:1.09265
# [172]	validation_0-mlogloss:0.84825	validation_1-mlogloss:1.09274
# [173]	validation_0-mlogloss:0.84711	validation_1-mlogloss:1.09303
# [174]	validation_0-mlogloss:0.84589	validation_1-mlogloss:1.09307
# [175]	validation_0-mlogloss:0.84473	validation_1-mlogloss:1.09283
# [176]	validation_0-mlogloss:0.84350	validation_1-mlogloss:1.09271
# [177]	validation_0-mlogloss:0.84233	validation_1-mlogloss:1.09260
# [178]	validation_0-mlogloss:0.84117	validation_1-mlogloss:1.09284
# [179]	validation_0-mlogloss:0.84001	validation_1-mlogloss:1.09256
# [180]	validation_0-mlogloss:0.83882	validation_1-mlogloss:1.09286
# [181]	validation_0-mlogloss:0.83768	validation_1-mlogloss:1.09289
# [182]	validation_0-mlogloss:0.83656	validation_1-mlogloss:1.09316
# [183]	validation_0-mlogloss:0.83538	validation_1-mlogloss:1.09312
# [184]	validation_0-mlogloss:0.83426	validation_1-mlogloss:1.09296
# [185]	validation_0-mlogloss:0.83311	validation_1-mlogloss:1.09268
# [186]	validation_0-mlogloss:0.83195	validation_1-mlogloss:1.09245
# [187]	validation_0-mlogloss:0.83076	validation_1-mlogloss:1.09206
# [188]	validation_0-mlogloss:0.82964	validation_1-mlogloss:1.09216
# [189]	validation_0-mlogloss:0.82849	validation_1-mlogloss:1.09229
# [190]	validation_0-mlogloss:0.82733	validation_1-mlogloss:1.09241
# [191]	validation_0-mlogloss:0.82616	validation_1-mlogloss:1.09213
# [192]	validation_0-mlogloss:0.82502	validation_1-mlogloss:1.09210
# [193]	validation_0-mlogloss:0.82387	validation_1-mlogloss:1.09211
# [194]	validation_0-mlogloss:0.82274	validation_1-mlogloss:1.09216
# [195]	validation_0-mlogloss:0.82167	validation_1-mlogloss:1.09230
# [196]	validation_0-mlogloss:0.82057	validation_1-mlogloss:1.09191
# [197]	validation_0-mlogloss:0.81947	validation_1-mlogloss:1.09202
# [198]	validation_0-mlogloss:0.81838	validation_1-mlogloss:1.09191
# [199]	validation_0-mlogloss:0.81725	validation_1-mlogloss:1.09160
# [200]	validation_0-mlogloss:0.81609	validation_1-mlogloss:1.09183
# [201]	validation_0-mlogloss:0.81493	validation_1-mlogloss:1.09196
# [202]	validation_0-mlogloss:0.81383	validation_1-mlogloss:1.09214
# [203]	validation_0-mlogloss:0.81275	validation_1-mlogloss:1.09190
# [204]	validation_0-mlogloss:0.81159	validation_1-mlogloss:1.09195
# [205]	validation_0-mlogloss:0.81049	validation_1-mlogloss:1.09209
# [206]	validation_0-mlogloss:0.80940	validation_1-mlogloss:1.09193
# [207]	validation_0-mlogloss:0.80834	validation_1-mlogloss:1.09241
# [208]	validation_0-mlogloss:0.80725	validation_1-mlogloss:1.09260
# [209]	validation_0-mlogloss:0.80612	validation_1-mlogloss:1.09262
# [210]	validation_0-mlogloss:0.80503	validation_1-mlogloss:1.09232
# [211]	validation_0-mlogloss:0.80401	validation_1-mlogloss:1.09196
# [212]	validation_0-mlogloss:0.80291	validation_1-mlogloss:1.09179
# [213]	validation_0-mlogloss:0.80184	validation_1-mlogloss:1.09194
# [214]	validation_0-mlogloss:0.80075	validation_1-mlogloss:1.09182
# [215]	validation_0-mlogloss:0.79967	validation_1-mlogloss:1.09154
# [216]	validation_0-mlogloss:0.79861	validation_1-mlogloss:1.09133
# [217]	validation_0-mlogloss:0.79754	validation_1-mlogloss:1.09132
# [218]	validation_0-mlogloss:0.79647	validation_1-mlogloss:1.09133
# [219]	validation_0-mlogloss:0.79540	validation_1-mlogloss:1.09146
# [220]	validation_0-mlogloss:0.79436	validation_1-mlogloss:1.09127
# [221]	validation_0-mlogloss:0.79331	validation_1-mlogloss:1.09146
# [222]	validation_0-mlogloss:0.79224	validation_1-mlogloss:1.09111
# [223]	validation_0-mlogloss:0.79116	validation_1-mlogloss:1.09110
# [224]	validation_0-mlogloss:0.79009	validation_1-mlogloss:1.09108
# [225]	validation_0-mlogloss:0.78902	validation_1-mlogloss:1.09125
# [226]	validation_0-mlogloss:0.78799	validation_1-mlogloss:1.09110
# [227]	validation_0-mlogloss:0.78696	validation_1-mlogloss:1.09103
# [228]	validation_0-mlogloss:0.78592	validation_1-mlogloss:1.09112
# [229]	validation_0-mlogloss:0.78488	validation_1-mlogloss:1.09112
# [230]	validation_0-mlogloss:0.78380	validation_1-mlogloss:1.09138
# [231]	validation_0-mlogloss:0.78276	validation_1-mlogloss:1.09113
# [232]	validation_0-mlogloss:0.78173	validation_1-mlogloss:1.09110
# [233]	validation_0-mlogloss:0.78070	validation_1-mlogloss:1.09086
# [234]	validation_0-mlogloss:0.77968	validation_1-mlogloss:1.09088
# [235]	validation_0-mlogloss:0.77863	validation_1-mlogloss:1.09107
# [236]	validation_0-mlogloss:0.77760	validation_1-mlogloss:1.09087
# [237]	validation_0-mlogloss:0.77656	validation_1-mlogloss:1.09090
# [238]	validation_0-mlogloss:0.77552	validation_1-mlogloss:1.09085
# [239]	validation_0-mlogloss:0.77447	validation_1-mlogloss:1.09093
# [240]	validation_0-mlogloss:0.77347	validation_1-mlogloss:1.09084
# [241]	validation_0-mlogloss:0.77244	validation_1-mlogloss:1.09076
# [242]	validation_0-mlogloss:0.77134	validation_1-mlogloss:1.09055
# [243]	validation_0-mlogloss:0.77031	validation_1-mlogloss:1.09042
# [244]	validation_0-mlogloss:0.76929	validation_1-mlogloss:1.09056
# [245]	validation_0-mlogloss:0.76826	validation_1-mlogloss:1.09033
# [246]	validation_0-mlogloss:0.76727	validation_1-mlogloss:1.09022
# [247]	validation_0-mlogloss:0.76627	validation_1-mlogloss:1.09024
# [248]	validation_0-mlogloss:0.76525	validation_1-mlogloss:1.09039
# [249]	validation_0-mlogloss:0.76424	validation_1-mlogloss:1.09050
# Validation performance:
#               precision    recall  f1-score   support
#
#           -1       0.28      0.59      0.38        90
#            0       0.68      0.37      0.48       186
#            1       0.34      0.31      0.32       118
#
#     accuracy                           0.40       394
#    macro avg       0.43      0.42      0.39       394
# weighted avg       0.49      0.40      0.41       394

# %% [markdown]
# ## Mepool Model 2 testen:
# ### Baseline + mempool size features (log en percentuele verandering)

# %%
# Voorspellingen en evaluatie op testset
X_test_flat = X_test.reshape(X_test.shape[0], -1)
y_test_pred = model.predict(X_test_flat)
y_test_pred = y_test_pred - 1  # Terug naar originele labels [-1, 0, 1]

print("\nTest performance:")
print(classification_report(y_test, y_test_pred))
# Out:
# Test performance:
#               precision    recall  f1-score   support
#
#           -1       0.33      0.82      0.47       120
#            0       0.62      0.33      0.43       158
#            1       0.31      0.04      0.08       116
#
#     accuracy                           0.39       394
#    macro avg       0.42      0.40      0.33       394
# weighted avg       0.44      0.39      0.34       394

# %% [markdown]
# ## Feature Importance analyse

# %%
# Merge mempool_featuresA with df_eindmodel
df_eindmodel = pd.merge(df_eindmodel, mempool_features, left_on='Timestamp', right_index=True)

# Remove specified columns
columns_to_drop = ['MempoolSizeBytes', 'avg_fee_per_tx_sats', 'avg_fee_per_tx', 
                  'mempool_transaction_count', 'TotalFees_BTC']
df_eindmodel = df_eindmodel.drop(columns=columns_to_drop)

# %%
df_eindmodel
# Out:
#       Timestamp       Open       High        Low      Close        Volume  \
# 0    2018-02-01    9974.91   10187.56    8820.96    8970.00  20517.085284
# 1    2018-02-02    8970.00    9234.10    7625.25    8580.00  47828.982222
# 2    2018-02-03    8551.19    9443.96    8170.71    9386.72  17968.929040
# 3    2018-02-04    9391.30    9491.20    8189.32    8301.65  14407.720751
# 4    2018-02-05    8301.65    8416.03    6865.66    6877.61  37314.242065
# ...         ...        ...        ...        ...        ...           ...
# 2651 2025-05-06   94725.00   96895.00   93376.00   96814.00   1074.635037
# 2652 2025-05-07   96815.00   97717.00   95823.00   97054.00   1333.272379
# 2653 2025-05-08   97059.00  104159.00   96907.00  103261.00   2303.463144
# 2654 2025-05-09  103234.00  104332.00  102350.00  102991.00   1336.085909
# 2655 2025-05-10  102992.00  104985.00  102845.00  104809.00    624.265066
#
#                MA7          MA30  fear_greed_index  market_regime  \
# 0     10602.648571  12637.540000              30.0              0
# 1     10250.204286  12429.063333              15.0              0
# 2      9956.165714  12249.274000              40.0              0
# 3      9484.974286  11980.415000              24.0              0
# 4      8862.992857  11650.574333              11.0              0
# ...            ...           ...               ...            ...
# 2651  95630.285714  89083.466667              59.0              0
# 2652  96040.714286  89681.033333              67.0              0
# 2653  97001.571429  90581.600000              65.0              0
# 2654  97868.142857  91261.466667              73.0              0
# 2655  99138.571429  92103.666667              70.0              0
#
#       log_mempool_size  mempool_size_pct_change  y  avg_fee_per_tx_log
# 0            17.768706                 0.004306 -1            0.008614
# 1            17.773003                 0.004306  1            0.008598
# 2            17.777281                 0.004288 -1            0.008581
# 3            17.405676                -0.310374 -1            0.011665
# 4            16.807729                -0.450061  1            0.019138
# ...                ...                      ... ..                 ...
# 2651         14.885169                 0.086380  0            0.001048
# 2652         15.494085                 0.838437  1            0.001220
# 2653         15.869819                 0.456060  0            0.001422
# 2654         15.795769                -0.071375  1            0.001557
# 2655         15.715794                -0.076861  0            0.001562
#
# [2656 rows x 14 columns]

# %%
# Remove mempool size related columns
columns_to_drop = ['log_mempool_size', 'mempool_size_pct_change']
df_eindmodel = df_eindmodel.drop(columns=columns_to_drop)

# %%
window_size = 30
feature_columns = [col for col in df_eindmodel.columns if col not in ['Timestamp', 'y']]  # alle inputfeatures

X = []
y = []

for i in range(len(df_eindmodel) - window_size):
    X.append(df_eindmodel[feature_columns].iloc[i:i+window_size].values)
    y.append(df_eindmodel['y'].iloc[i + window_size])  # gebruik bestaande label

X = np.array(X)
y = np.array(y)

print(f'X shape: {X.shape}')
print(f'y shape: {y.shape}')
# Out:
# X shape: (2626, 30, 10)
# y shape: (2626,)

# %%
# Print de feature namen
print("Features in X:")
for i, feature in enumerate(feature_columns):
    print(f"{i+1}. {feature}")
# Out:
# Features in X:
# 1. Open
# 2. High
# 3. Low
# 4. Close
# 5. Volume
# 6. MA7
# 7. MA30
# 8. fear_greed_index
# 9. market_regime
# 10. avg_fee_per_tx_log

# %%
# Bepaal totale lengte
n_total = X.shape[0]

# Bepaal de indices voor de splitsing (70% train, 15% val, 15% test)
train_end = int(n_total * 0.7)
val_end = int(n_total * 0.85)

# Splits X en y op basis van tijdsvolgorde
X_train, y_train = X[:train_end], y[:train_end]
X_val, y_val = X[train_end:val_end], y[train_end:val_end]
X_test, y_test = X[val_end:], y[val_end:]

# Print shapes om te checken
print("Train:", X_train.shape, y_train.shape)
print("Validation:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# Train: (1838, 30, 10) (1838,)
# Validation: (394, 30, 10) (394,)
# Test: (394, 30, 10) (394,)

# %%
# Train model met aangepaste parameters
model = XGBClassifier(
    objective='multi:softprob',
    num_class=3,
    random_state=42,
    max_depth=9,             
    learning_rate=0.01,       
    n_estimator = 121,      
    min_child_weight=1,     
    gamma=0.7,                
    subsample=0.8,         
    colsample_bytree=0.6,    
    reg_alpha=0,             
    reg_lambda=5           
)

# Flatten de 3D input data naar 2D voor XGBoost
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_val_flat = X_val.reshape(X_val.shape[0], -1)

# Labels aanpassen van [-1,0,1] naar [0,1,2] voor classificatie
y_train_adj = y_train + 1
y_val_adj = y_val + 1

# Voeg validatie toe voor learning curves
eval_set = [(X_train_flat, y_train_adj), (X_val_flat, y_val_adj)]

# Training met eval_set
model.fit(
    X_train_flat, 
    y_train_adj,
    eval_set=eval_set,
    verbose=True
)

# Plot learning curves
results = model.evals_result()
plt.figure(figsize=(10, 6))
plt.plot(results['validation_1']['mlogloss'], label='Validation')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.title('Learning Curve - Validation')
plt.legend()
plt.grid(True)
plt.show()

# Voorspellingen en evaluatie op validatieset
y_val_pred = model.predict(X_val_flat)
y_val_pred = y_val_pred - 1  # Terug naar originele labels [-1, 0, 1]

print("\nValidation performance:")
print(classification_report(y_val, y_val_pred))
# Out:
# c:\Users\boris\AppData\Local\Programs\Python\Python313\Lib\site-packages\xgboost\training.py:183: UserWarning: [14:42:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "n_estimator" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0]	validation_0-mlogloss:1.09425	validation_1-mlogloss:1.09809
# [1]	validation_0-mlogloss:1.09014	validation_1-mlogloss:1.09793
# [2]	validation_0-mlogloss:1.08595	validation_1-mlogloss:1.09806
# [3]	validation_0-mlogloss:1.08204	validation_1-mlogloss:1.09871
# [4]	validation_0-mlogloss:1.07756	validation_1-mlogloss:1.09867
# [5]	validation_0-mlogloss:1.07351	validation_1-mlogloss:1.09899
# [6]	validation_0-mlogloss:1.06941	validation_1-mlogloss:1.09874
# [7]	validation_0-mlogloss:1.06516	validation_1-mlogloss:1.09836
# [8]	validation_0-mlogloss:1.06106	validation_1-mlogloss:1.09911
# [9]	validation_0-mlogloss:1.05730	validation_1-mlogloss:1.09978
# [10]	validation_0-mlogloss:1.05319	validation_1-mlogloss:1.09900
# [11]	validation_0-mlogloss:1.04929	validation_1-mlogloss:1.09847
# [12]	validation_0-mlogloss:1.04507	validation_1-mlogloss:1.09769
# [13]	validation_0-mlogloss:1.04134	validation_1-mlogloss:1.09841
# [14]	validation_0-mlogloss:1.03761	validation_1-mlogloss:1.09830
# [15]	validation_0-mlogloss:1.03409	validation_1-mlogloss:1.09820
# [16]	validation_0-mlogloss:1.03053	validation_1-mlogloss:1.09769
# [17]	validation_0-mlogloss:1.02687	validation_1-mlogloss:1.09780
# [18]	validation_0-mlogloss:1.02315	validation_1-mlogloss:1.09767
# [19]	validation_0-mlogloss:1.01948	validation_1-mlogloss:1.09715
# [20]	validation_0-mlogloss:1.01569	validation_1-mlogloss:1.09666
# [21]	validation_0-mlogloss:1.01201	validation_1-mlogloss:1.09636
# [22]	validation_0-mlogloss:1.00827	validation_1-mlogloss:1.09665
# [23]	validation_0-mlogloss:1.00434	validation_1-mlogloss:1.09636
# [24]	validation_0-mlogloss:1.00064	validation_1-mlogloss:1.09624
# [25]	validation_0-mlogloss:0.99680	validation_1-mlogloss:1.09554
# [26]	validation_0-mlogloss:0.99328	validation_1-mlogloss:1.09469
# [27]	validation_0-mlogloss:0.98949	validation_1-mlogloss:1.09492
# [28]	validation_0-mlogloss:0.98597	validation_1-mlogloss:1.09522
# [29]	validation_0-mlogloss:0.98252	validation_1-mlogloss:1.09453
# [30]	validation_0-mlogloss:0.97894	validation_1-mlogloss:1.09428
# [31]	validation_0-mlogloss:0.97528	validation_1-mlogloss:1.09451
# [32]	validation_0-mlogloss:0.97177	validation_1-mlogloss:1.09457
# [33]	validation_0-mlogloss:0.96828	validation_1-mlogloss:1.09465
# [34]	validation_0-mlogloss:0.96499	validation_1-mlogloss:1.09508
# [35]	validation_0-mlogloss:0.96137	validation_1-mlogloss:1.09454
# [36]	validation_0-mlogloss:0.95795	validation_1-mlogloss:1.09434
# [37]	validation_0-mlogloss:0.95466	validation_1-mlogloss:1.09362
# [38]	validation_0-mlogloss:0.95135	validation_1-mlogloss:1.09333
# [39]	validation_0-mlogloss:0.94773	validation_1-mlogloss:1.09336
# [40]	validation_0-mlogloss:0.94417	validation_1-mlogloss:1.09330
# [41]	validation_0-mlogloss:0.94106	validation_1-mlogloss:1.09278
# [42]	validation_0-mlogloss:0.93778	validation_1-mlogloss:1.09241
# [43]	validation_0-mlogloss:0.93444	validation_1-mlogloss:1.09183
# [44]	validation_0-mlogloss:0.93103	validation_1-mlogloss:1.09209
# [45]	validation_0-mlogloss:0.92783	validation_1-mlogloss:1.09188
# [46]	validation_0-mlogloss:0.92442	validation_1-mlogloss:1.09191
# [47]	validation_0-mlogloss:0.92148	validation_1-mlogloss:1.09176
# [48]	validation_0-mlogloss:0.91806	validation_1-mlogloss:1.09133
# [49]	validation_0-mlogloss:0.91464	validation_1-mlogloss:1.09088
# [50]	validation_0-mlogloss:0.91141	validation_1-mlogloss:1.09149
# [51]	validation_0-mlogloss:0.90799	validation_1-mlogloss:1.09033
# [52]	validation_0-mlogloss:0.90493	validation_1-mlogloss:1.09089
# [53]	validation_0-mlogloss:0.90179	validation_1-mlogloss:1.09053
# [54]	validation_0-mlogloss:0.89868	validation_1-mlogloss:1.09023
# [55]	validation_0-mlogloss:0.89539	validation_1-mlogloss:1.09020
# [56]	validation_0-mlogloss:0.89219	validation_1-mlogloss:1.08962
# [57]	validation_0-mlogloss:0.88899	validation_1-mlogloss:1.08984
# [58]	validation_0-mlogloss:0.88596	validation_1-mlogloss:1.08962
# [59]	validation_0-mlogloss:0.88313	validation_1-mlogloss:1.08926
# [60]	validation_0-mlogloss:0.88035	validation_1-mlogloss:1.08874
# [61]	validation_0-mlogloss:0.87757	validation_1-mlogloss:1.08793
# [62]	validation_0-mlogloss:0.87497	validation_1-mlogloss:1.08712
# [63]	validation_0-mlogloss:0.87192	validation_1-mlogloss:1.08652
# [64]	validation_0-mlogloss:0.86877	validation_1-mlogloss:1.08645
# [65]	validation_0-mlogloss:0.86575	validation_1-mlogloss:1.08605
# [66]	validation_0-mlogloss:0.86270	validation_1-mlogloss:1.08645
# [67]	validation_0-mlogloss:0.85980	validation_1-mlogloss:1.08644
# [68]	validation_0-mlogloss:0.85671	validation_1-mlogloss:1.08633
# [69]	validation_0-mlogloss:0.85393	validation_1-mlogloss:1.08581
# [70]	validation_0-mlogloss:0.85081	validation_1-mlogloss:1.08556
# [71]	validation_0-mlogloss:0.84793	validation_1-mlogloss:1.08534
# [72]	validation_0-mlogloss:0.84526	validation_1-mlogloss:1.08519
# [73]	validation_0-mlogloss:0.84231	validation_1-mlogloss:1.08592
# [74]	validation_0-mlogloss:0.83963	validation_1-mlogloss:1.08543
# [75]	validation_0-mlogloss:0.83675	validation_1-mlogloss:1.08542
# [76]	validation_0-mlogloss:0.83404	validation_1-mlogloss:1.08480
# [77]	validation_0-mlogloss:0.83158	validation_1-mlogloss:1.08484
# [78]	validation_0-mlogloss:0.82912	validation_1-mlogloss:1.08495
# [79]	validation_0-mlogloss:0.82644	validation_1-mlogloss:1.08490
# [80]	validation_0-mlogloss:0.82375	validation_1-mlogloss:1.08426
# [81]	validation_0-mlogloss:0.82114	validation_1-mlogloss:1.08440
# [82]	validation_0-mlogloss:0.81846	validation_1-mlogloss:1.08412
# [83]	validation_0-mlogloss:0.81593	validation_1-mlogloss:1.08393
# [84]	validation_0-mlogloss:0.81336	validation_1-mlogloss:1.08405
# [85]	validation_0-mlogloss:0.81058	validation_1-mlogloss:1.08403
# [86]	validation_0-mlogloss:0.80813	validation_1-mlogloss:1.08344
# [87]	validation_0-mlogloss:0.80526	validation_1-mlogloss:1.08311
# [88]	validation_0-mlogloss:0.80268	validation_1-mlogloss:1.08294
# [89]	validation_0-mlogloss:0.80025	validation_1-mlogloss:1.08288
# [90]	validation_0-mlogloss:0.79766	validation_1-mlogloss:1.08264
# [91]	validation_0-mlogloss:0.79525	validation_1-mlogloss:1.08239
# [92]	validation_0-mlogloss:0.79280	validation_1-mlogloss:1.08202
# [93]	validation_0-mlogloss:0.79041	validation_1-mlogloss:1.08229
# [94]	validation_0-mlogloss:0.78785	validation_1-mlogloss:1.08190
# [95]	validation_0-mlogloss:0.78567	validation_1-mlogloss:1.08140
# [96]	validation_0-mlogloss:0.78321	validation_1-mlogloss:1.08172
# [97]	validation_0-mlogloss:0.78058	validation_1-mlogloss:1.08167
# [98]	validation_0-mlogloss:0.77817	validation_1-mlogloss:1.08192
# [99]	validation_0-mlogloss:0.77575	validation_1-mlogloss:1.08193
# Validation performance:
#               precision    recall  f1-score   support
#
#           -1       0.27      0.60      0.38        90
#            0       0.61      0.53      0.57       186
#            1       0.42      0.13      0.19       118
#
#     accuracy                           0.43       394
#    macro avg       0.44      0.42      0.38       394
# weighted avg       0.48      0.43      0.41       394

# %%
# Feature Importance Analysis

# Get feature names
feature_names = feature_columns

# Get feature importance scores and average across time windows
importance_scores = model.feature_importances_
importance_scores = importance_scores.reshape(-1, window_size)
avg_importance = importance_scores.mean(axis=1)

# Create dataframe with feature names and average importance scores
feature_importance = pd.DataFrame({
    'Feature': feature_names,
    'Average Importance': avg_importance
})

# Sort by importance
feature_importance = feature_importance.sort_values('Average Importance', ascending=False)

# Plot average feature importance
plt.figure(figsize=(10, 6))
plt.bar(range(len(feature_names)), feature_importance['Average Importance'])
plt.xticks(range(len(feature_names)), feature_importance['Feature'], rotation=45)
plt.xlabel('Features')
plt.ylabel('Average Importance Score')
plt.title('Average Feature Importance Analysis')
plt.tight_layout()
plt.show()

# Print features sorted by average importance
print("\nFeatures Sorted by Average Importance:")
print(feature_importance)
# Out:
# Features Sorted by Average Importance:
#               Feature  Average Importance
# 8       market_regime            0.003995
# 9  avg_fee_per_tx_log            0.003672
# 7    fear_greed_index            0.003483
# 2                 Low            0.003351
# 6                MA30            0.003323
# 4              Volume            0.003307
# 1                High            0.003268
# 3               Close            0.003116
# 0                Open            0.002980
# 5                 MA7            0.002840
